# %%
### IMPORTS ###
import pandas as pd
import yt_dlp
import json
import os
from pathlib import Path
import re

import webvtt
from ja_sentence_segmenter.common.pipeline import make_pipeline
from ja_sentence_segmenter.concatenate.simple_concatenator import concatenate_matching
from ja_sentence_segmenter.split.simple_splitter import split_newline, split_punctuation
import functools

# %%
# help(yt_dlp.YoutubeDL)
# Detailed explanation of yt-dlp options for your use case
"""
OPTIONS NEEDED FOR YOUR REQUIREMENTS:

1. TITLE - Automatically extracted as info_dict['title']
   
2. AUTHOR - Automatically extracted as info_dict['uploader']
   
3. LINK - The URL you provide to the function
   
4. DURATION - Automatically extracted as info_dict['duration'] (in seconds)

5. SUBTITLES WITH TIMESTAMPS (Japanese & English):
   - writesubtitles: True
     Downloads manually created subtitles
   
   - writeautomaticsub: True  
     Downloads auto-generated subtitles (YouTube's automatic captions)
   
   - subtitleslangs: ['ja', 'en']
     Specifies which subtitle languages to download
     Can use 'all' to download all available languages
   
   - subtitlesformat: 'vtt'  (RECOMMENDED)
     Format for subtitles. Options: 'vtt', 'srt', 'ass', 'lrc'
     VTT (WebVTT) includes timestamps in this format:
         00:00:01.000 --> 00:00:03.000
         Subtitle text here
     
     VTT is best for your use case because:
     - Includes precise timestamps
     - Easy to parse programmatically
     - Well-supported format

6. AUDIO FILE:
   - format: 'bestaudio/best'
     Downloads the best available audio quality
   
   - postprocessors: [{
         'key': 'FFmpegExtractAudio',
         'preferredcodec': 'mp3',      # Output format (mp3, wav, m4a, etc.)
         'preferredquality': '192',    # Audio bitrate (128, 192, 256, 320)
     }]
     Converts audio to MP3 format
   
   With the subtitle timestamps, you can later extract specific 
   audio segments using ffmpeg or pydub

OTHER USEFUL OPTIONS:

- writeinfojson: True
  Saves ALL metadata as a .info.json file including:
  - Full description, tags, categories
  - View count, like count, upload date
  - All available formats and quality info
  - Comments (if getcomments: True)
  
- outtmpl: 'path/%(title)s.%(ext)s'
  Controls output filename. Available variables:
  - %(title)s - Video title
  - %(uploader)s - Channel/uploader name
  - %(id)s - Video ID
  - %(upload_date)s - Upload date (YYYYMMDD)
  - %(duration)s - Duration in seconds
  Example: 'downloads/%(uploader)s/%(title)s_%(id)s.%(ext)s'

- writethumbnail: True
  Downloads the video thumbnail image
  
- quiet: False
  Shows download progress (True hides it)

- getcomments: True (with writeinfojson: True)
  Extracts video comments and saves to JSON
"""
# Out:
# "\nOPTIONS NEEDED FOR YOUR REQUIREMENTS:\n\n1. TITLE - Automatically extracted as info_dict['title']\n\n2. AUTHOR - Automatically extracted as info_dict['uploader']\n\n3. LINK - The URL you provide to the function\n\n4. DURATION - Automatically extracted as info_dict['duration'] (in seconds)\n\n5. SUBTITLES WITH TIMESTAMPS (Japanese & English):\n   - writesubtitles: True\n     Downloads manually created subtitles\n\n   - writeautomaticsub: True  \n     Downloads auto-generated subtitles (YouTube's automatic captions)\n\n   - subtitleslangs: ['ja', 'en']\n     Specifies which subtitle languages to download\n     Can use 'all' to download all available languages\n\n   - subtitlesformat: 'vtt'  (RECOMMENDED)\n     Format for subtitles. Options: 'vtt', 'srt', 'ass', 'lrc'\n     VTT (WebVTT) includes timestamps in this format:\n         00:00:01.000 --> 00:00:03.000\n         Subtitle text here\n\n     VTT is best for your use case because:\n     - Includes precise timestamps\n     - Easy to parse programmatically\n     - Well-supported format\n\n6. AUDIO FILE:\n   - format: 'bestaudio/best'\n     Downloads the best available audio quality\n\n   - postprocessors: [{\n         'key': 'FFmpegExtractAudio',\n         'preferredcodec': 'mp3',      # Output format (mp3, wav, m4a, etc.)\n         'preferredquality': '192',    # Audio bitrate (128, 192, 256, 320)\n     }]\n     Converts audio to MP3 format\n\n   With the subtitle timestamps, you can later extract specific \n   audio segments using ffmpeg or pydub\n\nOTHER USEFUL OPTIONS:\n\n- writeinfojson: True\n  Saves ALL metadata as a .info.json file including:\n  - Full description, tags, categories\n  - View count, like count, upload date\n  - All available formats and quality info\n  - Comments (if getcomments: True)\n\n- outtmpl: 'path/%(title)s.%(ext)s'\n  Controls output filename. Available variables:\n  - %(title)s - Video title\n  - %(uploader)s - Channel/uploader name\n  - %(id)s - Video ID\n  - %(upload_date)s - Upload date (YYYYMMDD)\n  - %(duration)s - Duration in seconds\n  Example: 'downloads/%(uploader)s/%(title)s_%(id)s.%(ext)s'\n\n- writethumbnail: True\n  Downloads the video thumbnail image\n\n- quiet: False\n  Shows download progress (True hides it)\n\n- getcomments: True (with writeinfojson: True)\n  Extracts video comments and saves to JSON\n"

# %%
def download_media_with_subtitles(url, output_dir='data'):
    """
    Download audio as MP3, subtitles, and metadata from a given URL.
    
    Args:
        url        (str): URL of the media to download
        output_dir (str): Directory to save downloaded files
    
    Returns:
        result: Information about downloaded files
    """
    
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)     
    
    # Configure yt-dlp options
    ydl_opts = {
        # Audio settings
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        
        # Output settings
        'outtmpl': f'{output_dir}/%(title)s.%(ext)s',
        
        # Subtitle settings - KEY FOR YOUR USE CASE
        'writesubtitles': True,              # Manual subs
        'writeautomaticsub': True,           # Auto-generated subs
        'subtitleslangs': ['ja'],            # Japanese (use translator to convert to en)
        'subtitlesformat': 'vtt',            # VTT format (includes timestamps)
        
        # Metadata settings
        'writeinfojson': True,               # Save full metadata as JSON
        'writethumbnail': False,             # Set True if you want thumbnails
        
        # Rate limiting to avoid 429 errors
        'sleep_interval_requests': 2,        # Sleep 2 seconds between API requests
        'sleep_interval_subtitles': 10,      # Sleep 10 seconds between subtitle downloads
        'sleep_interval': 1,                 # Sleep 1 second before each download
        
        # Progress settings
        'quiet': False,
        'no_warnings': False,
    }
    
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            # Extract info without downloading first to check what's available
            info = ydl.extract_info(url, download=False)

            # Display what's available
            print(f"\nTitle: {info.get('title')}")
            print(f"Author: {info.get('uploader', 'N/A')}")
            print(f"Duration: {info.get('duration', 'N/A')} seconds")
            print(f"URL: {url}\n")
            
            # Check subtitles
            manual_subs = list(info.get('subtitles', {}).keys())
            auto_subs = list(info.get('automatic_captions', {}).keys())
            print(f"Manual subtitles: {manual_subs if manual_subs else 'None'}")
            print(f"Auto-captions available for: {', '.join(auto_subs[:5])}... (and {len(auto_subs)-5} more)" if len(auto_subs) > 5 else f"Auto-captions: {auto_subs}\n")
            
            # Download everything
            print("\n===== Downloading audio, subtitles, and metadata... =====")
            print("(Adding delays between requests to avoid rate limiting...)\n")     

            ydl.download([url])
            
            result = {
                'title': info.get('title'),
                'duration': info.get('duration'),
                'uploader': info.get('uploader'),
                'upload_date': info.get('upload_date'),
                'view_count': info.get('view_count'),
                'like_count': info.get('like_count'),
                'description': info.get('description'),
                'subtitles_available': list(info.get('subtitles', {}).keys()),
                'auto_captions_available': list(info.get('automatic_captions', {}).keys()),
                'output_dir': output_dir
            }
            
            print("\nDownload complete!\n")
            return result
    except Exception as e:
        print(f"Error: {str(e)}\n")
        return None

# %%
# Test the function with a URL
# Replace with your desired URL
# url = "https://www.youtube.com/watch?v=1PPLx2N_YTE" # YUYU podcast test, auto gen subs
# url = "https://www.youtube.com/watch?v=hkeegM5t-lw" # Jiro podcast test, manual subs
# url = "https://open.spotify.com/track/7DyS11kB1YNrfDzQqtjmTh?si=24a7621a3a24483c" # spotify song
url = "https://www.youtube.com/watch?v=1mz-A--mANU"

# Download audio, subtitles, and metadata
result = download_media_with_subtitles(url, output_dir='japanese_media')

# Display the metadata
if result:
    #print("\\n\" + \"=\"*50")
    print("DOWNLOADED MEDIA INFORMATION\n")
    #print("=\"*50")
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1mz-A--mANU
# [youtube] 1mz-A--mANU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading android vr player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading ios downgraded player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading m3u8 information
# [info] 1mz-A--mANU: Downloading subtitles: ja
#
# Title: 平井 大 / Slow & Easy（Music Video）
# Author: 平井 大 HIRAIDAI
# Duration: 222 seconds
# URL: https://www.youtube.com/watch?v=1mz-A--mANU
#
# Manual subtitles: ['ja']
# Auto-captions available for: ja, ab-ja, aa-ja, af-ja, ak-ja... (and 152 more)
#
# ===== Downloading audio, subtitles, and metadata... =====
# (Adding delays between requests to avoid rate limiting...)
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1mz-A--mANU
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading android vr player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading ios downgraded player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading m3u8 information
# [info] 1mz-A--mANU: Downloading subtitles: ja
# [info] 1mz-A--mANU: Downloading 1 format(s): 251
# Deleting existing file japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.ja.vtt
# [info] Writing video subtitles to: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.ja.vtt
# [download] Sleeping 10.00 seconds ...
# WARNING: The extractor specified to use impersonation for this download, but no impersonate target is available. If you encounter errors, then see  https://github.com/yt-dlp/yt-dlp#impersonation  for information on installing the required dependencies
# [download] Destination: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.ja.vtt
# [download] 100% of    3.31KiB in 00:00:00 at 34.86KiB/s
# [info] Writing video metadata as JSON to: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.info.json
# [download] Sleeping 1.00 seconds ...
# [download] Destination: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.webm
# [download] 100% of    3.58MiB in 00:00:02 at 1.58MiB/s
# [ExtractAudio] Destination: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.mp3
# Deleting original file japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.webm (pass -k to keep)
#
# Download complete!
#
# DOWNLOADED MEDIA INFORMATION
#
# {
#   "title": "平井 大 / Slow & Easy（Music Video）",
#   "duration": 222,
#   "uploader": "平井 大 HIRAIDAI",
#   "upload_date": "20181220",
#   "view_count": 19170623,
#   "like_count": 85333,
#   "description": "平井 大の楽曲をチェック！\nhttps://DaiHirai.lnk.to/toppage\n\nFOLLOW \"HIRAIDAI\"\nWebsite: https://hiraidai.com/\nInstagram: https://www.instagram.com/hirai_dai_official/\nTwitter: https://twitter.com/hiraidai\nLINE: https://line.me/R/ti/p/%40hiraidai\nTikTok：https://www.tiktok.com/@hiraidai",
#   "subtitles_available": [
#     "ja"
#   ],
#   "auto_captions_available": [
#     "ja",
#     "ab-ja",
#     "aa-ja",
#     "af-ja",
#     "ak-ja",
#     "sq-ja",
#     "am-ja",
#     "ar-ja",
#     "hy-ja",
#     "as-ja",
#     "ay-ja",
#     "az-ja",
#     "bn-ja",
#     "ba-ja",
#     "eu-ja",
#     "be-ja",
#     "bho-ja",
#     "bs-ja",
#     "br-ja",
#     "bg-ja",
#     "my-ja",
#     "ca-ja",
#     "ceb-ja",
#     "zh-Hans-ja",
#     "zh-Hant-ja",
#     "co-ja",
#     "hr-ja",
#     "cs-ja",
#     "da-ja",
#     "dv-ja",
#     "nl-ja",
#     "dz-ja",
#     "en-ja",
#     "eo-ja",
#     "et-ja",
#     "ee-ja",
#     "fo-ja",
#     "fj-ja",
#     "fil-ja",
#     "fi-ja",
#     "fr-ja",
#     "gaa-ja",
#     "gl-ja",
#     "lg-ja",
#     "ka-ja",
#     "de-ja",
#     "el-ja",
#     "gn-ja",
#     "gu-ja",
#     "ht-ja",
#     "ha-ja",
#     "haw-ja",
#     "iw-ja",
#     "hi-ja",
#     "hmn-ja",
#     "hu-ja",
#     "is-ja",
#     "ig-ja",
#     "id-ja",
#     "iu-ja",
#     "ga-ja",
#     "it-ja",
#     "ja-ja",
#     "jv-ja",
#     "kl-ja",
#     "kn-ja",
#     "kk-ja",
#     "kha-ja",
#     "km-ja",
#     "rw-ja",
#     "ko-ja",
#     "kri-ja",
#     "ku-ja",
#     "ky-ja",
#     "lo-ja",
#     "la-ja",
#     "lv-ja",
#     "ln-ja",
#     "lt-ja",
#     "lua-ja",
#     "luo-ja",
#     "lb-ja",
#     "mk-ja",
#     "mg-ja",
#     "ms-ja",
#     "ml-ja",
#     "mt-ja",
#     "gv-ja",
#     "mi-ja",
#     "mr-ja",
#     "mn-ja",
#     "mfe-ja",
#     "ne-ja",
#     "new-ja",
#     "nso-ja",
#     "no-ja",
#     "ny-ja",
#     "oc-ja",
#     "or-ja",
#     "om-ja",
#     "os-ja",
#     "pam-ja",
#     "ps-ja",
#     "fa-ja",
#     "pl-ja",
#     "pt-ja",
#     "pt-PT-ja",
#     "pa-ja",
#     "qu-ja",
#     "ro-ja",
#     "rn-ja",
#     "ru-ja",
#     "sm-ja",
#     "sg-ja",
#     "sa-ja",
#     "gd-ja",
#     "sr-ja",
#     "crs-ja",
#     "sn-ja",
#     "sd-ja",
#     "si-ja",
#     "sk-ja",
#     "sl-ja",
#     "so-ja",
#     "st-ja",
#     "es-ja",
#     "su-ja",
#     "sw-ja",
#     "ss-ja",
#     "sv-ja",
#     "tg-ja",
#     "ta-ja",
#     "tt-ja",
#     "te-ja",
#     "th-ja",
#     "bo-ja",
#     "ti-ja",
#     "to-ja",
#     "ts-ja",
#     "tn-ja",
#     "tum-ja",
#     "tr-ja",
#     "tk-ja",
#     "uk-ja",
#     "ur-ja",
#     "ug-ja",
#     "uz-ja",
#     "ve-ja",
#     "vi-ja",
#     "war-ja",
#     "cy-ja",
#     "fy-ja",
#     "wo-ja",
#     "xh-ja",
#     "yi-ja",
#     "yo-ja",
#     "zu-ja"
#   ],
#   "output_dir": "japanese_media"
# }

# %%
### CREATING THE vtt PARSER ###
import re
from pathlib import Path

# %%
# 1.) vtt cleaner

# Remove empty lines
# Remove WEBVTT, Kind: captions, Language: ja lines (always first 3)
# Remove all lines with "<c>" or "</c>" since these are bad format and are repeatted in 
# next line anyways

# Output to (cleaned)+path
def vtt_clean(input_file):
    input_path = Path(input_file)

    if not input_path.exists():
        raise FileNotFoundError(F"File not found: {input_path}")

    # Read full file into content buffer
    content = input_path.read_text(encoding='utf-8')

    # Process
    re.sub(r"\n\n\n|\n\n", "\n", content) # Remove extra line breaks
    content = '\n'.join( # Remove all lines that have tags (they are repeats)
        line for line in content.split('\n') 
        if '<c>' not in line 
        and '</c>' not in line
        and 'WEBVTT' not in line
        and 'Kind: captions' not in line
        and 'Language: ja' not in line
    )

    content = content.split("\n") # Create array of all the lines with content
    content = [item for item in content if item not in ('', ' ')]

    window = 1
    cur_sent = ""
    c_len = len(content)
    data = []
    for i in range(0, c_len, window):
        if "-->" not in content[i]:
            continue

        if "-->" in content[i+1]:
            continue

        start_time, end_time = parse_timeframe(content[i])
        if (end_time - start_time) < .5:
            continue
        else:
            cur_sent = content[i+1]
            data.append({
                'start_time': start_time,
                'end_time': end_time,
                'text': content[i+1]
            })
    return data

# %%
def parse_timeframe(timeframe):
    # Remove any "-->" or align:start position:0% lines
    timeframe = re.sub(r"align.*", "", timeframe)
    timeframe = re.sub(r" --> ", ":", timeframe)
    timeframe = timeframe.split(":")
    s_hour = int(timeframe[0])
    s_min  = int(timeframe[1])
    s_sec  = float(timeframe[2])
    e_hour = int(timeframe[3])
    e_min  = int(timeframe[4])
    e_sec  = float(timeframe[5])

    start_time = round(((3600 * s_hour) + (60 * s_min) + s_sec), 2)
    end_time   = round(((3600 * e_hour) + (60 * e_min) + e_sec), 2)
    #print(timeframe)
    #print(F"start_time: {start_time}\nend_time: {end_time}")
    return start_time, end_time

# %%
s_test, e_test = parse_timeframe("00:00:02.230 --> 00:00:02.240 align:start position:0%")
e_test
# Out:
# 2.24

# %%
data1 = vtt_clean("/home/evanxavierhu/Documents/VSCode_Local_Projects/JL_Project/Japanese_Lang_Project/data_exploration/japanese_media/【1hour Podcast】本名は？結婚してる？苦手なことは？YUYUについて話しました！ (Japanese Radio for Listening practice).ja.vtt")
data2 = vtt_clean("/home/evanxavierhu/Documents/VSCode_Local_Projects/JL_Project/Japanese_Lang_Project/data_exploration/japanese_media/【Japanese Podcast】I Got This! - Master 706 Essential Words Without Even Noticing.ja.vtt")
data3 = vtt_clean("/home/evanxavierhu/Documents/VSCode_Local_Projects/JL_Project/Japanese_Lang_Project/data_exploration/japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.ja.vtt")

# %%
data1
# Out:
# [{'start_time': 2.24, 'end_time': 4.47, 'text': 'はい、皆さんこんにちは。ゆの日本語'},
#  {'start_time': 4.48, 'end_time': 7.07, 'text': 'ポッドキャストのお時間です。皆さん元気'},
#  {'start_time': 7.08, 'end_time': 9.83, 'text': 'にしていますでしょうか?今日は久しぶり'},
#  {'start_time': 9.84, 'end_time': 14.15, 'text': 'に1時間ポッドキャストにチャレンジし'},
#  {'start_time': 14.16, 'end_time': 17.11, 'text': 'たいと思います。テーマはゆについて、あ'},
#  {'start_time': 17.12, 'end_time': 19.95, 'text': '、ま、つまり僕についてですね。ま、'},
#  {'start_time': 19.96, 'end_time': 23.31, 'text': 'おかげ様でYouTubeの登録者数が'},
#  {'start_time': 23.32, 'end_time': 26.59, 'text': 'もうすぐ50万人を迎えてそれだけじゃ'},
#  {'start_time': 26.6, 'end_time': 29.71, 'text': 'なくてですね、チャンネル運営が5年目を'},
#  {'start_time': 29.72, 'end_time': 32.23, 'text': '迎える、ま、そういった年でもあるんです'},
#  {'start_time': 32.24, 'end_time': 35.11, 'text': 'よ。まあ、つまり簡単に言うと5年前に'},
#  {'start_time': 35.12, 'end_time': 38.91, 'text': 'ゆuの日本語ポッドキャストを始めてで、'},
#  {'start_time': 38.92, 'end_time': 42.31, 'text': 'もう5年が経ったということで、ま、その'},
#  {'start_time': 42.32, 'end_time': 44.19, 'text': '始めた頃から新しいメンバーもですね、'},
#  {'start_time': 44.2, 'end_time': 46.11, 'text': 'あの、ま、この、この場合のメンバーメン'},
#  {'start_time': 46.12, 'end_time': 48.27, 'text': 'バーっていうのは皆さん、フォロワー、皆'},
#  {'start_time': 48.28, 'end_time': 53.15, 'text': 'さんのことなんですけども、ま、新しい'},
#  {'start_time': 53.16, 'end_time': 56.19, 'text': 'メンバーも迎えて、ま、多分僕についての'},
#  {'start_time': 56.2, 'end_time': 60.11, 'text': 'ね、え、知っていることっていうのは'},
#  {'start_time': 60.12, 'end_time': 63.47, 'text': 'もちろんですけども、新しい方と、ま、昔'},
#  {'start_time': 63.48, 'end_time': 66.07, 'text': 'から聞いてくださっている方はもう全然'},
#  {'start_time': 66.08, 'end_time': 70.11, 'text': '違うわけですよね。ていうことで、ま、'},
#  {'start_time': 70.12, 'end_time': 74.11, 'text': 'いい機会だなと思いまして、自己紹介をし'},
#  {'start_time': 74.12, 'end_time': 77.39, 'text': 'てみたいと思います。はい。ま、ただね、'},
#  {'start_time': 77.4, 'end_time': 80.31, 'text': '自己紹介って普通10秒とか20秒ぐらい'},
#  {'start_time': 80.32, 'end_time': 85.35, 'text': 'ですよね。なんですけども、ま、その自己'},
#  {'start_time': 85.36, 'end_time': 88.47, 'text': '紹介で話すテーマをできるだけ深く'},
#  {'start_time': 88.48, 'end_time': 90.87, 'text': '掘り下げてで、僕について、ま、皆さんに'},
#  {'start_time': 90.88, 'end_time': 93.87, 'text': '知ってもらおうっていうのが、ま、今回の'},
#  {'start_time': 93.88, 'end_time': 96.27, 'text': '1時間ポッドキャストです。はい。という'},
#  {'start_time': 96.28, 'end_time': 98.79, 'text': 'ことで、ま、簡単にメモを取ってきました'},
#  {'start_time': 98.8, 'end_time': 102.23, 'text': '。ま、こんな感じですね。え、話す内容に'},
#  {'start_time': 102.24, 'end_time': 106.07, 'text': 'ついては、え、全部で10個です。え、1'},
#  {'start_time': 106.08, 'end_time': 108.95, 'text': 'つ目は名前について、で、2つ目は出身地'},
#  {'start_time': 108.96, 'end_time': 112.75, 'text': '、住んでいるところについて。そして3つ'},
#  {'start_time': 112.76, 'end_time': 116.47, 'text': '目は、え、家族について。そして4つ目、'},
#  {'start_time': 116.48, 'end_time': 120.47, 'text': '好きなこと、趣味、特技。そして5つ目、'},
#  {'start_time': 120.48, 'end_time': 124.75, 'text': '苦手なこと。そして、え、6つ目、学歴'},
#  {'start_time': 124.76, 'end_time': 127.31, 'text': 'ですね。で、7つ目、性格。8つ目、今の'},
#  {'start_time': 127.32, 'end_time': 130.07, 'text': '仕事。そして、え、ここの爪、'},
#  {'start_time': 130.08, 'end_time': 133.31, 'text': 'プライベート。そして最後はこれからの'},
#  {'start_time': 133.32, 'end_time': 136.51, 'text': '目標ということで、ま、10個のテーマに'},
#  {'start_time': 136.52, 'end_time': 140.19, 'text': 'ついて1時間かけてのんびりと話していき'},
#  {'start_time': 140.2, 'end_time': 142.75, 'text': 'たいと思います。はい。で、早速始めて'},
#  {'start_time': 142.76, 'end_time': 145.39, 'text': 'いきたいと思うんですけども、1つ目の'},
#  {'start_time': 145.4, 'end_time': 149.31, 'text': '名前ですね。'},
#  {'start_time': 149.32, 'end_time': 153.11, 'text': '僕の名前は裕介と言います。皆さんこれ'},
#  {'start_time': 153.12, 'end_time': 155.51, 'text': '知ってました?はい。あの、フルネームを'},
#  {'start_time': 155.52, 'end_time': 159.19, 'text': 'ね、YouTubeでアップロードするの'},
#  {'start_time': 159.2, 'end_time': 161.59, 'text': 'はちょっといさかあの抵抗があるところが'},
#  {'start_time': 161.6, 'end_time': 164.91, 'text': 'あるので名前だけにしたいと思うんですが'},
#  {'start_time': 164.92, 'end_time': 170.27, 'text': '名前はゆ介っています。感じなんですが、'},
#  {'start_time': 170.28, 'end_time': 173.63, 'text': 'Uゆ自のUに、え、スケはあのゆ介とか他'},
#  {'start_time': 173.64, 'end_time': 177.63, 'text': 'のね、え、皆さんがよく使う簡単な紹介の'},
#  {'start_time': 177.64, 'end_time': 180.51, 'text': '回でスって書いて裕介っていう風に読み'},
#  {'start_time': 180.52, 'end_time': 182.83, 'text': 'ます。ま、日本人の名前っていうのは'},
#  {'start_time': 182.84, 'end_time': 184.59, 'text': 'それぞれこう意味が込められてい'},
#  {'start_time': 184.6, 'end_time': 188.15, 'text': 'るっていうのはもう皆さん知っていると'},
#  {'start_time': 188.16, 'end_time': 191.51, 'text': '思うんですけども、え、僕の名前は、え、'},
#  {'start_time': 191.52, 'end_time': 194.91, 'text': 'おばあちゃんがつけてくれました。で、'},
#  {'start_time': 194.92, 'end_time': 198.47, 'text': 'えっと、おばあちゃんがこの名前に込めた'},
#  {'start_time': 198.48, 'end_time': 201.67, 'text': '思いっていうのは、えー、'},
#  {'start_time': 201.68, 'end_time': 205.51, 'text': '次的に、ま、つまりのんびりと自分の'},
#  {'start_time': 205.52, 'end_time': 208.11, 'text': 'ペースでリラックスしてその過ごして'},
#  {'start_time': 208.12, 'end_time': 211.27, 'text': '欲しい、優しい男の子に、ま、育って欲し'},
#  {'start_time': 211.28, 'end_time': 214.59, 'text': 'いっていう思いを込めて、え、裕介にした'},
#  {'start_time': 214.6, 'end_time': 216.95, 'text': 'そうです。ま、これは僕が生まれた時にお'},
#  {'start_time': 216.96, 'end_time': 219.27, 'text': 'ばあちゃんに直接聞いたわけではなく、ま'},
#  {'start_time': 219.28, 'end_time': 221.83, 'text': '、家族から、ま、そういうことがあった'},
#  {'start_time': 221.84, 'end_time': 223.59, 'text': 'らしいよとか、おばあちゃんがそういう風'},
#  {'start_time': 223.6, 'end_time': 226.47, 'text': 'にね、あの、つけたんだよっておばあ'},
#  {'start_time': 226.48, 'end_time': 228.39, 'text': 'ちゃんに聞いた話なので、ま、あの、本当'},
#  {'start_time': 228.4, 'end_time': 231.15, 'text': 'かどうかはね、分からないですけども、ま'},
#  {'start_time': 231.16, 'end_time': 234.71, 'text': '、そういった意味で裕介っていう風に言い'},
#  {'start_time': 234.72, 'end_time': 238.07, 'text': 'ます。この裕介っていうのはですね、本当'},
#  {'start_time': 238.08, 'end_time': 241.35, 'text': 'に日本人色々まあ、なんて言うんですか、'},
#  {'start_time': 241.36, 'end_time': 245.59, 'text': 'よくある名前なんですけども、ま、その中'},
#  {'start_time': 245.6, 'end_time': 248.55, 'text': 'でもこの僕の漢字を使う裕介っていう名前'},
#  {'start_time': 248.56, 'end_time': 252.23, 'text': 'はですね、あんまりないんじゃないかなと'},
#  {'start_time': 252.24, 'end_time': 256.35, 'text': '思います。なんか話に聞くとこの僕のU'},
#  {'start_time': 256.36, 'end_time': 259.47, 'text': 'っていう感じは割と若い人にもう使うこと'},
#  {'start_time': 259.48, 'end_time': 262.43, 'text': 'が多いらしくて、僕の世代ではあまり使わ'},
#  {'start_time': 262.44, 'end_time': 265.79, 'text': 'れない。ま、そういった感じで、ちょっと'},
#  {'start_time': 265.8, 'end_time': 269.47, 'text': '特別感がね、昔からありました。そして'},
#  {'start_time': 269.48, 'end_time': 273.19, 'text': 'この裕介のUなんですけども、形としても'},
#  {'start_time': 273.2, 'end_time': 276.11, 'text': 'すごく綺麗だなって思うんですよ。下に心'},
#  {'start_time': 276.12, 'end_time': 280.95, 'text': 'がある感じですね。あ、心があるという'},
#  {'start_time': 280.96, 'end_time': 284.11, 'text': 'ことで、ま、すごく人間っぽい優しい感じ'},
#  {'start_time': 284.12, 'end_time': 287.11, 'text': 'がする。うん。ま、勝てなくてもいいと、'},
#  {'start_time': 287.12, 'end_time': 289.11, 'text': '人生が成功しなくてもいいけど、なんか'},
#  {'start_time': 289.12, 'end_time': 292.67, 'text': '優しく生きていきたい。そういう風に'},
#  {'start_time': 292.68, 'end_time': 297.19, 'text': '思える素敵な名前だなと。あの自分の名前'},
#  {'start_time': 297.2, 'end_time': 300.11, 'text': 'のことは大好きです。はい。で、え、次に'},
#  {'start_time': 300.12, 'end_time': 303.19, 'text': 'ですね、ま、皆さんが使っている'},
#  {'start_time': 303.2, 'end_time': 306.63, 'text': 'ニックネームゆですね。はい。もうお'},
#  {'start_time': 306.64, 'end_time': 310.63, 'text': '気づきの方もいると思うんですが、ゆ介だ'},
#  {'start_time': 310.64, 'end_time': 313.87, 'text': 'からゆゆっていう風にしました。ま、これ'},
#  {'start_time': 313.88, 'end_time': 317.51, 'text': 'はあの色々な意味の部分もありまして、え'},
#  {'start_time': 317.52, 'end_time': 320.03, 'text': '、つまり僕のこの裕介のUっていうのは'},
#  {'start_time': 320.04, 'end_time': 323.75, 'text': 'リラックスして自分のペースでっていう'},
#  {'start_time': 323.76, 'end_time': 327.99, 'text': '意味があります。で、皆さんにもその日本'},
#  {'start_time': 328.0, 'end_time': 330.19, 'text': '語の勉強を自分のペースでリラックスして'},
#  {'start_time': 330.2, 'end_time': 333.55, 'text': 'やってもらえたらいいなってずっと思って'},
#  {'start_time': 333.56, 'end_time': 335.95, 'text': 'いて、で、このゆאゆっていうのがいいん'},
#  {'start_time': 335.96, 'end_time': 339.15, 'text': 'じゃないかなっていう風に決めました。で'},
#  {'start_time': 339.16, 'end_time': 341.47, 'text': '、ま、この名前をつけたのも、え、今から'},
#  {'start_time': 341.48, 'end_time': 343.95, 'text': '5年前、ちょうどこのポッドキャストだっ'},
#  {'start_time': 343.96, 'end_time': 346.91, 'text': 'たりとか、あとはゆ日日本語っていう自分'},
#  {'start_time': 346.92, 'end_time': 350.63, 'text': 'のプロジェクトを立ち上げる時に裕介って'},
#  {'start_time': 350.64, 'end_time': 354.27, 'text': 'いう名前でそのネットに自分のね、え、'},
#  {'start_time': 354.28, 'end_time': 356.83, 'text': '存在をま、出すっていうのはどうなん'},
#  {'start_time': 356.84, 'end_time': 358.75, 'text': 'だろうな。せっかくだからみんなが覚え'},
#  {'start_time': 358.76, 'end_time': 361.87, 'text': 'やすいニックネームみたいなのがあると'},
#  {'start_time': 361.88, 'end_time': 366.83, 'text': 'いいなっていう、ま、そういった話になり'},
#  {'start_time': 366.84, 'end_time': 371.23, 'text': 'まして。で、その時にいろんな候補があっ'},
#  {'start_time': 371.24, 'end_time': 373.75, 'text': 'たんですけども、UっていうYuYuって'},
#  {'start_time': 373.76, 'end_time': 378.51, 'text': 'いう風に書く'},
#  {'start_time': 378.52, 'end_time': 382.11, 'text': '名前、ま、そういう風な活動名で活動して'},
#  {'start_time': 382.12, 'end_time': 384.43, 'text': 'いる人がその当時5年前には'},
#  {'start_time': 384.44, 'end_time': 389.19, 'text': 'YouTubeにいなかったんですよね。'},
#  {'start_time': 389.2, 'end_time': 393.51, 'text': 'なので、こうちょっと戦略的なあの意味も'},
#  {'start_time': 393.52, 'end_time': 395.87, 'text': 'あって、ま、皆さんが呼びやすい、覚え'},
#  {'start_time': 395.88, 'end_time': 400.59, 'text': 'やすい、そして文字として見て分かり'},
#  {'start_time': 400.6, 'end_time': 404.31, 'text': 'やすいで調べる時にゆゆって調べたら僕が'},
#  {'start_time': 404.32, 'end_time': 407.03, 'text': '出てくる可能性が高いっていうのでこの'},
#  {'start_time': 407.04, 'end_time': 410.11, 'text': 'ゆuユっていう名前をつけました。はい。'},
#  {'start_time': 410.12, 'end_time': 414.43, 'text': 'ま、アルファベットで書くとyuyuって'},
#  {'start_time': 414.44, 'end_time': 418.03, 'text': '書くんですが、え、元々の名前が裕介から'},
#  {'start_time': 418.04, 'end_time': 423.03, 'text': '来ているので、あの、ひらがで書くとゆう'},
#  {'start_time': 423.04, 'end_time': 426.11, 'text': 'ゆうっていう風に、あの、書くっていう僕'},
#  {'start_time': 426.12, 'end_time': 429.07, 'text': 'の中ではそういう理解があって、ま、あの'},
#  {'start_time': 429.08, 'end_time': 431.43, 'text': '、もちろんですけども、YU、Yuだとゆ'},
#  {'start_time': 431.44, 'end_time': 434.07, 'text': 'になるので、え、いろんなYouTube'},
#  {'start_time': 434.08, 'end_time': 437.55, 'text': 'のコメントでね、ゆ先生っていう風に、'},
#  {'start_time': 437.56, 'end_time': 442.39, 'text': 'あの、ま、書かれる方が多いんですけども'},
#  {'start_time': 442.4, 'end_time': 445.83, 'text': '、ま、正確に言うとU先生になるかなと'},
#  {'start_time': 445.84, 'end_time': 448.71, 'text': '思います。ま、あの、ま、正直ね、'},
#  {'start_time': 448.72, 'end_time': 450.99, 'text': 'ニックネームですので、あの、どうでも'},
#  {'start_time': 451.0, 'end_time': 453.51, 'text': 'いいんですけどもね、あの、もし、え、僕'},
#  {'start_time': 453.52, 'end_time': 457.27, 'text': 'の名前をひらがで書きたいっていう方は、'},
#  {'start_time': 457.28, 'end_time': 461.11, 'text': 'え、音を伸ばして4文字ゆうゆうって書い'},
#  {'start_time': 461.12, 'end_time': 463.19, 'text': 'てくれると嬉しいなと思います。はい。で'},
#  {'start_time': 463.2, 'end_time': 468.31, 'text': '、ま、ちょっと名前つがりでですね。えっ'},
#  {'start_time': 468.32, 'end_time': 471.23, 'text': 'と、僕のその活動名、え、ゆをひらがで'},
#  {'start_time': 471.24, 'end_time': 474.27, 'text': 'ゆゆって書いてもゆって書いてもそれは'},
#  {'start_time': 474.28, 'end_time': 477.79, 'text': 'いいんですけども、あのゆ介っていう名前'},
#  {'start_time': 477.8, 'end_time': 481.31, 'text': 'をあのコメントで、え、書いてくれる場合'},
#  {'start_time': 481.32, 'end_time': 484.83, 'text': 'は、あの、是非僕の感じ、このね、有々児'},
#  {'start_time': 484.84, 'end_time': 489.03, 'text': '的のUを使って書いてくれると嬉しいです'},
#  {'start_time': 489.04, 'end_time': 492.15, 'text': '。うん。あの、他の感じで書かれてしまう'},
#  {'start_time': 492.16, 'end_time': 494.63, 'text': 'となんか他の人みたいな自分に書かれてな'},
#  {'start_time': 494.64, 'end_time': 496.75, 'text': 'いっていう気持ちがするんですよね。で、'},
#  {'start_time': 496.76, 'end_time': 499.43, 'text': 'ま、これちょっと日本語のアドバイスなん'},
#  {'start_time': 499.44, 'end_time': 502.67, 'text': 'ですけども、え、日本人のお友達がいると'},
#  {'start_time': 502.68, 'end_time': 505.67, 'text': '。で、その人の名前の発音は分かるんだ'},
#  {'start_time': 505.68, 'end_time': 508.23, 'text': 'けども、漢字が分からない場合、この場合'},
#  {'start_time': 508.24, 'end_time': 511.35, 'text': 'は基本的にはひらがで書いてしまって'},
#  {'start_time': 511.36, 'end_time': 514.47, 'text': '大丈夫です。で、ビジネスの場面では'},
#  {'start_time': 514.48, 'end_time': 517.87, 'text': 'カタカナで書く場合もあります。まあ、'},
#  {'start_time': 517.88, 'end_time': 520.95, 'text': 'どっちにしても、あの、そのお友達だっ'},
#  {'start_time': 520.96, 'end_time': 524.23, 'text': 'たりとか、取引先だったり先輩ね、その'},
#  {'start_time': 524.24, 'end_time': 526.59, 'text': '日本人の名前の感じをしっかり覚えてお'},
#  {'start_time': 526.6, 'end_time': 529.67, 'text': 'くっていうのはすごく大切なことになり'},
#  {'start_time': 529.68, 'end_time': 532.39, 'text': 'ますし、覚えて損はないと思いますので、'},
#  {'start_time': 532.4, 'end_time': 535.67, 'text': 'ま、是非ぜひぜ非ぜ非ぜひぜひ'},
#  {'start_time': 535.68, 'end_time': 539.79, 'text': '覚えといてください。はい。これが名前'},
#  {'start_time': 539.8, 'end_time': 543.23, 'text': 'ですね。で、次なんですが出身地です。'},
#  {'start_time': 543.24, 'end_time': 546.39, 'text': '出身地は埼玉県。ま、僕は埼玉県で生まれ'},
#  {'start_time': 546.4, 'end_time': 549.55, 'text': 'ました。そして、えっと、埼玉県で育った'},
#  {'start_time': 549.56, 'end_time': 551.15, 'text': 'んですけども、あの、そう、そう、そう、'},
#  {'start_time': 551.16, 'end_time': 553.51, 'text': 'そう。ま、これはね、ちょ皆さんに'},
#  {'start_time': 553.52, 'end_time': 558.11, 'text': 'しっかり言っておきたいんですが、日本人'},
#  {'start_time': 558.12, 'end_time': 560.55, 'text': 'です。はい。日本で生まれました。あの、'},
#  {'start_time': 560.56, 'end_time': 563.07, 'text': '中にはコメントでね、裕介って日本人'},
#  {'start_time': 563.08, 'end_time': 566.71, 'text': 'なのっていう風には書く方いるんですけど'},
#  {'start_time': 566.72, 'end_time': 569.27, 'text': 'も、あのコメントが1番傷つくかな。うん'},
#  {'start_time': 569.28, 'end_time': 571.07, 'text': '。え、なんか自分が日本人じゃないって'},
#  {'start_time': 571.08, 'end_time': 574.19, 'text': 'いうのはなんかアイデンティティがないと'},
#  {'start_time': 574.2, 'end_time': 576.43, 'text': 'か自分の家族が日本にいるのに自分だけ'},
#  {'start_time': 576.44, 'end_time': 579.51, 'text': '外国人になっちゃったのみたいな気持ちに'},
#  {'start_time': 579.52, 'end_time': 583.35, 'text': 'なるので、あの柚介は日本人だよと。うん'},
#  {'start_time': 583.36, 'end_time': 585.87, 'text': '。是非ぜひあの皆さんね、あのゆの日本語'},
#  {'start_time': 585.88, 'end_time': 587.63, 'text': 'ポッドキャストファンのお友達がいたら'},
#  {'start_time': 587.64, 'end_time': 589.39, 'text': 'ゆって日本人だよってこな間だ'},
#  {'start_time': 589.4, 'end_time': 593.11, 'text': 'ポッドキャストで言ってたよねっていう風'},
#  {'start_time': 593.12, 'end_time': 595.63, 'text': 'にあの少しでも皆さんに裕介は日本人だ'},
#  {'start_time': 595.64, 'end_time': 598.19, 'text': 'よっていうのを広めてくれると嬉しいなと'},
#  {'start_time': 598.2, 'end_time': 601.87, 'text': '思います。はい。ま、話は戻りまして、'},
#  {'start_time': 601.88, 'end_time': 605.55, 'text': '出身地は埼玉県です。え、東京の北にある'},
#  {'start_time': 605.56, 'end_time': 607.83, 'text': 'ところですね。あの、ま、日本では東京の'},
#  {'start_time': 607.84, 'end_time': 611.43, 'text': 'ベッドタウン、ま、つまり東京で働いて'},
#  {'start_time': 611.44, 'end_time': 613.31, 'text': 'いる人の住む家がある町、ま、として有名'},
#  {'start_time': 613.32, 'end_time': 616.23, 'text': 'なところなんですけども、ま、そこで'},
#  {'start_time': 616.24, 'end_time': 620.75, 'text': '生まれ育ちました。ただですね、あの、'},
#  {'start_time': 620.76, 'end_time': 624.79, 'text': 'お父さんの会社の、え、都合上ね、え、'},
#  {'start_time': 624.8, 'end_time': 627.75, 'text': '色々なところを引っ越してとしてきた、ま'},
#  {'start_time': 627.76, 'end_time': 632.27, 'text': '、そういった経緯もあります。え、生まれ'},
#  {'start_time': 632.28, 'end_time': 634.79, 'text': 'てからすぐですね、どうも栃木県の小山市'},
#  {'start_time': 634.8, 'end_time': 637.67, 'text': 'っていうところに住んでいたそうです。で'},
#  {'start_time': 637.68, 'end_time': 640.67, 'text': '、なんかそこでね、色々ななんか問題が'},
#  {'start_time': 640.68, 'end_time': 646.83, 'text': 'あったらしくて、で、埼玉県に戻ってきて'},
#  {'start_time': 646.84, 'end_time': 651.11, 'text': '、で、そこから幼稚園、小学校までは埼玉'},
#  {'start_time': 651.12, 'end_time': 656.07, 'text': '県にいました。で、小学校6年生、自分が'},
#  {'start_time': 656.08, 'end_time': 658.99, 'text': '12歳の時だったかなに静岡県に引っ越す'},
#  {'start_time': 659.0, 'end_time': 662.79, 'text': 'ことになります。これもお父さんの仕事の'},
#  {'start_time': 662.8, 'end_time': 666.47, 'text': '都合だったんですね。で、えっと、中学校'},
#  {'start_time': 666.48, 'end_time': 670.59, 'text': '高校の時は6年間静岡県に住んでいました'},
#  {'start_time': 670.6, 'end_time': 673.83, 'text': '。で、高校を卒業して今度大学に行く。'},
#  {'start_time': 673.84, 'end_time': 675.71, 'text': '大学は東京にあったので、え、埼玉県のお'},
#  {'start_time': 675.72, 'end_time': 679.59, 'text': 'じいちゃんおばあちゃんの家に住んでいて'},
#  {'start_time': 679.6, 'end_time': 682.59, 'text': '、で、その後にメキシコに移住しました。'},
#  {'start_time': 682.6, 'end_time': 687.23, 'text': 'なので、えっと、メキシコに来たのが僕が'},
#  {'start_time': 687.24, 'end_time': 690.47, 'text': '22歳の時で、今僕が35歳、36歳かな'},
#  {'start_time': 690.48, 'end_time': 694.51, 'text': 'ので、ま、約13年間メキシコに住んでい'},
#  {'start_time': 694.52, 'end_time': 697.39, 'text': 'ます。僕の今住んでいるメキシコの町なん'},
#  {'start_time': 697.4, 'end_time': 700.31, 'text': 'ですけど、具アダラハ原。すごい難しい'},
#  {'start_time': 700.32, 'end_time': 703.39, 'text': '名前ですよね。僕も覚えるの苦労したん'},
#  {'start_time': 703.4, 'end_time': 706.19, 'text': 'ですが、グアダラハ原っていうところで、'},
#  {'start_time': 706.2, 'end_time': 709.63, 'text': 'え、メキシコの第2の都市として、ま、'},
#  {'start_time': 709.64, 'end_time': 713.43, 'text': '知られています。そうですね。すごく'},
#  {'start_time': 713.44, 'end_time': 717.03, 'text': '大きい街ではあるんですけども、その'},
#  {'start_time': 717.04, 'end_time': 720.31, 'text': 'ビジネスの町ではないので、雰囲気的には'},
#  {'start_time': 720.32, 'end_time': 723.75, 'text': 'ちょっと村というか、田舎みたいな雰囲気'},
#  {'start_time': 723.76, 'end_time': 726.83, 'text': 'がある。そういうなんか働いている人が'},
#  {'start_time': 726.84, 'end_time': 729.75, 'text': '毎日こう東京みたいにたくさん歩いていて'},
#  {'start_time': 729.76, 'end_time': 733.07, 'text': '、街のスピードがすごく早い、生活の'},
#  {'start_time': 733.08, 'end_time': 735.79, 'text': 'リズムがすごく早い、大変な街ではないっ'},
#  {'start_time': 735.8, 'end_time': 738.95, 'text': 'ていううん。そういったなんか不思議な'},
#  {'start_time': 738.96, 'end_time': 741.91, 'text': '大きな町なのにちょっと田舎の雰囲気が'},
#  {'start_time': 741.92, 'end_time': 745.31, 'text': 'ある不思議なところです。で、あの'},
#  {'start_time': 745.32, 'end_time': 747.87, 'text': 'グアダラハ原はとても古い町でその'},
#  {'start_time': 747.88, 'end_time': 750.67, 'text': 'メキシコっていう国は、え、スペインの'},
#  {'start_time': 750.68, 'end_time': 753.91, 'text': '植民地だった時代があるんですね。ていう'},
#  {'start_time': 753.92, 'end_time': 757.87, 'text': 'ことで、そういう大きな町の中心街は'},
#  {'start_time': 757.88, 'end_time': 761.79, 'text': 'ヨーロッパ風の建物がたくさんあります。'},
#  {'start_time': 761.8, 'end_time': 764.55, 'text': 'うん。なのでね、メキシコの中心街を歩い'},
#  {'start_time': 764.56, 'end_time': 767.91, 'text': 'ていると、あれ、僕は今ヨーロッパにいる'},
#  {'start_time': 767.92, 'end_time': 770.71, 'text': 'のかな?ていった錯覚に陥る。なんかそう'},
#  {'start_time': 770.72, 'end_time': 773.67, 'text': 'いう風にこうなんか間違えて理解して'},
#  {'start_time': 773.68, 'end_time': 777.67, 'text': 'しまう、錯覚に陥ってしまう、そういった'},
#  {'start_time': 777.68, 'end_time': 779.75, 'text': '綺麗な街並もあるところです。はい。ね、'},
#  {'start_time': 779.76, 'end_time': 782.87, 'text': 'あのメキシコのね、グアダラ原に住んで'},
#  {'start_time': 782.88, 'end_time': 786.51, 'text': 'いるんですけども、そののんびりした'},
#  {'start_time': 786.52, 'end_time': 789.47, 'text': '雰囲気でも大きい町、そして中心街は'},
#  {'start_time': 789.48, 'end_time': 791.91, 'text': 'ヨーロッパの街並があってすごく綺麗な'},
#  {'start_time': 791.92, 'end_time': 795.91, 'text': 'ところ。うん。ま、そういったいいところ'},
#  {'start_time': 795.92, 'end_time': 799.59, 'text': 'もあるんですが、僕がこの13年間ずっと'},
#  {'start_time': 799.6, 'end_time': 802.83, 'text': 'メキシコにいる、ま、生活し続けている'},
#  {'start_time': 802.84, 'end_time': 807.51, 'text': '理由の1つがですね、ま、大きな理由の1'},
#  {'start_time': 807.52, 'end_time': 811.95, 'text': 'つが天候です。天気なんですね。えっと、'},
#  {'start_time': 811.96, 'end_time': 814.91, 'text': 'この街っていうのはすごく天気がいい。'},
#  {'start_time': 814.92, 'end_time': 819.47, 'text': 'まあ、1年のうちほとんど晴れていて、'},
#  {'start_time': 819.48, 'end_time': 822.71, 'text': 'そして寒くなく暑くもなくっていうところ'},
#  {'start_time': 822.72, 'end_time': 826.27, 'text': 'なんですね。え、大体1年の平均気温が'},
#  {'start_time': 826.28, 'end_time': 830.59, 'text': '30°前後で、そして最低気温も大体'},
#  {'start_time': 830.6, 'end_time': 833.71, 'text': '10°前後になります。すごくね、この'},
#  {'start_time': 833.72, 'end_time': 837.87, 'text': '地理的に不思議なところにありまして、え'},
#  {'start_time': 837.88, 'end_time': 840.63, 'text': '、地球の井戸ですね。がこう丸であったら'},
#  {'start_time': 840.64, 'end_time': 843.79, 'text': 'どれくらいこう北なのか、どれくらい南な'},
#  {'start_time': 843.8, 'end_time': 846.23, 'text': 'のかっていうのを、え、何度で表すの?'},
#  {'start_time': 846.24, 'end_time': 850.35, 'text': 'これ井戸って言うんですけども、その井戸'},
#  {'start_time': 850.36, 'end_time': 853.35, 'text': 'が大体ハワイと同じなんですよ。ハワイっ'},
#  {'start_time': 853.36, 'end_time': 855.35, 'text': 'て言ったらね、とこ、1年中っていう'},
#  {'start_time': 855.36, 'end_time': 860.75, 'text': 'イメージがあるところだと思うんですけど'},
#  {'start_time': 860.76, 'end_time': 863.91, 'text': 'も、ハワイと同じ井戸なんですが、標高が'},
#  {'start_time': 863.92, 'end_time': 867.63, 'text': '高いところなんですね。大体標高が'},
#  {'start_time': 867.64, 'end_time': 870.15, 'text': '1800mぐらいあります。ああ、日本で'},
#  {'start_time': 870.16, 'end_time': 872.39, 'text': 'ね、1番高いところで行っても大体'},
#  {'start_time': 872.4, 'end_time': 875.67, 'text': '1000mぐらいですから、もうさらに上'},
#  {'start_time': 875.68, 'end_time': 878.19, 'text': 'ですね。え、皆さんの知っている富士山'},
#  {'start_time': 878.2, 'end_time': 880.71, 'text': 'ありますね。富士山のちょうど真ん中。'},
#  {'start_time': 880.72, 'end_time': 884.11, 'text': 'これを5号目って言います。えっと、'},
#  {'start_time': 884.12, 'end_time': 886.87, 'text': '富士山は1番上が10号で、1番下が1号'},
#  {'start_time': 886.88, 'end_time': 891.35, 'text': 'なんですが、その真ん中5号目と同じ'},
#  {'start_time': 891.36, 'end_time': 894.35, 'text': 'くらいの標です。なので、朝とか夜は'},
#  {'start_time': 894.36, 'end_time': 897.47, 'text': 'すごく涼しいなんだけども、太陽が出て'},
#  {'start_time': 897.48, 'end_time': 900.47, 'text': 'くると暑くなる。うん。ていうね、すごく'},
#  {'start_time': 900.48, 'end_time': 903.63, 'text': '不思議なところです。本当に1年中天気が'},
#  {'start_time': 903.64, 'end_time': 908.07, 'text': '良くて、あの、エアコンがいらないんです'},
#  {'start_time': 908.08, 'end_time': 910.47, 'text': 'よ。そう。ま、最近ね、気候変動ね、残念'},
#  {'start_time': 910.48, 'end_time': 913.67, 'text': 'なことに天気がすごく変わってきてしまっ'},
#  {'start_time': 913.68, 'end_time': 916.55, 'text': 'ていて、あの、昔みたいなその気候では'},
#  {'start_time': 916.56, 'end_time': 919.79, 'text': 'なくなってきてはいるんですが、それでも'},
#  {'start_time': 919.8, 'end_time': 923.75, 'text': '1年に1ヶ月だけ5月がすごく暑いんです'},
#  {'start_time': 923.76, 'end_time': 925.67, 'text': 'が、それ以外は冷房もいらない。え、今ね'},
#  {'start_time': 925.68, 'end_time': 930.63, 'text': '、え、このポッドキャストを撮っているの'},
#  {'start_time': 930.64, 'end_time': 932.55, 'text': 'は1月の、え、21日ですけども、ま、'},
#  {'start_time': 932.56, 'end_time': 934.63, 'text': 'この通り'},
#  {'start_time': 934.64, 'end_time': 936.67, 'text': '普通のこうトレーナーというかロングT'},
#  {'start_time': 936.68, 'end_time': 938.99, 'text': 'シャツを着ています。で、今この'},
#  {'start_time': 939.0, 'end_time': 943.35, 'text': 'ポッドキャストを撮っているのが、え、朝'},
#  {'start_time': 943.36, 'end_time': 947.71, 'text': 'の4時50分ということで、まあ1日で'},
#  {'start_time': 947.72, 'end_time': 951.35, 'text': '1番寒くなる時間帯、しかも1月なのに'},
#  {'start_time': 951.36, 'end_time': 954.55, 'text': 'こんな服装で全然寒くない。ちょうど'},
#  {'start_time': 954.56, 'end_time': 956.99, 'text': 'いいっていう本当に気候がいい。ま、そう'},
#  {'start_time': 957.0, 'end_time': 959.83, 'text': 'いったこともあって、ま、未だにメキシコ'},
#  {'start_time': 959.84, 'end_time': 962.55, 'text': 'のグアダラハ原に住み続けています。ま、'},
#  {'start_time': 962.56, 'end_time': 964.87, 'text': 'ここで、えー、ポドキャストを撮ったりと'},
#  {'start_time': 964.88, 'end_time': 968.23, 'text': 'かオンラインレッスンをやったりして生活'},
#  {'start_time': 968.24, 'end_time': 972.43, 'text': 'しているっていうのが、え、出身地の'},
#  {'start_time': 972.44, 'end_time': 977.19, 'text': 'テーマです。そして次なんですが家族です'},
#  {'start_time': 977.2, 'end_time': 981.15, 'text': 'ね。はい。え、僕の家族は4人家族です。'},
#  {'start_time': 981.16, 'end_time': 983.83, 'text': 'お父さん、お母さん、僕、そして弟が1人'},
#  {'start_time': 983.84, 'end_time': 986.75, 'text': 'います。はい。え、もうお父さんと'},
#  {'start_time': 986.76, 'end_time': 990.83, 'text': 'お母さんはもうお仕事が終わりまして丁年'},
#  {'start_time': 990.84, 'end_time': 992.67, 'text': '退職を迎えて、今その埼玉県の、え、昔お'},
#  {'start_time': 992.68, 'end_time': 996.67, 'text': 'じいちゃんが住んでいた実家に住んでい'},
#  {'start_time': 996.68, 'end_time': 999.27, 'text': 'ます。はい。で、えっと、ま、お父さん、'},
#  {'start_time': 999.28, 'end_time': 1002.71, 'text': 'お母さん、ま、弟がいるんですけども、ま'},
#  {'start_time': 1002.72, 'end_time': 1005.67, 'text': '、この家族のテーマについて何を話そうか'},
#  {'start_time': 1005.68, 'end_time': 1008.51, 'text': 'なと考えていました。ま、あんまりね、'},
#  {'start_time': 1008.52, 'end_time': 1011.71, 'text': '自分のこの家族、特にそのYouTube'},
#  {'start_time': 1011.72, 'end_time': 1015.11, 'text': 'とかSNSの活動をしていない家族につい'},
#  {'start_time': 1015.12, 'end_time': 1017.83, 'text': 'ていろんな情報を話すのはやっぱり心が'},
#  {'start_time': 1017.84, 'end_time': 1021.39, 'text': '引けるうん、なんかいいのかなっていう風'},
#  {'start_time': 1021.4, 'end_time': 1024.71, 'text': 'に思う部分もあるので、えっと、僕の家族'},
#  {'start_time': 1024.72, 'end_time': 1027.95, 'text': 'のすごいところを皆さんに自慢していき'},
#  {'start_time': 1027.96, 'end_time': 1031.23, 'text': 'たいと思います。はい。え、まずお父さん'},
#  {'start_time': 1031.24, 'end_time': 1034.07, 'text': 'なんですけども、え、今67歳です。なん'},
#  {'start_time': 1034.08, 'end_time': 1037.71, 'text': 'ですが、未だにサーフィンをやっています'},
#  {'start_time': 1037.72, 'end_time': 1041.55, 'text': '。すごいんですよ。はい。アスリートです'},
#  {'start_time': 1041.56, 'end_time': 1045.27, 'text': '。ま、67歳っていう年なんですけども、'},
#  {'start_time': 1045.28, 'end_time': 1048.87, 'text': 'すごいね、いい体というかはい。もう本当'},
#  {'start_time': 1048.88, 'end_time': 1052.11, 'text': 'にアスリートみたいな体で、あの、普通に'},
#  {'start_time': 1052.12, 'end_time': 1055.15, 'text': '、え、冬になっても寒い海にウエット'},
#  {'start_time': 1055.16, 'end_time': 1058.51, 'text': 'スーツを着て飛び込みサーフィンをやって'},
#  {'start_time': 1058.52, 'end_time': 1061.11, 'text': 'います。うん。ま、父さんと言ったらもう'},
#  {'start_time': 1061.12, 'end_time': 1065.35, 'text': 'サーフィンっていう、もうそれくらい僕が'},
#  {'start_time': 1065.36, 'end_time': 1068.15, 'text': 'もう生まれた頃からずっともう彼これ多分'},
#  {'start_time': 1068.16, 'end_time': 1071.71, 'text': '40年近くサーフィンをやり続けているの'},
#  {'start_time': 1071.72, 'end_time': 1074.99, 'text': 'かな。はい。ま、そういったサーフィン'},
#  {'start_time': 1075.0, 'end_time': 1077.71, 'text': 'パパです。ま、こう子供の頃からね、大人'},
#  {'start_time': 1077.72, 'end_time': 1080.15, 'text': 'になるまで、ま、いろんな方が、ま、僕の'},
#  {'start_time': 1080.16, 'end_time': 1083.31, 'text': 'お父さんとね、知り合いになるわけなん'},
#  {'start_time': 1083.32, 'end_time': 1085.03, 'text': 'ですけども、よ、よく友達にね、イエ裕介'},
#  {'start_time': 1085.04, 'end_time': 1089.23, 'text': 'のお父さんってかっこいいよね。'},
#  {'start_time': 1089.24, 'end_time': 1093.07, 'text': 'サーフィンできてすごいよね。ね、その、'},
#  {'start_time': 1093.08, 'end_time': 1095.95, 'text': 'ま、おじさんになってもすごいこう若者の'},
#  {'start_time': 1095.96, 'end_time': 1098.71, 'text': '体というかうん。すごいスマートな体で'},
#  {'start_time': 1098.72, 'end_time': 1101.03, 'text': 'すごいよねっていう風にあの言ってくれて'},
#  {'start_time': 1101.04, 'end_time': 1104.31, 'text': 'ね、ま、ちょっと自慢のお父さんでもあり'},
#  {'start_time': 1104.32, 'end_time': 1106.75, 'text': 'ます。はい。で、次はお母さんなんです'},
#  {'start_time': 1106.76, 'end_time': 1109.67, 'text': 'けども、お母さんは、えっと、ずっと昔'},
#  {'start_time': 1109.68, 'end_time': 1113.67, 'text': 'から、えっと、主婦です。うん。ただ、'},
#  {'start_time': 1113.68, 'end_time': 1115.63, 'text': 'あの、昔はですね、病院で働いていてうん'},
#  {'start_time': 1115.64, 'end_time': 1117.91, 'text': '。ま、すごい、なんて言うのかな、大切な'},
#  {'start_time': 1117.92, 'end_time': 1120.55, 'text': '仕事をしていたんですが、ま、僕が生まれ'},
#  {'start_time': 1120.56, 'end_time': 1125.07, 'text': 'てからずっと主婦で僕を育ててくれました'},
#  {'start_time': 1125.08, 'end_time': 1130.43, 'text': '。で、あの、お母さんのすごいところは'},
#  {'start_time': 1130.44, 'end_time': 1133.39, 'text': 'まず話し方と声がとても綺麗だと思うん'},
#  {'start_time': 1133.4, 'end_time': 1136.11, 'text': 'ですね。で、あの、ポドキャストを聞いて'},
#  {'start_time': 1136.12, 'end_time': 1138.43, 'text': 'くださっている方、そしてクラスに参加し'},
#  {'start_time': 1138.44, 'end_time': 1141.51, 'text': 'てくれる方ね、あとはYouTubeで'},
#  {'start_time': 1141.52, 'end_time': 1145.19, 'text': 'コラボしてくれた方、皆さんに言われるの'},
#  {'start_time': 1145.2, 'end_time': 1147.55, 'text': 'がゆさんってすごく声が綺麗ですよね。'},
#  {'start_time': 1147.56, 'end_time': 1150.27, 'text': '話している日本語がすごく聞きやすいです'},
#  {'start_time': 1150.28, 'end_time': 1153.51, 'text': 'よね。分かりやすいですよねっていっつも'},
#  {'start_time': 1153.52, 'end_time': 1156.31, 'text': '褒めてもらえるんですよ。で、それはなん'},
#  {'start_time': 1156.32, 'end_time': 1159.47, 'text': 'でかなっていうのを考えた時に、あ、多分'},
#  {'start_time': 1159.48, 'end_time': 1162.79, 'text': 'お母さんに声が似てるからなのかなって'},
#  {'start_time': 1162.8, 'end_time': 1164.87, 'text': '思います。うん。あの、ま、後でも話すん'},
#  {'start_time': 1164.88, 'end_time': 1167.15, 'text': 'ですが、僕の奥さん、メキシコ人の奥さん'},
#  {'start_time': 1167.16, 'end_time': 1169.03, 'text': '、メキシコ人の奥さんって言うと日本人の'},
#  {'start_time': 1169.04, 'end_time': 1171.03, 'text': '奥さんがいそうな感じがするけど、そんな'},
#  {'start_time': 1171.04, 'end_time': 1173.55, 'text': 'ことないですよ。そんなことない。僕の奥'},
#  {'start_time': 1173.56, 'end_time': 1176.07, 'text': 'さん、えっと、ニアさんが、あの、いつも'},
#  {'start_time': 1176.08, 'end_time': 1177.87, 'text': 'ね、楽しそうに、え、ブごめんなさい。'},
#  {'start_time': 1177.88, 'end_time': 1179.87, 'text': 'えっと、ニディアさんが、え、日本に行く'},
#  {'start_time': 1179.88, 'end_time': 1182.63, 'text': 'と僕のお母さんの楽しそうに会話をしてい'},
#  {'start_time': 1182.64, 'end_time': 1185.47, 'text': 'ます。で、きっと多分彼女にとっても聞き'},
#  {'start_time': 1185.48, 'end_time': 1188.11, 'text': 'やすい声なんじゃないかなと思うんです。'},
#  {'start_time': 1188.12, 'end_time': 1191.51, 'text': 'ま、そういった声を多分昔から聞いている'},
#  {'start_time': 1191.52, 'end_time': 1194.75, 'text': 'からなのか分からないですけども、あの、'},
#  {'start_time': 1194.76, 'end_time': 1199.27, 'text': 'こういうはっきりとした話し方っていうの'},
#  {'start_time': 1199.28, 'end_time': 1201.03, 'text': 'ができてるのかなと思います。うん。で、'},
#  {'start_time': 1201.04, 'end_time': 1205.39, 'text': 'えっと、次なんですけど、お母さんの'},
#  {'start_time': 1205.4, 'end_time': 1211.07, 'text': 'すごいところ、考え方なんですね。'},
#  {'start_time': 1211.08, 'end_time': 1215.67, 'text': '昔からその色々なこう観点から物が見'},
#  {'start_time': 1215.68, 'end_time': 1219.47, 'text': 'られる感じがするんですよ。あの、僕は'},
#  {'start_time': 1219.48, 'end_time': 1223.35, 'text': 'お母さんとディベートをして勝てる'},
#  {'start_time': 1223.36, 'end_time': 1225.83, 'text': 'イメージが湧きませんね。はい。本当に'},
#  {'start_time': 1225.84, 'end_time': 1228.83, 'text': 'いろんな角度から物が見れていて、ま、'},
#  {'start_time': 1228.84, 'end_time': 1232.67, 'text': '鋭いというかうん。ま、そうやってあなた'},
#  {'start_time': 1232.68, 'end_time': 1235.71, 'text': '言うけどこういうことよねみたいにあの別'},
#  {'start_time': 1235.72, 'end_time': 1238.39, 'text': '角度からこういろんなことを言われること'},
#  {'start_time': 1238.4, 'end_time': 1242.23, 'text': 'が多くてですね。その中でもよく覚えて'},
#  {'start_time': 1242.24, 'end_time': 1244.47, 'text': 'いるのが、え、先生についてなんです。え'},
#  {'start_time': 1244.48, 'end_time': 1248.43, 'text': '、ま、他のポドキャストでも撮ったことが'},
#  {'start_time': 1248.44, 'end_time': 1251.19, 'text': 'あるんですが、僕はその大学生の時にが'},
#  {'start_time': 1251.2, 'end_time': 1253.47, 'text': '日本の中学校高校の先生になるための、ま'},
#  {'start_time': 1253.48, 'end_time': 1256.51, 'text': '、ライセンスを取りたいっていう、ま、'},
#  {'start_time': 1256.52, 'end_time': 1258.67, 'text': 'そういった話を家族にしたんですね。で、'},
#  {'start_time': 1258.68, 'end_time': 1262.87, 'text': 'そこでそのお母さんに言われたのが、ま、'},
#  {'start_time': 1262.88, 'end_time': 1265.55, 'text': '私は先生っていう職業がすごく嫌いだって'},
#  {'start_time': 1265.56, 'end_time': 1269.35, 'text': 'いう。その当時'},
#  {'start_time': 1269.36, 'end_time': 1272.43, 'text': '僕にとって唯一よく知っている仕事って'},
#  {'start_time': 1272.44, 'end_time': 1275.31, 'text': 'いうのが学校の先生だったんですね。ま、'},
#  {'start_time': 1275.32, 'end_time': 1278.39, 'text': 'もちろんそうですよね。中学校、高校って'},
#  {'start_time': 1278.4, 'end_time': 1280.07, 'text': 'いう、ま、そういった環境で育っていく中'},
#  {'start_time': 1280.08, 'end_time': 1283.43, 'text': 'で、'},
#  {'start_time': 1283.44, 'end_time': 1286.03, 'text': 'ま、普通に会社員の方と関わる機会って'},
#  {'start_time': 1286.04, 'end_time': 1306.15, 'text': 'いうのはあんまりないですしね。'},
#  {'start_time': 1306.16, 'end_time': 1310.39, 'text': '子供って学校の先生に憧れと思うんですよ。'},
#  {'start_time': 1313.2, 'end_time': 1315.31, 'text': 'で、あの、ま、僕も、ま、色々経緯はある'},
#  {'start_time': 1315.32, 'end_time': 1318.71, 'text': 'んですけども、学校の先生になろうって'},
#  {'start_time': 1318.72, 'end_time': 1321.23, 'text': 'いうことで、あの、両親にね、話したん'},
#  {'start_time': 1321.24, 'end_time': 1323.91, 'text': 'です。で、そん時に、いや、僕、私は学校'},
#  {'start_time': 1323.92, 'end_time': 1327.79, 'text': 'の先生っていうのがすごく嫌いだと。だっ'},
#  {'start_time': 1327.8, 'end_time': 1330.71, 'text': 'て、その大人でありながらその子供に囲ま'},
#  {'start_time': 1330.72, 'end_time': 1334.83, 'text': 'れて生活するっていうのはどんなことをし'},
#  {'start_time': 1334.84, 'end_time': 1337.75, 'text': 'たとしてもリスペクトされる。そう。その'},
#  {'start_time': 1337.76, 'end_time': 1340.75, 'text': '表向きはね、実際先生がいないとこで先生'},
#  {'start_time': 1340.76, 'end_time': 1344.91, 'text': 'の悪口は言われるだろうけど、どんな仕事'},
#  {'start_time': 1344.92, 'end_time': 1349.51, 'text': 'をしても先生っていうだけで尊敬される'},
#  {'start_time': 1349.52, 'end_time': 1352.27, 'text': 'そんなところにいる人間が全刀な人間に'},
#  {'start_time': 1352.28, 'end_time': 1354.59, 'text': 'なるわけがないっていう風にあのお母さん'},
#  {'start_time': 1354.6, 'end_time': 1357.55, 'text': 'に言われてですね。ま、そうだよなと。'},
#  {'start_time': 1357.56, 'end_time': 1361.27, 'text': 'うん。で、あの、僕がね、その先生を目指'},
#  {'start_time': 1361.28, 'end_time': 1364.07, 'text': 'すってなった時にですね、あの、そうだと'},
#  {'start_time': 1364.08, 'end_time': 1366.91, 'text': 'すごいいい先生と出会えて、そういう先生'},
#  {'start_time': 1366.92, 'end_time': 1370.19, 'text': 'になりたいから学校の先生になるための'},
#  {'start_time': 1370.2, 'end_time': 1374.87, 'text': '勉強をするんだではなくて、あの、ま、中'},
#  {'start_time': 1374.88, 'end_time': 1376.87, 'text': '学校の時にね、すごく苦手で、ま、その辛'},
#  {'start_time': 1376.88, 'end_time': 1380.95, 'text': 'うん。ちょっと大変な先生がいたんですね'},
#  {'start_time': 1380.96, 'end_time': 1383.71, 'text': '。で、ま、その先生に、ま、いろんなこと'},
#  {'start_time': 1383.72, 'end_time': 1386.75, 'text': 'を、ま、されてって言うとちょっと言い方'},
#  {'start_time': 1386.76, 'end_time': 1389.39, 'text': 'があれなんですけども、あの、ちょ、苦い'},
#  {'start_time': 1389.4, 'end_time': 1392.79, 'text': '思い出があると。で、ま、是非ね、そう'},
#  {'start_time': 1392.8, 'end_time': 1397.59, 'text': 'いった経験をする子供が少なくなるように'},
#  {'start_time': 1397.6, 'end_time': 1399.47, 'text': 'ね、優しい大人としてその学校の先生に'},
#  {'start_time': 1399.48, 'end_time': 1402.99, 'text': 'なりたいんだっていう風に、ま、そういっ'},
#  {'start_time': 1403.0, 'end_time': 1404.95, 'text': 'た気持ちを持ってあの学校の先生を目指し'},
#  {'start_time': 1404.96, 'end_time': 1407.07, 'text': 'たわけなんですけども、ま、そのきっかけ'},
#  {'start_time': 1407.08, 'end_time': 1410.55, 'text': 'になったのはやっぱお母さんの一言ですね'},
#  {'start_time': 1410.56, 'end_time': 1413.59, 'text': '。ま、そういった1つのものをこう批判的'},
#  {'start_time': 1413.6, 'end_time': 1415.67, 'text': 'に見るっていうそういうま、ちょっと'},
#  {'start_time': 1415.68, 'end_time': 1418.03, 'text': 'ネガティブではあるとは思うんですけど、'},
#  {'start_time': 1418.04, 'end_time': 1420.95, 'text': 'でもすごく大切な考え方っていうのも'},
#  {'start_time': 1420.96, 'end_time': 1426.83, 'text': 'お母さんに教わりましたね。はい。で、次'},
#  {'start_time': 1426.84, 'end_time': 1429.55, 'text': 'は弟なんですけども、弟のすごいところ。'},
#  {'start_time': 1429.56, 'end_time': 1434.79, 'text': 'すごくおしゃれですね。なんか弟だけ'},
#  {'start_time': 1434.8, 'end_time': 1438.47, 'text': 'すごいあのね、すごい話す声が素晴らしい'},
#  {'start_time': 1438.48, 'end_time': 1441.83, 'text': 'とかね。サーフィンができて、そのね、'},
#  {'start_time': 1441.84, 'end_time': 1445.27, 'text': '未だに若い体うんとかっていうところから'},
#  {'start_time': 1445.28, 'end_time': 1447.43, 'text': 'おしゃれっていうあのすごく普通というか'},
#  {'start_time': 1447.44, 'end_time': 1449.71, 'text': '、あの、そういうすごいところになっ'},
#  {'start_time': 1449.72, 'end_time': 1453.95, 'text': 'ちゃってるとは思うんですけども、すごく'},
#  {'start_time': 1453.96, 'end_time': 1457.51, 'text': 'おしゃれなんですよ。うん。それはその'},
#  {'start_time': 1457.52, 'end_time': 1459.99, 'text': '家族で1人の人間として、ま、兄として'},
#  {'start_time': 1460.0, 'end_time': 1464.23, 'text': 'すごい憧れてる、リスペクトしている部分'},
#  {'start_time': 1464.24, 'end_time': 1466.07, 'text': 'です。うん。あの、僕自身があんまり'},
#  {'start_time': 1466.08, 'end_time': 1468.35, 'text': 'おしゃれじゃないんですね。ファッション'},
#  {'start_time': 1468.36, 'end_time': 1470.83, 'text': 'センスがないんですよ。なんか変なT'},
#  {'start_time': 1470.84, 'end_time': 1474.27, 'text': 'シャツを買ってしまったりとか、体に合わ'},
#  {'start_time': 1474.28, 'end_time': 1479.83, 'text': 'ない服っていうのをあの、買ってしまっ'},
#  {'start_time': 1479.84, 'end_time': 1481.99, 'text': 'たりとかうん。なんですけど、その弟は'},
#  {'start_time': 1482.0, 'end_time': 1484.59, 'text': 'すごいね、自分のスタイルっていうのを'},
#  {'start_time': 1484.6, 'end_time': 1488.87, 'text': 'ちゃんと持っていて、その自分のスタイル'},
#  {'start_time': 1488.88, 'end_time': 1491.31, 'text': 'にあった服をちゃんと選べる人で、あの、'},
#  {'start_time': 1491.32, 'end_time': 1493.91, 'text': 'ま、そういったファッションのセンスがい'},
#  {'start_time': 1493.92, 'end_time': 1496.23, 'text': 'いっていうのを生かして、ま、それに関係'},
#  {'start_time': 1496.24, 'end_time': 1499.71, 'text': 'しているお仕事をしているんですけども、'},
#  {'start_time': 1499.72, 'end_time': 1501.87, 'text': 'そういったその自分の好きなことをお仕事'},
#  {'start_time': 1501.88, 'end_time': 1504.35, 'text': 'にできているっていうのもすごく'},
#  {'start_time': 1504.36, 'end_time': 1506.23, 'text': 'リスペクトしています。うん。この'},
#  {'start_time': 1506.24, 'end_time': 1508.59, 'text': 'ファッションセンスは本当に助かっていて'},
#  {'start_time': 1508.6, 'end_time': 1512.31, 'text': '、あの、こういったね、今僕が着ている'},
#  {'start_time': 1512.32, 'end_time': 1515.35, 'text': 'ものも弟からもらったりとか、あと弟が'},
#  {'start_time': 1515.36, 'end_time': 1518.35, 'text': '選んでくれたりとかしてます。はい。あの'},
#  {'start_time': 1518.36, 'end_time': 1520.95, 'text': '、そう、そう、そう、そう。最近ね、ゆ'},
#  {'start_time': 1520.96, 'end_time': 1522.71, 'text': 'さん着てる服いいなとかすごいあの、'},
#  {'start_time': 1522.72, 'end_time': 1524.91, 'text': 'おしゃれだと思いますっていうコメントも'},
#  {'start_time': 1524.92, 'end_time': 1527.75, 'text': '頂いているんですが、もうそれはもう僕の'},
#  {'start_time': 1527.76, 'end_time': 1530.79, 'text': 'センスではなく、弟が選んでくれてるから'},
#  {'start_time': 1530.8, 'end_time': 1533.47, 'text': '、あの、かっこいい服が着られて'},
#  {'start_time': 1533.48, 'end_time': 1537.35, 'text': 'るっていうだけですね。はい。ね。すごい'},
#  {'start_time': 1537.36, 'end_time': 1541.43, 'text': 'ですよね。ファッションおしゃれな人って'},
#  {'start_time': 1541.44, 'end_time': 1544.55, 'text': '何でしょうね。その話す時にこういうこと'},
#  {'start_time': 1544.56, 'end_time': 1546.63, 'text': 'を話せば面白いんじゃないかっていうのが'},
#  {'start_time': 1546.64, 'end_time': 1550.11, 'text': '分かるっていうスキルに似ていると思うん'},
#  {'start_time': 1550.12, 'end_time': 1554.19, 'text': 'ですよ。こういう服を着ると自分の身長と'},
#  {'start_time': 1554.2, 'end_time': 1557.11, 'text': 'か顔の形とかその紙の雰囲気とかその歩き'},
#  {'start_time': 1557.12, 'end_time': 1559.59, 'text': '方とか立ち方っていうのにマッチするん'},
#  {'start_time': 1559.6, 'end_time': 1564.19, 'text': 'じゃないかなっていうのをこう感覚的に'},
#  {'start_time': 1564.2, 'end_time': 1566.39, 'text': 'わかるっていうのは多分本当に普段その'},
#  {'start_time': 1566.4, 'end_time': 1569.15, 'text': 'ファッションとか服について考えてないと'},
#  {'start_time': 1569.16, 'end_time': 1572.63, 'text': 'できないと思うんですね。ま、僕はその'},
#  {'start_time': 1572.64, 'end_time': 1574.95, 'text': '話すことしか取り絵がないので、あの、'},
#  {'start_time': 1574.96, 'end_time': 1577.59, 'text': '話すことについて普段よく考えているん'},
#  {'start_time': 1577.6, 'end_time': 1579.95, 'text': 'ですけども、ま、だからこそできる。多分'},
#  {'start_time': 1579.96, 'end_time': 1584.35, 'text': '弟はその服についてよく考えてい'},
#  {'start_time': 1584.36, 'end_time': 1586.95, 'text': 'るっていうことですごくね、おしゃれな弟'},
#  {'start_time': 1586.96, 'end_time': 1590.43, 'text': 'かっこいいな、すごいなって思ってます。'},
#  {'start_time': 1590.44, 'end_time': 1595.39, 'text': 'はい。ていうのが、ま、僕の家族の、えー'},
#  {'start_time': 1595.4, 'end_time': 1600.99, 'text': '、すごいところです。そしてもう家族を'},
#  {'start_time': 1601.0, 'end_time': 1603.31, 'text': '語る上でね、1番大切な家族、僕の奥さん'},
#  {'start_time': 1603.32, 'end_time': 1606.27, 'text': 'ですね、ニディアさんについて話していき'},
#  {'start_time': 1606.28, 'end_time': 1608.79, 'text': 'たいと思います。はい。あの、たまにね、'},
#  {'start_time': 1608.8, 'end_time': 1610.63, 'text': 'YouTubeのコメントでゆさんは結婚'},
#  {'start_time': 1610.64, 'end_time': 1613.23, 'text': 'してるんですかっていう話、あの、'},
#  {'start_time': 1613.24, 'end_time': 1616.35, 'text': 'コメントをいただくんですがはい。'},
#  {'start_time': 1616.36, 'end_time': 1618.83, 'text': 'てレんてレ結婚しています。結婚指輪も'},
#  {'start_time': 1618.84, 'end_time': 1622.39, 'text': 'つけてます。はい。えっと、ニディアさん'},
#  {'start_time': 1622.4, 'end_time': 1625.75, 'text': 'は、え、メキシコ人の女性で、え、僕と'},
#  {'start_time': 1625.76, 'end_time': 1627.75, 'text': 'ほぼ同い年です。これ言って良かったのか'},
#  {'start_time': 1627.76, 'end_time': 1631.55, 'text': 'な?言っていいと思う。はい。そう、ほぼ'},
#  {'start_time': 1631.56, 'end_time': 1634.91, 'text': '同い年。同級生です。え、僕が1989年'},
#  {'start_time': 1634.92, 'end_time': 1637.23, 'text': 'に生まれて、ニディアさんも1989年に'},
#  {'start_time': 1637.24, 'end_time': 1640.07, 'text': '生まれました。えっと、僕が10月に'},
#  {'start_time': 1640.08, 'end_time': 1644.35, 'text': '生まれて、ニディアさんが2月に生まれて'},
#  {'start_time': 1644.36, 'end_time': 1646.95, 'text': 'いるので、もし同じ日本の学校に通ってい'},
#  {'start_time': 1646.96, 'end_time': 1650.95, 'text': 'たらニディアさんは先輩になりますね。ま'},
#  {'start_time': 1650.96, 'end_time': 1655.15, 'text': '、ただ同い年です。うん。で、えっと、今'},
#  {'start_time': 1655.16, 'end_time': 1657.03, 'text': 'は僕とあの一緒に働いていてオンライン'},
#  {'start_time': 1657.04, 'end_time': 1660.47, 'text': 'スクールのレッスンをしてもらったりとか'},
#  {'start_time': 1660.48, 'end_time': 1663.11, 'text': '、あと会社運営ですね。その会社を続け'},
#  {'start_time': 1663.12, 'end_time': 1666.23, 'text': 'いるために必要な手続きとかっていうのを'},
#  {'start_time': 1666.24, 'end_time': 1669.35, 'text': '手伝ってくれています。うん。そうですね'},
#  {'start_time': 1669.36, 'end_time': 1671.75, 'text': '。ニディアさんとの出会い。ま、ここら辺'},
#  {'start_time': 1671.76, 'end_time': 1674.19, 'text': 'はね、もう避けては通れないと思うんです'},
#  {'start_time': 1674.2, 'end_time': 1677.27, 'text': 'けども、え、ニディアさんとはメキシコで'},
#  {'start_time': 1677.28, 'end_time': 1680.31, 'text': '出会いました。で、えっと、以前働いてい'},
#  {'start_time': 1680.32, 'end_time': 1683.75, 'text': 'た日本語学校で出会ったんですね。ま、'},
#  {'start_time': 1683.76, 'end_time': 1685.67, 'text': 'これを言うとですね、結構裕介はダメな'},
#  {'start_time': 1685.68, 'end_time': 1688.67, 'text': '先生だって言われるので、あんまり言い'},
#  {'start_time': 1688.68, 'end_time': 1692.39, 'text': 'たくはないんですけども。はい。え、13'},
#  {'start_time': 1692.4, 'end_time': 1695.23, 'text': '年前、22歳の時ですね。え、グアラ原に'},
#  {'start_time': 1695.24, 'end_time': 1699.35, 'text': 'ある、ある日本語学校に務めていました。'},
#  {'start_time': 1699.36, 'end_time': 1703.23, 'text': 'で、えっと、そこで、え、ま、いろんな'},
#  {'start_time': 1703.24, 'end_time': 1705.67, 'text': '学生と出会ったんですけども、あの、ま、'},
#  {'start_time': 1705.68, 'end_time': 1711.03, 'text': 'その中でその出会った1人がニディアさん'},
#  {'start_time': 1711.04, 'end_time': 1714.07, 'text': 'だったんですね。で、えっと、当時僕は'},
#  {'start_time': 1714.08, 'end_time': 1717.87, 'text': 'ニディアさんのクラスを教えていたわけで'},
#  {'start_time': 1717.88, 'end_time': 1720.95, 'text': 'はなく、あの、全然違うクラスの、ま、'},
#  {'start_time': 1720.96, 'end_time': 1725.59, 'text': '担当だったんですよ。ただ、ま、その日本'},
#  {'start_time': 1725.6, 'end_time': 1728.11, 'text': '語学校に日本から新しい若い男の先生と女'},
#  {'start_time': 1728.12, 'end_time': 1730.71, 'text': 'の先生が来るっていうことで、ま、'},
#  {'start_time': 1730.72, 'end_time': 1734.63, 'text': 'いろんな学生がですね、そのありがたい'},
#  {'start_time': 1734.64, 'end_time': 1738.35, 'text': 'ことにね、裕介、今日晩御飯食べ行こうよ'},
#  {'start_time': 1738.36, 'end_time': 1739.99, 'text': 'とか飲み行こうよっていつもこう誘って、'},
#  {'start_time': 1740.0, 'end_time': 1742.99, 'text': 'あの、ま、誘ってもらったんですね、そう'},
#  {'start_time': 1743.0, 'end_time': 1746.75, 'text': 'いう学生たちに。うん。っていうのもその'},
#  {'start_time': 1746.76, 'end_time': 1748.83, 'text': '、ま、僕自身ね、このポッドキャストでも'},
#  {'start_time': 1748.84, 'end_time': 1751.51, 'text': '何度も言っているんですけども、'},
#  {'start_time': 1751.52, 'end_time': 1753.95, 'text': 'めちゃくちゃ貧乏だったんですよ。そう。'},
#  {'start_time': 1753.96, 'end_time': 1757.23, 'text': 'あの、日本語学校の給料があんまり高く'},
#  {'start_time': 1757.24, 'end_time': 1759.71, 'text': 'なくて、すごい大変な思いをしたわけなん'},
#  {'start_time': 1759.72, 'end_time': 1762.27, 'text': 'ですけども、その時にですね、うん、誘っ'},
#  {'start_time': 1762.28, 'end_time': 1765.79, 'text': 'てくれた、え、1人がニディアさんでした'},
#  {'start_time': 1765.8, 'end_time': 1768.99, 'text': '。ま、ニディアさんにあのなんて言うのか'},
#  {'start_time': 1769.0, 'end_time': 1771.03, 'text': 'な、直接差し1対1で誘われていたわけで'},
#  {'start_time': 1771.04, 'end_time': 1774.19, 'text': 'はなくて、え、ニディアさんとニディア'},
#  {'start_time': 1774.2, 'end_time': 1776.39, 'text': 'さんのお友達、その当時はあと23人他の'},
#  {'start_time': 1776.4, 'end_time': 1779.67, 'text': '人もいたんですが、そのグループの人たち'},
#  {'start_time': 1779.68, 'end_time': 1783.03, 'text': 'にね、裕介飲みに行こうよっていう風に'},
#  {'start_time': 1783.04, 'end_time': 1785.99, 'text': '誘ってもらって、で、ま、そこであの色々'},
#  {'start_time': 1786.0, 'end_time': 1789.99, 'text': 'こう話していく中でだんだん仲良くなって'},
#  {'start_time': 1790.0, 'end_time': 1794.95, 'text': '、で、あの、そのニディアさんとニディア'},
#  {'start_time': 1794.96, 'end_time': 1797.95, 'text': 'さんのお友達2人と僕と4人であの'},
#  {'start_time': 1797.96, 'end_time': 1801.67, 'text': 'メキシコのある町に旅行に行ったんですね'},
#  {'start_time': 1801.68, 'end_time': 1804.47, 'text': '。で、ま、旅行に行った時に、え、ま、'},
#  {'start_time': 1804.48, 'end_time': 1807.31, 'text': '色々ありまして、あの、付き合うことに'},
#  {'start_time': 1807.32, 'end_time': 1812.39, 'text': 'なりました。うん。で、ま、そっから約'},
#  {'start_time': 1812.4, 'end_time': 1816.15, 'text': '13年ずっとあの一緒にいまして、で、'},
#  {'start_time': 1816.16, 'end_time': 1822.19, 'text': '付き合い始めてから3年目で、え、結婚を'},
#  {'start_time': 1822.2, 'end_time': 1824.67, 'text': 'して、で、今年かな?来年かな?あれ'},
#  {'start_time': 1824.68, 'end_time': 1828.27, 'text': 'どっちだったっけ?今年だと思います。え'},
#  {'start_time': 1828.28, 'end_time': 1830.59, 'text': '、今年結婚10周年を迎えます。うん。'},
#  {'start_time': 1830.6, 'end_time': 1834.35, 'text': 'っていうことでね、ま、大切なパートナー'},
#  {'start_time': 1834.36, 'end_time': 1839.47, 'text': 'です。で、あの、ニアさんのいいところ、'},
#  {'start_time': 1839.48, 'end_time': 1841.87, 'text': 'すごいところていうのは、あの、笑って'},
#  {'start_time': 1841.88, 'end_time': 1845.43, 'text': 'くれる、'},
#  {'start_time': 1845.44, 'end_time': 1848.87, 'text': '笑ってくれる、笑顔でいてくれるっていう'},
#  {'start_time': 1848.88, 'end_time': 1852.63, 'text': 'のと、あの、すごく優しい人だと思います'},
#  {'start_time': 1852.64, 'end_time': 1855.15, 'text': '。うん。あの、もちろんその結婚するか'},
#  {'start_time': 1855.16, 'end_time': 1857.43, 'text': '結婚しないかっていうのは、あの、こう、'},
#  {'start_time': 1857.44, 'end_time': 1859.75, 'text': 'ま、昔からね、付き合ってた時から考えて'},
#  {'start_time': 1859.76, 'end_time': 1864.23, 'text': 'はいたんですけども、ま、どのタイミング'},
#  {'start_time': 1864.24, 'end_time': 1867.35, 'text': 'であの、あ、この人と一緒にいたいな、'},
#  {'start_time': 1867.36, 'end_time': 1870.83, 'text': '結婚したいなっていう風に思ったかって'},
#  {'start_time': 1870.84, 'end_time': 1873.67, 'text': '言うとですね、えー、もう今から何年前だ'},
#  {'start_time': 1873.68, 'end_time': 1876.91, 'text': '、もうほとん、もう10年以上前になると'},
#  {'start_time': 1876.92, 'end_time': 1879.75, 'text': '思います。え、'},
#  {'start_time': 1879.76, 'end_time': 1882.47, 'text': 'お父さんのですね、お母さんだ、僕のお'},
#  {'start_time': 1882.48, 'end_time': 1885.27, 'text': 'ばあちゃんが、えっと、僕らが日本に遊び'},
#  {'start_time': 1885.28, 'end_time': 1888.95, 'text': 'に行っていた時に、ま、亡くなってしまっ'},
#  {'start_time': 1888.96, 'end_time': 1892.83, 'text': 'たんですね。で、えっと、ま、すごい'},
#  {'start_time': 1892.84, 'end_time': 1895.51, 'text': '悲しい経験ではあったんですけども、で、'},
#  {'start_time': 1895.52, 'end_time': 1898.31, 'text': '亡くなってしまった。で、その日に、えっ'},
#  {'start_time': 1898.32, 'end_time': 1901.27, 'text': 'と、僕の母方のおじいちゃんおばあちゃん'},
#  {'start_time': 1901.28, 'end_time': 1905.55, 'text': 'の家に、ま、お父さんとニディアさんと僕'},
#  {'start_time': 1905.56, 'end_time': 1910.07, 'text': 'で帰ってきて、で、あの、お父さんが静か'},
#  {'start_time': 1910.08, 'end_time': 1912.23, 'text': 'に晩御飯を食べていたんです。で、あの、'},
#  {'start_time': 1912.24, 'end_time': 1914.55, 'text': '不思議とね、こう、落ち着いた雰囲気で'},
#  {'start_time': 1914.56, 'end_time': 1917.99, 'text': 'ご飯を食べていて、ああ、やっぱ大人って'},
#  {'start_time': 1918.0, 'end_time': 1920.79, 'text': 'すげえなね。自分の両、お母さんが'},
#  {'start_time': 1920.8, 'end_time': 1923.11, 'text': '亡くなったとしても、やっぱりこう自分の'},
#  {'start_time': 1923.12, 'end_time': 1926.15, 'text': '気持ちをコントロールできるんだなって'},
#  {'start_time': 1926.16, 'end_time': 1928.83, 'text': 'いう風にね。あの、思ってたんですよ。で'},
#  {'start_time': 1928.84, 'end_time': 1931.15, 'text': '、そしたらニリアさんがちょっとお父さん'},
#  {'start_time': 1931.16, 'end_time': 1933.99, 'text': 'すごくかわいそうだからハグをしてあげて'},
#  {'start_time': 1934.0, 'end_time': 1937.23, 'text': 'もいいかしら?って、ま、僕にね、尋ねて'},
#  {'start_time': 1937.24, 'end_time': 1939.15, 'text': 'きて、で、ま、日本人はそんなハグをし'},
#  {'start_time': 1939.16, 'end_time': 1942.07, 'text': 'ない、ま、ハグをしない文化ではあるん'},
#  {'start_time': 1942.08, 'end_time': 1946.51, 'text': 'ですけども、そのメキシコではですね、'},
#  {'start_time': 1946.52, 'end_time': 1949.11, 'text': 'その悲しい人がいた時にその悲しい人のね'},
#  {'start_time': 1949.12, 'end_time': 1950.71, 'text': '、辛さとか痛みっていうのが少しでも'},
#  {'start_time': 1950.72, 'end_time': 1952.51, 'text': '柔らぐ'},
#  {'start_time': 1952.52, 'end_time': 1954.87, 'text': 'してあげる。ま、そういう文化があるから'},
#  {'start_time': 1954.88, 'end_time': 1957.67, 'text': '私はしてあげたい。っていう風にね、言っ'},
#  {'start_time': 1957.68, 'end_time': 1959.71, 'text': 'てくれて、で、ま、もちろんいいよってね'},
#  {'start_time': 1959.72, 'end_time': 1961.83, 'text': '、どうぞっていう風に言って、で、'},
#  {'start_time': 1961.84, 'end_time': 1964.55, 'text': 'ニディアさんがお父さんにね、大丈夫って'},
#  {'start_time': 1964.56, 'end_time': 1967.43, 'text': 'こうハグをしてあげたんですね。そしたら'},
#  {'start_time': 1967.44, 'end_time': 1970.43, 'text': 'お父さんが急にボロっ泣き始めて、'},
#  {'start_time': 1970.44, 'end_time': 1973.07, 'text': 'うわーって泣き始めて、ああ、すごいこう'},
#  {'start_time': 1973.08, 'end_time': 1976.51, 'text': '我慢してたんだな。そういったその'},
#  {'start_time': 1976.52, 'end_time': 1981.43, 'text': 'お父さん僕の気づかなかったその人の辛さ'},
#  {'start_time': 1981.44, 'end_time': 1985.91, 'text': 'とかっていうのをその見るのが感じるのが'},
#  {'start_time': 1985.92, 'end_time': 1988.87, 'text': 'すごくできる方だな、素敵な方だなと思っ'},
#  {'start_time': 1988.88, 'end_time': 1992.11, 'text': 'て、あ、結婚したいなっていう風に思い'},
#  {'start_time': 1992.12, 'end_time': 1995.47, 'text': 'ました。で、ま、結婚生活色々あります'},
#  {'start_time': 1995.48, 'end_time': 1998.47, 'text': 'けども、いつも笑っていてくれるっていう'},
#  {'start_time': 1998.48, 'end_time': 2001.43, 'text': 'のは本当に助かってます。あの、ま、僕'},
#  {'start_time': 2001.44, 'end_time': 2003.87, 'text': '自身もね、そんなに冗談が得意な人間では'},
#  {'start_time': 2003.88, 'end_time': 2006.79, 'text': 'ないんですけども、つまらない冗談でも'},
#  {'start_time': 2006.8, 'end_time': 2009.59, 'text': '笑ってくれたりとかはい。いつもこう家の'},
#  {'start_time': 2009.6, 'end_time': 2011.31, 'text': '中では笑い声が聞こえている。うん。そう'},
#  {'start_time': 2011.32, 'end_time': 2013.67, 'text': 'いう風にこういつも笑ってくれるニディア'},
#  {'start_time': 2013.68, 'end_time': 2016.39, 'text': 'さんがいるからこそ、ま、こういったね、'},
#  {'start_time': 2016.4, 'end_time': 2019.51, 'text': 'こうずっと家でする仕事であったとしても'},
# ...
#  {'start_time': 2516.28, 'end_time': 2519.15, 'text': 'うん。ま、それはこうSNSで見てパーっ'},
#  {'start_time': 2519.16, 'end_time': 2524.51, 'text': 'てこう、え、そうなんだではなく自分の頭'},
#  {'start_time': 2524.52, 'end_time': 2526.83, 'text': 'の中でね、え、例えば日本語を上手になる'},
#  {'start_time': 2526.84, 'end_time': 2528.83, 'text': 'までには、ま、どういったアシストが'},
#  {'start_time': 2528.84, 'end_time': 2531.03, 'text': 'できるんだろうとか、どういった勉強が'},
#  {'start_time': 2531.04, 'end_time': 2533.63, 'text': 'いいんだろうっていうところからとか、'},
#  {'start_time': 2533.64, 'end_time': 2536.15, 'text': 'そのなんで人間は楽しいって感じるん'},
#  {'start_time': 2536.16, 'end_time': 2538.47, 'text': 'だろう。楽しいって何なんだろう。他の'},
#  {'start_time': 2538.48, 'end_time': 2540.79, 'text': '言葉で説明するんだったらどういう言葉が'},
#  {'start_time': 2540.8, 'end_time': 2542.71, 'text': '使えるんだろう?最近どんなこと楽しかっ'},
#  {'start_time': 2542.72, 'end_time': 2546.39, 'text': 'ただろう?みたいなのをずっと考えてます'},
#  {'start_time': 2546.4, 'end_time': 2548.67, 'text': '。はい。ま、ていうのがう、なんか特技な'},
#  {'start_time': 2548.68, 'end_time': 2552.03, 'text': 'のかどうかは分からないですけども、ま、'},
#  {'start_time': 2552.04, 'end_time': 2557.51, 'text': '自分ができることなんじゃないかなと思い'},
#  {'start_time': 2559.8, 'end_time': 2563.99, 'text': 'ないね。'},
#  {'start_time': 2564.0, 'end_time': 2569.11, 'text': 'そう、今僕趣味って胸を張って言えるもの'},
#  {'start_time': 2569.12, 'end_time': 2571.63, 'text': 'がないんですよ。難しい話。ただこのU'},
#  {'start_time': 2571.64, 'end_time': 2576.15, 'text': '日本語とかUの日本語ポッドキャストを'},
#  {'start_time': 2576.16, 'end_time': 2579.07, 'text': '始まる始める前は本当に多趣味趣味があり'},
#  {'start_time': 2579.08, 'end_time': 2583.03, 'text': 'ました。例えば、え、イラストを書く、'},
#  {'start_time': 2583.04, 'end_time': 2585.83, 'text': 'アニメのイラストを書くとか、あとは、え'},
#  {'start_time': 2585.84, 'end_time': 2588.75, 'text': '、自転車ですね。ロードバイクに乗って'},
#  {'start_time': 2588.76, 'end_time': 2590.31, 'text': 'いろんなとこに行くね。ロードバイク早く'},
#  {'start_time': 2590.32, 'end_time': 2592.27, 'text': '走るためのトレーニングをするって'},
#  {'start_time': 2592.28, 'end_time': 2595.63, 'text': 'いうのも好きだった時期もあるし、ま、'},
#  {'start_time': 2595.64, 'end_time': 2598.59, 'text': 'ギターを引いていた時期もあるし、あとは'},
#  {'start_time': 2598.6, 'end_time': 2603.07, 'text': '何をやってましたかね。うーん、'},
#  {'start_time': 2603.08, 'end_time': 2605.67, 'text': 'バスケットとかを友達とやってね、上手に'},
#  {'start_time': 2605.68, 'end_time': 2607.91, 'text': 'なるために練習していた時期もあるして'},
#  {'start_time': 2607.92, 'end_time': 2610.63, 'text': 'いうことで本当にいろんな趣味があったん'},
#  {'start_time': 2610.64, 'end_time': 2613.07, 'text': 'ですけども、あと釣りだ。釣り釣り釣りも'},
#  {'start_time': 2613.08, 'end_time': 2614.91, 'text': '趣味だった時期があります。まあ、なん'},
#  {'start_time': 2614.92, 'end_time': 2617.75, 'text': 'ですけども、ま、こういう仕事をしている'},
#  {'start_time': 2617.76, 'end_time': 2620.99, 'text': 'とね、ま、常にその仕事のことについて'},
#  {'start_time': 2621.0, 'end_time': 2624.35, 'text': '考えなければならないし、もう仕事のこと'},
#  {'start_time': 2624.36, 'end_time': 2626.51, 'text': 'ばかりになってしまう。ま、でもそのこう'},
#  {'start_time': 2626.52, 'end_time': 2629.39, 'text': 'いうポッドキャストだったりとかその色々'},
#  {'start_time': 2629.4, 'end_time': 2632.35, 'text': 'な仕事をやってく中でもう趣味に近いもの'},
#  {'start_time': 2632.36, 'end_time': 2635.39, 'text': 'になってきているので、その'},
#  {'start_time': 2635.4, 'end_time': 2638.59, 'text': 'そういったね、全然全く違った自分の仕事'},
#  {'start_time': 2638.6, 'end_time': 2641.87, 'text': 'とは関係ない趣味っていうのはないかなと'},
#  {'start_time': 2641.88, 'end_time': 2646.67, 'text': '思います。はい。じゃ、次です。苦手な'},
#  {'start_time': 2646.68, 'end_time': 2649.31, 'text': 'こと。です。えっと、苦手なことは'},
#  {'start_time': 2649.32, 'end_time': 2654.55, 'text': '人付き合いです。'},
#  {'start_time': 2654.56, 'end_time': 2658.19, 'text': '人と付き合うのがあんまり得意ではないか'},
#  {'start_time': 2658.2, 'end_time': 2660.23, 'text': 'なと思います。えって思うじゃん。こう'},
#  {'start_time': 2660.24, 'end_time': 2663.79, 'text': 'やってポッドキャスト聞いてたらさ、ゆ'},
#  {'start_time': 2663.8, 'end_time': 2666.11, 'text': 'さん明るくて話すのが上手で自分で上手'},
#  {'start_time': 2666.12, 'end_time': 2669.79, 'text': 'って言うなやって思いますけども、話すの'},
#  {'start_time': 2669.8, 'end_time': 2672.19, 'text': 'が上手でね、会話レッスンやってて、'},
#  {'start_time': 2672.2, 'end_time': 2675.23, 'text': 'Instagram見るといろんな学生と'},
#  {'start_time': 2675.24, 'end_time': 2678.35, 'text': '楽しそうにしてるしっていうのでね、上手'},
#  {'start_time': 2678.36, 'end_time': 2682.03, 'text': 'じゃんって思うかもしれないけども苦手で'},
#  {'start_time': 2682.04, 'end_time': 2684.31, 'text': 'はある。うん。そう。ま、やっぱり'},
#  {'start_time': 2684.32, 'end_time': 2687.63, 'text': 'ソーシャルバッテリーがかなり少なめな'},
#  {'start_time': 2687.64, 'end_time': 2690.23, 'text': '人間ではあると思います。ま、こう言うと'},
#  {'start_time': 2690.24, 'end_time': 2692.15, 'text': 'そのじゃあ学生とね、一緒に遊びに行くの'},
#  {'start_time': 2692.16, 'end_time': 2696.03, 'text': 'が嫌なのっていう全くそういうことでは'},
#  {'start_time': 2696.04, 'end_time': 2699.67, 'text': 'ないんだけども、そのなんだろうな、友達'},
#  {'start_time': 2699.68, 'end_time': 2703.19, 'text': 'と遊びに行くと、え、友達と遊びに行っ'},
#  {'start_time': 2703.2, 'end_time': 2706.27, 'text': 'たりとか、ま、誰かと出かけたりとかする'},
#  {'start_time': 2706.28, 'end_time': 2708.43, 'text': 'とか、パーティーに参加する時に自分は'},
#  {'start_time': 2708.44, 'end_time': 2711.43, 'text': '間違ってないだろうかっていうのをすごく'},
#  {'start_time': 2711.44, 'end_time': 2715.71, 'text': '気にするんですよ。変なこと言ってないか'},
#  {'start_time': 2715.72, 'end_time': 2722.35, 'text': 'なとか、嫌な気持ちになってないかなとか'},
#  {'start_time': 2722.36, 'end_time': 2725.55, 'text': '。うん。そのちゃんと僕はうまく立ち回る'},
#  {'start_time': 2725.56, 'end_time': 2727.31, 'text': 'そのアクションができてるかな、立ち回れ'},
#  {'start_time': 2727.32, 'end_time': 2729.47, 'text': 'てるのかなっていうのをすごく気にし'},
#  {'start_time': 2729.48, 'end_time': 2732.47, 'text': 'ちゃうので、'},
#  {'start_time': 2732.48, 'end_time': 2735.79, 'text': 'ま、疲れちゃうかな。うん。ただですね、'},
#  {'start_time': 2735.8, 'end_time': 2739.35, 'text': 'あの、初対面は得意です。ま、この仕事を'},
#  {'start_time': 2739.36, 'end_time': 2741.51, 'text': 'していると本当に初めましての人とはい、'},
#  {'start_time': 2741.52, 'end_time': 2743.19, 'text': '1時間話してくださいっていう、そういっ'},
#  {'start_time': 2743.2, 'end_time': 2745.03, 'text': 'たシチュエーションってたくさんあるん'},
#  {'start_time': 2745.04, 'end_time': 2747.51, 'text': 'ですよね。あの、昨日もプライベート'},
#  {'start_time': 2747.52, 'end_time': 2750.15, 'text': 'レッスンが1つ新しいクラス始まりまして'},
#  {'start_time': 2750.16, 'end_time': 2753.03, 'text': '、その初めましての人と、ま、日本語を'},
#  {'start_time': 2753.04, 'end_time': 2755.07, 'text': '話す、1時間話すっていう、ま、そういっ'},
#  {'start_time': 2755.08, 'end_time': 2758.51, 'text': 'た状況があったんですけども、ま、そう'},
#  {'start_time': 2758.52, 'end_time': 2761.23, 'text': 'いったお仕事のおかげで初めましては'},
#  {'start_time': 2761.24, 'end_time': 2764.55, 'text': 'すごく得意です。気まずくならない、'},
#  {'start_time': 2764.56, 'end_time': 2768.67, 'text': '気まずい雰囲気を作らない'},
#  {'start_time': 2768.68, 'end_time': 2770.43, 'text': 'ようにできるっていうのは特技かな。苦手'},
#  {'start_time': 2770.44, 'end_time': 2773.11, 'text': 'なことでしたね。はい。苦手なこと。'},
#  {'start_time': 2773.12, 'end_time': 2776.51, 'text': '人付き合い。あと'},
#  {'start_time': 2776.52, 'end_time': 2780.43, 'text': '寝るのが苦手です。そうなんですよ。僕'},
#  {'start_time': 2780.44, 'end_time': 2783.27, 'text': '本当に寝るのが苦手で'},
#  {'start_time': 2783.28, 'end_time': 2786.23, 'text': 'なんて言うかな。寝続けるのが苦手かな。'},
#  {'start_time': 2786.24, 'end_time': 2788.83, 'text': 'パッと寝れるんですよ。昨日も夜12時に'},
#  {'start_time': 2788.84, 'end_time': 2792.19, 'text': 'なってで'},
#  {'start_time': 2792.2, 'end_time': 2795.91, 'text': '布団に入って目をつぶってカってすぐ寝'},
#  {'start_time': 2795.92, 'end_time': 2798.87, 'text': 'ちゃったんですよ。そうなんだけども大体'},
#  {'start_time': 2798.88, 'end_time': 2802.59, 'text': '3時間くらい4時間くらいで起きるんです'},
#  {'start_time': 2802.6, 'end_time': 2805.31, 'text': 'ね。で、ま、起きてしまったらもう寝られ'},
#  {'start_time': 2805.32, 'end_time': 2808.55, 'text': 'ない。うん。もう目がこんなギラギラ'},
#  {'start_time': 2808.56, 'end_time': 2810.79, 'text': 'ギラギラってなってしまってはい。寝られ'},
#  {'start_time': 2810.8, 'end_time': 2812.87, 'text': 'ない。うーん。ま、ちょっと皆さん、あの'},
#  {'start_time': 2812.88, 'end_time': 2814.39, 'text': '、心配しないでくださいとは言いつつも、'},
#  {'start_time': 2814.4, 'end_time': 2817.59, 'text': 'その'},
#  {'start_time': 2817.6, 'end_time': 2821.35, 'text': '夜ね、寝て寝続けられないけども昼寝を'},
#  {'start_time': 2821.36, 'end_time': 2824.67, 'text': '長く取ってます。なので大体夜3時間4'},
#  {'start_time': 2824.68, 'end_time': 2827.43, 'text': '時間くらい寝て昼間2時間3時間くらい寝'},
#  {'start_time': 2827.44, 'end_time': 2830.23, 'text': 'てま、1日で全体6時間くらい寝るように'},
#  {'start_time': 2830.24, 'end_time': 2832.71, 'text': 'してるんですけどもやっぱ寝るのがね苦手'},
#  {'start_time': 2832.72, 'end_time': 2837.27, 'text': 'なんですね。あの、さっきも言って言った'},
#  {'start_time': 2837.28, 'end_time': 2839.87, 'text': 'んですけども、よく考える癖があるので、'},
#  {'start_time': 2839.88, 'end_time': 2842.15, 'text': 'ふって寝よう、なんか眠くない時にとか'},
#  {'start_time': 2842.16, 'end_time': 2844.47, 'text': '起きてしまった後に寝ようとすると'},
#  {'start_time': 2844.48, 'end_time': 2847.47, 'text': 'ぐわーって頭でいろんなことを考えて'},
#  {'start_time': 2847.48, 'end_time': 2852.11, 'text': 'しまってなかなか寝られない。うん。て'},
#  {'start_time': 2852.12, 'end_time': 2856.23, 'text': 'いうのが苦手かなと思います。はい。さあ'},
#  {'start_time': 2856.24, 'end_time': 2858.03, 'text': '、今が、え、47分。いいですね。いい'},
#  {'start_time': 2858.04, 'end_time': 2860.51, 'text': '感じです。多分1時間ちょうどよく'},
#  {'start_time': 2860.52, 'end_time': 2862.55, 'text': '終われるかなと思うんですけども。え、次'},
#  {'start_time': 2862.56, 'end_time': 2867.19, 'text': 'が'},
#  {'start_time': 2867.2, 'end_time': 2872.19, 'text': '学歴です。はい。一応大学まで出てます。'},
#  {'start_time': 2872.2, 'end_time': 2876.99, 'text': 'うん。え、小学校、中学校までは効立の小'},
#  {'start_time': 2877.0, 'end_time': 2881.19, 'text': '学校、中学校でした。で、高校では私立の'},
#  {'start_time': 2881.2, 'end_time': 2883.59, 'text': '高校に行きました。はい。元々僕は勉強が'},
#  {'start_time': 2883.6, 'end_time': 2886.75, 'text': 'できません。テストの点数がいつも悪い'},
#  {'start_time': 2886.76, 'end_time': 2890.15, 'text': 'です。はい。あの、唯一できることとし'},
#  {'start_time': 2890.16, 'end_time': 2892.19, 'text': 'たら宿題を忘れないようにす、忘れない'},
#  {'start_time': 2892.2, 'end_time': 2895.31, 'text': 'ようにするだよ。忘れないじゃなくて忘れ'},
#  {'start_time': 2895.32, 'end_time': 2899.19, 'text': 'ないようにするぐらいかなと思うんですが'},
#  {'start_time': 2899.2, 'end_time': 2905.23, 'text': '、学校の勉強は本当に苦手らでした。なの'},
#  {'start_time': 2905.24, 'end_time': 2908.31, 'text': 'で、中学校の3年生の時に行ける高校が'},
#  {'start_time': 2908.32, 'end_time': 2912.03, 'text': 'あんまりなかったんですよ。'},
#  {'start_time': 2912.04, 'end_time': 2916.03, 'text': 'で、ラッキーなことにその時やっていた'},
#  {'start_time': 2916.04, 'end_time': 2918.15, 'text': '水泳で、ま、そこそこの結果が出て、で、'},
#  {'start_time': 2918.16, 'end_time': 2921.15, 'text': 'あとはその僕の言っていたスイミング'},
#  {'start_time': 2921.16, 'end_time': 2925.23, 'text': 'スクールのコーチとある、ま、静岡県に'},
#  {'start_time': 2925.24, 'end_time': 2927.63, 'text': 'ある私立の高校の、ま、監督先生と'},
#  {'start_time': 2927.64, 'end_time': 2931.03, 'text': 'コネクションがあったので紹介してくれて'},
#  {'start_time': 2931.04, 'end_time': 2935.03, 'text': '、え、推薦、スポーツ推薦っていう形で'},
#  {'start_time': 2935.04, 'end_time': 2938.35, 'text': 'その学校に入りました。そうなのでその'},
#  {'start_time': 2938.36, 'end_time': 2941.63, 'text': '高校自体はそんなにあ、ま、なんかそんな'},
#  {'start_time': 2941.64, 'end_time': 2943.83, 'text': 'に悪くない高校うん。ま、普通よりも'},
#  {'start_time': 2943.84, 'end_time': 2946.67, 'text': 'ちょっと上かなっていう高校なんですけど'},
#  {'start_time': 2946.68, 'end_time': 2950.63, 'text': 'も、もう勉強のレベルは全然ダメでしたね'},
#  {'start_time': 2950.64, 'end_time': 2953.75, 'text': '。はい。で、ま、その高校っていうのは'},
#  {'start_time': 2953.76, 'end_time': 2957.15, 'text': 'そのまんま大学もあるんですよ。なので'},
#  {'start_time': 2957.16, 'end_time': 2959.39, 'text': 'その学校の先生に言われたのが、あの宿題'},
#  {'start_time': 2959.4, 'end_time': 2961.51, 'text': 'をちゃんとしなさい。クラスを真面目に'},
#  {'start_time': 2961.52, 'end_time': 2965.67, 'text': '受けなさい。そしてテストも頑張りなさ'},
#  {'start_time': 2965.68, 'end_time': 2969.87, 'text': 'いって言われて、で、その内心点って言う'},
#  {'start_time': 2969.88, 'end_time': 2971.75, 'text': 'んですけども、1年間ね、数学なら数学を'},
#  {'start_time': 2971.76, 'end_time': 2974.31, 'text': 'どれくらい頑張りましたかっていうの点数'},
#  {'start_time': 2974.32, 'end_time': 2977.87, 'text': 'がつくんですね。で、その点数を下げない'},
#  {'start_time': 2977.88, 'end_time': 2980.47, 'text': 'ように成績をよくしといて、その成績で僕'},
#  {'start_time': 2980.48, 'end_time': 2982.87, 'text': 'は大学に入りました。これを推薦入学って'},
#  {'start_time': 2982.88, 'end_time': 2986.55, 'text': '言うんですけども、あの、日本のね、中で'},
#  {'start_time': 2986.56, 'end_time': 2989.87, 'text': 'は水薦入学で大学に入る人たちは頭の悪い'},
#  {'start_time': 2989.88, 'end_time': 2992.63, 'text': '人たちだっていう、ま、そういったね。'},
#  {'start_time': 2992.64, 'end_time': 2995.15, 'text': 'あの、レッテルを貼られることはよくある'},
#  {'start_time': 2995.16, 'end_time': 2997.35, 'text': 'んですけども、まさしくその通りで、あの'},
#  {'start_time': 2997.36, 'end_time': 3000.27, 'text': '、そんなに頭が良くありません。勉強が'},
#  {'start_time': 3000.28, 'end_time': 3003.75, 'text': 'できません。ま、そういった、あの、運'},
#  {'start_time': 3003.76, 'end_time': 3006.11, 'text': 'だけで大学まで行きました。で、その大学'},
#  {'start_time': 3006.12, 'end_time': 3009.31, 'text': 'で勉強していたことなんですけども、経済'},
#  {'start_time': 3009.32, 'end_time': 3012.71, 'text': '学を勉強してました。'},
#  {'start_time': 3012.72, 'end_time': 3017.51, 'text': '全然今のゆさんと関係ない経済学なんです'},
#  {'start_time': 3017.52, 'end_time': 3021.63, 'text': 'けども、高校の時にね、その'},
#  {'start_time': 3021.64, 'end_time': 3025.71, 'text': '大学を選ぶっていうタイミングがあったん'},
#  {'start_time': 3025.72, 'end_time': 3028.27, 'text': 'ですよね。で、おかげ様でその、ま、'},
#  {'start_time': 3028.28, 'end_time': 3030.71, 'text': 'スポーツ推薦で入ったっていうのもあって'},
#  {'start_time': 3030.72, 'end_time': 3033.67, 'text': '、その'},
#  {'start_time': 3033.68, 'end_time': 3037.83, 'text': '学校の成績はすごく良かったんですね。で'},
#  {'start_time': 3037.84, 'end_time': 3040.51, 'text': '、その成績のおかげで、ま、色々な大学が'},
#  {'start_time': 3040.52, 'end_time': 3044.11, 'text': '選べるっていう状況だったんですけども、'},
#  {'start_time': 3044.12, 'end_time': 3047.83, 'text': 'ま、その時にその'},
#  {'start_time': 3047.84, 'end_time': 3050.55, 'text': '問題が少ないうん。ま、つまりその変えが'},
#  {'start_time': 3050.56, 'end_time': 3052.43, 'text': '効くその'},
#  {'start_time': 3052.44, 'end_time': 3056.31, 'text': '勉強って何なのかなっていうので、ま、'},
#  {'start_time': 3056.32, 'end_time': 3060.03, 'text': '経済学を勉強することになりました。ま、'},
#  {'start_time': 3060.04, 'end_time': 3062.91, 'text': 'その当時ね、僕心理学の勉強をしたかった'},
#  {'start_time': 3062.92, 'end_time': 3065.51, 'text': 'んです。なんとなくこう心の勉強したりと'},
#  {'start_time': 3065.52, 'end_time': 3069.63, 'text': 'かカウンセラーになるってかっこいいな。'},
#  {'start_time': 3069.64, 'end_time': 3071.95, 'text': '元々人の話を聞くのが得意だったので、'},
#  {'start_time': 3071.96, 'end_time': 3076.03, 'text': 'あのカウンセラーの仕事向いてるんじゃ'},
#  {'start_time': 3076.04, 'end_time': 3079.51, 'text': 'ないかなね。例えば学校でさ、あの心の'},
#  {'start_time': 3079.52, 'end_time': 3082.99, 'text': '問題がある生徒に対してカウンセリングし'},
#  {'start_time': 3083.0, 'end_time': 3086.91, 'text': 'たらいいかなとかって思ったんだけども、'},
#  {'start_time': 3086.92, 'end_time': 3089.27, 'text': 'そのどうもその僕の入れる心理学部だとお'},
#  {'start_time': 3089.28, 'end_time': 3091.43, 'text': '医者さんにはなれない。カウンセラーには'},
#  {'start_time': 3091.44, 'end_time': 3094.11, 'text': 'なれるけどお医者さんにはなれない。お'},
#  {'start_time': 3094.12, 'end_time': 3097.75, 'text': '医者さんになれなかったら貧乏な生活が'},
#  {'start_time': 3097.76, 'end_time': 3100.79, 'text': '待っている。だからなんでその貧乏な生活'},
#  {'start_time': 3100.8, 'end_time': 3105.51, 'text': 'が待っていることを知りつつも心理学部に'},
#  {'start_time': 3105.52, 'end_time': 3108.07, 'text': '入りたいのって学校の先生に聞かれてう'},
#  {'start_time': 3108.08, 'end_time': 3110.87, 'text': 'ええ、じゃあ経済にしますっていう風に'},
#  {'start_time': 3110.88, 'end_time': 3113.55, 'text': 'そこで折れてしまったんですね。まあ、今'},
#  {'start_time': 3113.56, 'end_time': 3116.27, 'text': 'この2026年心の病気っていうのが'},
#  {'start_time': 3116.28, 'end_time': 3119.27, 'text': 'すごく大変で、このカウンセリングのお'},
#  {'start_time': 3119.28, 'end_time': 3121.87, 'text': '仕事っていうのは大事だっていうのをね、'},
#  {'start_time': 3121.88, 'end_time': 3124.23, 'text': 'あの、ま、そういった状況にあるから、ま'},
#  {'start_time': 3124.24, 'end_time': 3126.95, 'text': '、あの時心理学を勉強してれば良かったか'},
#  {'start_time': 3126.96, 'end_time': 3130.83, 'text': 'なとも思うんですけども、経済学部に入り'},
#  {'start_time': 3130.84, 'end_time': 3134.43, 'text': 'ました。ま、そういったね、悩んだその'},
#  {'start_time': 3134.44, 'end_time': 3137.31, 'text': '結果として経済学部を選んで、だから経済'},
#  {'start_time': 3137.32, 'end_time': 3140.99, 'text': 'の勉強がしたかったわけじゃないのに経済'},
#  {'start_time': 3141.0, 'end_time': 3143.59, 'text': '学部に入ってしまったのですごい辛い思い'},
#  {'start_time': 3143.6, 'end_time': 3147.55, 'text': 'というか大変な思いをしましたね。毎日'},
#  {'start_time': 3147.56, 'end_time': 3149.19, 'text': '勉強することが面白くない。つまらないね'},
#  {'start_time': 3149.2, 'end_time': 3152.19, 'text': '。'},
#  {'start_time': 3152.2, 'end_time': 3153.95, 'text': 'なんか自分が経済について勉強して'},
#  {'start_time': 3153.96, 'end_time': 3156.15, 'text': 'ビジネスマンになりたいなんて全然'},
#  {'start_time': 3156.16, 'end_time': 3160.35, 'text': 'ビジョンが湧かないって思ってたんです。'},
#  {'start_time': 3160.36, 'end_time': 3164.95, 'text': 'で、その時に、あの、'},
#  {'start_time': 3164.96, 'end_time': 3168.55, 'text': 'その僕の言っていた大学では教員家程、'},
#  ...]

# %%
data1_df = pd.DataFrame(data1)
data2_df = pd.DataFrame(data2)
data3_df = pd.DataFrame(data3)

# %%
data1_df
# Out:
#       start_time  end_time                 text
# 0           2.24      4.47    はい、皆さんこんにちは。ゆの日本語
# 1           4.48      7.07  ポッドキャストのお時間です。皆さん元気
# 2           7.08      9.83  にしていますでしょうか?今日は久しぶり
# 3           9.84     14.15   に1時間ポッドキャストにチャレンジし
# 4          14.16     17.11  たいと思います。テーマはゆについて、あ
# ...          ...       ...                  ...
# 1347     4192.44   4194.15  ポッドキャストを聞き終わった後、え、別
# 1348     4194.16   4196.19  のお気に入りのポッドキャストだったりと
# 1349     4196.20   4199.03    か最近のエピソードを聞いてくれると
# 1350     4199.04   4201.19  すごく嬉しいです。はい、ということで皆
# 1351     4201.20   4206.16    さん引き続き日本語の勉強を頑張って
#
# [1352 rows x 3 columns]

# %%
# Further Data Cleaning
# Taking segmented subtitle data and cleaning it to make sentences complete

# Pseduocode:
# For normal videos: Punctuations are included ("。", "、", "～", "？", "！")
# 1.) Need to use a sliding window, but it has to be variable.  (based on sent)
# 2.) Use the ja_sentence_segmenter to split the text into sentences
# Case 1: Block is a complete sentence. (rare)
#      No need to parse the text --> just put in to data format
#      No need to change the times
# Case 2: Block was split into multiple sentences
#  2a: First sentence is not complete 
#      (WE KNOW IF THE FIRST SENTENCE IS NOT COMPLETE BASED ON THE PREVIOUS BLOCK
#       IF THE PREVIOUS BLOCK HAD AN INCOMPLETE SENT THEN WE ASSUME THE CURRENT FIRST
#       BLOCK IS THE RUNON FROM THE PREVIOUS, ELSE IT IS NOT A RUNON AND IS COMPLETE)
#      Remove it
#  2b: First sentence --> Last sentence as all complete: 
#      All sentences --> data format
#      Put the same time frame for all
#  2c: Last sentence is not complete:
#      incomplete_sent = last_sent
#      Then take the first sentence from the next segment and
#      (incomplete_sent + cur_sent) --> data format
#      (Prev_time_frame.start_time, cur_time_frame.end_time)
#
#      Else, if the next segment does not contain a full sentence:
#      incomplete_sent = incomplete_sent + cur_sent --> continue without inputting
#

# %%
# my_list = [{'one': 1}, 'two', 'three']
# my_list[0]['one']
re.split(r'(?<=[。？！])', "たいと思いますテーマはゆについて、あ")
# Out:
# ['たいと思いますテーマはゆについて、あ']

# %%
# Map to data helper function
def sent_to_data(sent_id, text, start_time, end_time):
    return {
        'sentence_id': sent_id,
        'start_time': start_time,
        'end_time': end_time,
        'text': text,
        'jlpt_level': '',
        'grammar': '',
        'vocabulary': ''
    }

# %%
# Input is in [{'start_time': int, 'end_time': int, 'text': 'string'}, ...]
def segs_to_sents(data):
    result = [] # New resulting list
    i = 0       # Sequential index for the list based on each append
    
    tot_segs = len(data)
    start = 0 # Start of the sliding window
    end   = 0 # End of the sliding window

    incomplete_sent = "" # Sentence accumulator for incomplete sentences
    while end < tot_segs:
        # Get current segment and split based on ("。", "？", "！")
        sent_split = re.split(r'(?<=[。？！])', data[end]['text'])
        
        ##### Cases 1,2,3 The block contains exactly one sentence #####
        # Case 1: Block is a complete sentence and there is no incomplete sent
        # EX: sent_split = ["はい、皆さんこんにちは。"]
        if(incomplete_sent == "" and len(sent_split) == 1 and "。" in sent_split[0]):
            result.append(sent_to_data(i, sent_split, data[end]['start_time'], data[end['end_time']]))
            i     = i + 1
            start = start + 1
            end   = end + 1
            continue
        
        if(incomplete_sent != "" and len(sent_split) == 1):
        # Case 2: Block splits into 1 block WITH a punctuation
        # EX:  sent_split = ['ポッドキャストのお時間です。']
        # incomplete_sent = 'ゆの日本語'
            if "。" in sent_split[0]:
                sent = incomplete_sent + sent_split[0]
                result.append(sent_to_data(i, sent, data[start]['start_time='], data[end]['end_time']))

                incomplete_sent = ""
                i     = i + 1
                start = end + 1
                end   = end + 1
                continue

        # Case 3: Block splits into 1 block WITHOUT a punctuation
        # EX:  sent_split = ['に1時間ポッドキャストにチャレンジし'] (next seg: "たいと思います。")
        # incomplete_sent = '今日は久しぶり'
            if "。" not in sent_split[0]:
                incomplete_sent = incomplete_sent + sent_split[0]
                end = end + 1
                continue

# %%
incomplete_sent = "ゆの日本語"
test = "ポッドキャストのお時間です。"

incomplete_sent + test
# Out:
# 'ゆの日本語ポッドキャストのお時間です。'

# %%
# seg_to_sent(data1)

# %%
# 0   2.24	4.47	はい、皆さんこんにちは。ゆの日本語
# 1	  4.48	7.07	ポッドキャストのお時間です。皆さん元気
# 2	  7.08	9.83	にしていますでしょうか?今日は久しぶり
# 3	  9.84	14.15	に1時間ポッドキャストにチャレンジし
# 4	 14.16	17.11	たいと思います。テーマはゆについて、あ

# %%
# ===== Data Format (EXAMPLE) ===== #
{
  'sentence_id': 0,
  'text': 'はい、皆さんこんにちは。',
  'time_range': (2.24, 4.47),  # For audio playback
  'grammar_patterns': ['ます form', 'greeting'],
  'jlpt_level': 'N5',
  'difficulty': 2,
  'pos_tags': [...],  # From MeCab
  'vocabulary': ['皆さん', 'こんにちは']
}

# # Example
# text = "はい、皆さんこんにちは。ゆの日本語"
# sentences = split_japanese_sentences(text)
# # ['はい、皆さんこんにちは。', 'ゆの日本語']

# %%
# Observations
# For podcast and normal videos:
# Sentences get cutoff and sometimes end on the next line.
# Easy to tell because periods are present
# We could clean this by searching for segments that dont end in a period
# then merge the next block until a period is hit.
# How do I know if I should merge into the first or second segment?
# Or should I always merge into the first segment?
# Then how should I update the start and end times? I don't think I should.
# But I should remove all the text I merged with the first block

# There are cases where sentences may be complete in 2, 3, or 4 lines
# This is when we start a sentence and now a period isn't seen for
# a couple of lines. In this case we should delete the block and merge
# the times.

# For music videos:
# There are no periods and only occasionally question marks
# It may be a lot more difficult to split up sentences by context
# It may be easier to keep this as is

# Maybe add a feature to the app where a user can select blocks 
# or manually type in their sentence and have the app assign grammar tags
# and allow them to add their sentences to their decks of choice
