# %%
### IMPORTS ###
import pandas as pd
import yt_dlp
import json
import os
from pathlib import Path
import re

import webvtt
from ja_sentence_segmenter.common.pipeline import make_pipeline
from ja_sentence_segmenter.concatenate.simple_concatenator import concatenate_matching
from ja_sentence_segmenter.split.simple_splitter import split_newline, split_punctuation
import functools

# %%
# help(yt_dlp.YoutubeDL)
# Detailed explanation of yt-dlp options for your use case
"""
OPTIONS NEEDED FOR YOUR REQUIREMENTS:

1. TITLE - Automatically extracted as info_dict['title']
   
2. AUTHOR - Automatically extracted as info_dict['uploader']
   
3. LINK - The URL you provide to the function
   
4. DURATION - Automatically extracted as info_dict['duration'] (in seconds)

5. SUBTITLES WITH TIMESTAMPS (Japanese & English):
   - writesubtitles: True
     Downloads manually created subtitles
   
   - writeautomaticsub: True  
     Downloads auto-generated subtitles (YouTube's automatic captions)
   
   - subtitleslangs: ['ja', 'en']
     Specifies which subtitle languages to download
     Can use 'all' to download all available languages
   
   - subtitlesformat: 'vtt'  (RECOMMENDED)
     Format for subtitles. Options: 'vtt', 'srt', 'ass', 'lrc'
     VTT (WebVTT) includes timestamps in this format:
         00:00:01.000 --> 00:00:03.000
         Subtitle text here
     
     VTT is best for your use case because:
     - Includes precise timestamps
     - Easy to parse programmatically
     - Well-supported format

6. AUDIO FILE:
   - format: 'bestaudio/best'
     Downloads the best available audio quality
   
   - postprocessors: [{
         'key': 'FFmpegExtractAudio',
         'preferredcodec': 'mp3',      # Output format (mp3, wav, m4a, etc.)
         'preferredquality': '192',    # Audio bitrate (128, 192, 256, 320)
     }]
     Converts audio to MP3 format
   
   With the subtitle timestamps, you can later extract specific 
   audio segments using ffmpeg or pydub

OTHER USEFUL OPTIONS:

- writeinfojson: True
  Saves ALL metadata as a .info.json file including:
  - Full description, tags, categories
  - View count, like count, upload date
  - All available formats and quality info
  - Comments (if getcomments: True)
  
- outtmpl: 'path/%(title)s.%(ext)s'
  Controls output filename. Available variables:
  - %(title)s - Video title
  - %(uploader)s - Channel/uploader name
  - %(id)s - Video ID
  - %(upload_date)s - Upload date (YYYYMMDD)
  - %(duration)s - Duration in seconds
  Example: 'downloads/%(uploader)s/%(title)s_%(id)s.%(ext)s'

- writethumbnail: True
  Downloads the video thumbnail image
  
- quiet: False
  Shows download progress (True hides it)

- getcomments: True (with writeinfojson: True)
  Extracts video comments and saves to JSON
"""
# Out:
# "\nOPTIONS NEEDED FOR YOUR REQUIREMENTS:\n\n1. TITLE - Automatically extracted as info_dict['title']\n\n2. AUTHOR - Automatically extracted as info_dict['uploader']\n\n3. LINK - The URL you provide to the function\n\n4. DURATION - Automatically extracted as info_dict['duration'] (in seconds)\n\n5. SUBTITLES WITH TIMESTAMPS (Japanese & English):\n   - writesubtitles: True\n     Downloads manually created subtitles\n\n   - writeautomaticsub: True  \n     Downloads auto-generated subtitles (YouTube's automatic captions)\n\n   - subtitleslangs: ['ja', 'en']\n     Specifies which subtitle languages to download\n     Can use 'all' to download all available languages\n\n   - subtitlesformat: 'vtt'  (RECOMMENDED)\n     Format for subtitles. Options: 'vtt', 'srt', 'ass', 'lrc'\n     VTT (WebVTT) includes timestamps in this format:\n         00:00:01.000 --> 00:00:03.000\n         Subtitle text here\n\n     VTT is best for your use case because:\n     - Includes precise timestamps\n     - Easy to parse programmatically\n     - Well-supported format\n\n6. AUDIO FILE:\n   - format: 'bestaudio/best'\n     Downloads the best available audio quality\n\n   - postprocessors: [{\n         'key': 'FFmpegExtractAudio',\n         'preferredcodec': 'mp3',      # Output format (mp3, wav, m4a, etc.)\n         'preferredquality': '192',    # Audio bitrate (128, 192, 256, 320)\n     }]\n     Converts audio to MP3 format\n\n   With the subtitle timestamps, you can later extract specific \n   audio segments using ffmpeg or pydub\n\nOTHER USEFUL OPTIONS:\n\n- writeinfojson: True\n  Saves ALL metadata as a .info.json file including:\n  - Full description, tags, categories\n  - View count, like count, upload date\n  - All available formats and quality info\n  - Comments (if getcomments: True)\n\n- outtmpl: 'path/%(title)s.%(ext)s'\n  Controls output filename. Available variables:\n  - %(title)s - Video title\n  - %(uploader)s - Channel/uploader name\n  - %(id)s - Video ID\n  - %(upload_date)s - Upload date (YYYYMMDD)\n  - %(duration)s - Duration in seconds\n  Example: 'downloads/%(uploader)s/%(title)s_%(id)s.%(ext)s'\n\n- writethumbnail: True\n  Downloads the video thumbnail image\n\n- quiet: False\n  Shows download progress (True hides it)\n\n- getcomments: True (with writeinfojson: True)\n  Extracts video comments and saves to JSON\n"

# %%
def download_media_with_subtitles(url, output_dir='data'):
    """
    Download audio as MP3, subtitles, and metadata from a given URL.
    
    Args:
        url        (str): URL of the media to download
        output_dir (str): Directory to save downloaded files
    
    Returns:
        result: Information about downloaded files
    """
    
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)     
    
    # Configure yt-dlp options
    ydl_opts = {
        # Audio settings
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        
        # Output settings
        'outtmpl': f'{output_dir}/%(title)s.%(ext)s',
        
        # Subtitle settings - KEY FOR YOUR USE CASE
        'writesubtitles': True,              # Manual subs
        'writeautomaticsub': True,           # Auto-generated subs
        'subtitleslangs': ['ja'],            # Japanese (use translator to convert to en)
        'subtitlesformat': 'vtt',            # VTT format (includes timestamps)
        
        # Metadata settings
        'writeinfojson': True,               # Save full metadata as JSON
        'writethumbnail': False,             # Set True if you want thumbnails
        
        # Rate limiting to avoid 429 errors
        'sleep_interval_requests': 2,        # Sleep 2 seconds between API requests
        'sleep_interval_subtitles': 10,      # Sleep 10 seconds between subtitle downloads
        'sleep_interval': 1,                 # Sleep 1 second before each download
        
        # Progress settings
        'quiet': False,
        'no_warnings': False,
    }
    
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            # Extract info without downloading first to check what's available
            info = ydl.extract_info(url, download=False)

            # Display what's available
            print(f"\nTitle: {info.get('title')}")
            print(f"Author: {info.get('uploader', 'N/A')}")
            print(f"Duration: {info.get('duration', 'N/A')} seconds")
            print(f"URL: {url}\n")
            
            # Check subtitles
            manual_subs = list(info.get('subtitles', {}).keys())
            auto_subs = list(info.get('automatic_captions', {}).keys())
            print(f"Manual subtitles: {manual_subs if manual_subs else 'None'}")
            print(f"Auto-captions available for: {', '.join(auto_subs[:5])}... (and {len(auto_subs)-5} more)" if len(auto_subs) > 5 else f"Auto-captions: {auto_subs}\n")
            
            # Download everything
            print("\n===== Downloading audio, subtitles, and metadata... =====")
            print("(Adding delays between requests to avoid rate limiting...)\n")     

            ydl.download([url])
            
            result = {
                'title': info.get('title'),
                'duration': info.get('duration'),
                'uploader': info.get('uploader'),
                'upload_date': info.get('upload_date'),
                'view_count': info.get('view_count'),
                'like_count': info.get('like_count'),
                'description': info.get('description'),
                'subtitles_available': list(info.get('subtitles', {}).keys()),
                'auto_captions_available': list(info.get('automatic_captions', {}).keys()),
                'output_dir': output_dir
            }
            
            print("\nDownload complete!\n")
            return result
    except Exception as e:
        print(f"Error: {str(e)}\n")
        return None

# %%
# Test the function with a URL
# Replace with your desired URL
# url = "https://www.youtube.com/watch?v=1PPLx2N_YTE" # YUYU podcast test, auto gen subs
# url = "https://www.youtube.com/watch?v=hkeegM5t-lw" # Jiro podcast test, manual subs
# url = "https://open.spotify.com/track/7DyS11kB1YNrfDzQqtjmTh?si=24a7621a3a24483c" # spotify song
url = "https://www.youtube.com/watch?v=1mz-A--mANU"

# Download audio, subtitles, and metadata
result = download_media_with_subtitles(url, output_dir='japanese_media')

# Display the metadata
if result:
    #print("\\n\" + \"=\"*50")
    print("DOWNLOADED MEDIA INFORMATION\n")
    #print("=\"*50")
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1mz-A--mANU
# [youtube] 1mz-A--mANU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading android vr player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading ios downgraded player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading m3u8 information
# [info] 1mz-A--mANU: Downloading subtitles: ja
#
# Title: 平井 大 / Slow & Easy（Music Video）
# Author: 平井 大 HIRAIDAI
# Duration: 222 seconds
# URL: https://www.youtube.com/watch?v=1mz-A--mANU
#
# Manual subtitles: ['ja']
# Auto-captions available for: ja, ab-ja, aa-ja, af-ja, ak-ja... (and 152 more)
#
# ===== Downloading audio, subtitles, and metadata... =====
# (Adding delays between requests to avoid rate limiting...)
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1mz-A--mANU
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading android vr player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading ios downgraded player API JSON
# [youtube] Sleeping 2 seconds ...
# [youtube] 1mz-A--mANU: Downloading m3u8 information
# [info] 1mz-A--mANU: Downloading subtitles: ja
# [info] 1mz-A--mANU: Downloading 1 format(s): 251
# [info] Writing video subtitles to: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.ja.vtt
# [download] Sleeping 10.00 seconds ...
# WARNING: The extractor specified to use impersonation for this download, but no impersonate target is available. If you encounter errors, then see  https://github.com/yt-dlp/yt-dlp#impersonation  for information on installing the required dependencies
# [download] Destination: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.ja.vtt
# [download] 100% of    3.31KiB in 00:00:00 at 35.56KiB/s
# [info] Writing video metadata as JSON to: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.info.json
# [download] Sleeping 1.00 seconds ...
# [download] Destination: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.webm
# [download] 100% of    3.58MiB in 00:00:01 at 2.19MiB/s
# [ExtractAudio] Destination: japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.mp3
# Deleting original file japanese_media/平井 大 ⧸ Slow & Easy（Music Video）.webm (pass -k to keep)
#
# Download complete!
#
# DOWNLOADED MEDIA INFORMATION
#
# {
#   "title": "平井 大 / Slow & Easy（Music Video）",
#   "duration": 222,
#   "uploader": "平井 大 HIRAIDAI",
#   "upload_date": "20181220",
#   "view_count": 19151280,
#   "like_count": 85267,
#   "description": "平井 大の楽曲をチェック！\nhttps://DaiHirai.lnk.to/toppage\n\nFOLLOW \"HIRAIDAI\"\nWebsite: https://hiraidai.com/\nInstagram: https://www.instagram.com/hirai_dai_official/\nTwitter: https://twitter.com/hiraidai\nLINE: https://line.me/R/ti/p/%40hiraidai\nTikTok：https://www.tiktok.com/@hiraidai",
#   "subtitles_available": [
#     "ja"
#   ],
#   "auto_captions_available": [
#     "ja",
#     "ab-ja",
#     "aa-ja",
#     "af-ja",
#     "ak-ja",
#     "sq-ja",
#     "am-ja",
#     "ar-ja",
#     "hy-ja",
#     "as-ja",
#     "ay-ja",
#     "az-ja",
#     "bn-ja",
#     "ba-ja",
#     "eu-ja",
#     "be-ja",
#     "bho-ja",
#     "bs-ja",
#     "br-ja",
#     "bg-ja",
#     "my-ja",
#     "ca-ja",
#     "ceb-ja",
#     "zh-Hans-ja",
#     "zh-Hant-ja",
#     "co-ja",
#     "hr-ja",
#     "cs-ja",
#     "da-ja",
#     "dv-ja",
#     "nl-ja",
#     "dz-ja",
#     "en-ja",
#     "eo-ja",
#     "et-ja",
#     "ee-ja",
#     "fo-ja",
#     "fj-ja",
#     "fil-ja",
#     "fi-ja",
#     "fr-ja",
#     "gaa-ja",
#     "gl-ja",
#     "lg-ja",
#     "ka-ja",
#     "de-ja",
#     "el-ja",
#     "gn-ja",
#     "gu-ja",
#     "ht-ja",
#     "ha-ja",
#     "haw-ja",
#     "iw-ja",
#     "hi-ja",
#     "hmn-ja",
#     "hu-ja",
#     "is-ja",
#     "ig-ja",
#     "id-ja",
#     "iu-ja",
#     "ga-ja",
#     "it-ja",
#     "ja-ja",
#     "jv-ja",
#     "kl-ja",
#     "kn-ja",
#     "kk-ja",
#     "kha-ja",
#     "km-ja",
#     "rw-ja",
#     "ko-ja",
#     "kri-ja",
#     "ku-ja",
#     "ky-ja",
#     "lo-ja",
#     "la-ja",
#     "lv-ja",
#     "ln-ja",
#     "lt-ja",
#     "lua-ja",
#     "luo-ja",
#     "lb-ja",
#     "mk-ja",
#     "mg-ja",
#     "ms-ja",
#     "ml-ja",
#     "mt-ja",
#     "gv-ja",
#     "mi-ja",
#     "mr-ja",
#     "mn-ja",
#     "mfe-ja",
#     "ne-ja",
#     "new-ja",
#     "nso-ja",
#     "no-ja",
#     "ny-ja",
#     "oc-ja",
#     "or-ja",
#     "om-ja",
#     "os-ja",
#     "pam-ja",
#     "ps-ja",
#     "fa-ja",
#     "pl-ja",
#     "pt-ja",
#     "pt-PT-ja",
#     "pa-ja",
#     "qu-ja",
#     "ro-ja",
#     "rn-ja",
#     "ru-ja",
#     "sm-ja",
#     "sg-ja",
#     "sa-ja",
#     "gd-ja",
#     "sr-ja",
#     "crs-ja",
#     "sn-ja",
#     "sd-ja",
#     "si-ja",
#     "sk-ja",
#     "sl-ja",
#     "so-ja",
#     "st-ja",
#     "es-ja",
#     "su-ja",
#     "sw-ja",
#     "ss-ja",
#     "sv-ja",
#     "tg-ja",
#     "ta-ja",
#     "tt-ja",
#     "te-ja",
#     "th-ja",
#     "bo-ja",
#     "ti-ja",
#     "to-ja",
#     "ts-ja",
#     "tn-ja",
#     "tum-ja",
#     "tr-ja",
#     "tk-ja",
#     "uk-ja",
#     "ur-ja",
#     "ug-ja",
#     "uz-ja",
#     "ve-ja",
#     "vi-ja",
#     "war-ja",
#     "cy-ja",
#     "fy-ja",
#     "wo-ja",
#     "xh-ja",
#     "yi-ja",
#     "yo-ja",
#     "zu-ja"
#   ],
#   "output_dir": "japanese_media"
# }

# %%
### CREATING THE vtt PARSER ###
import re
from pathlib import Path

# %%
# 1.) vtt cleaner

# Remove empty lines
# Remove WEBVTT, Kind: captions, Language: ja lines (always first 3)
# Remove all lines with "<c>" or "</c>" since these are bad format and are repeatted in 
# next line anyways

# Output to (cleaned)+path
def vtt_clean(input_file, output_file):
    input_path = Path(input_file)
    output_path = Path(output_file)

    if not input_path.exists():
        raise FileNotFoundError(F"File not found: {input_path}")

    # Read full file into content buffer
    content = input_path.read_text(encoding='utf-8')

    # Process
    re.sub(r"\n\n\n|\n\n", "\n", content)
    content = '\n'.join(
        line for line in content.split('\n') 
        if '<c>' not in line 
        and '</c>' not in line
        and 'WEBVTT' not in line
        and 'Kind: captions' not in line
        and 'Language: ja' not in line
    )

    content = content.split("\n")
    content = [item for item in content if item not in ('', ' ')]
    # for item in content:
    #     print(item)

    # Now must make json data for start_time, end_time, text
    # If the line has "-->" its a time stamp
    # sometimes 2 timestamps are back to back lines so we can't flip

    # use a sliding window:

# %%
vtt_clean("/home/evanxavierhu/Documents/VSCode_Local_Projects/JL_Project/Japanese_Lang_Project/japanese_media/【1hour Podcast】本名は？結婚してる？苦手なことは？YUYUについて話しました！ (Japanese Radio for Listening practice).ja.vtt", "data1.txt")

#vtt_clean("/home/evanxavierhu/Documents/VSCode_Local_Projects/JL_Project/Japanese_Lang_Project/japanese_media/【Japanese Podcast】I Got This! - Master 706 Essential Words Without Even Noticing.ja.vtt", "data2.txt")
# Out:
# 00:00:00.160 --> 00:00:02.230 align:start position:0%
# 00:00:02.230 --> 00:00:02.240 align:start position:0%
# はい、皆さんこんにちは。ゆの日本語
# 00:00:02.240 --> 00:00:04.470 align:start position:0%
# はい、皆さんこんにちは。ゆの日本語
# 00:00:04.470 --> 00:00:04.480 align:start position:0%
# ポッドキャストのお時間です。皆さん元気
# 00:00:04.480 --> 00:00:07.070 align:start position:0%
# ポッドキャストのお時間です。皆さん元気
# 00:00:07.070 --> 00:00:07.080 align:start position:0%
# にしていますでしょうか?今日は久しぶり
# 00:00:07.080 --> 00:00:09.830 align:start position:0%
# にしていますでしょうか?今日は久しぶり
# 00:00:09.830 --> 00:00:09.840 align:start position:0%
# に1時間ポッドキャストにチャレンジし
# 00:00:09.840 --> 00:00:14.150 align:start position:0%
# に1時間ポッドキャストにチャレンジし
# 00:00:14.150 --> 00:00:14.160 align:start position:0%
# たいと思います。テーマはゆについて、あ
# 00:00:14.160 --> 00:00:17.109 align:start position:0%
# たいと思います。テーマはゆについて、あ
# 00:00:17.109 --> 00:00:17.119 align:start position:0%
# 、ま、つまり僕についてですね。ま、
# 00:00:17.119 --> 00:00:19.950 align:start position:0%
# 、ま、つまり僕についてですね。ま、
# 00:00:19.950 --> 00:00:19.960 align:start position:0%
# おかげ様でYouTubeの登録者数が
# 00:00:19.960 --> 00:00:23.310 align:start position:0%
# おかげ様でYouTubeの登録者数が
# 00:00:23.310 --> 00:00:23.320 align:start position:0%
# もうすぐ50万人を迎えてそれだけじゃ
# 00:00:23.320 --> 00:00:26.589 align:start position:0%
# もうすぐ50万人を迎えてそれだけじゃ
# 00:00:26.589 --> 00:00:26.599 align:start position:0%
# なくてですね、チャンネル運営が5年目を
# 00:00:26.599 --> 00:00:29.710 align:start position:0%
# なくてですね、チャンネル運営が5年目を
# 00:00:29.710 --> 00:00:29.720 align:start position:0%
# 迎える、ま、そういった年でもあるんです
# 00:00:29.720 --> 00:00:32.229 align:start position:0%
# 迎える、ま、そういった年でもあるんです
# 00:00:32.229 --> 00:00:32.239 align:start position:0%
# よ。まあ、つまり簡単に言うと5年前に
# 00:00:32.239 --> 00:00:35.110 align:start position:0%
# よ。まあ、つまり簡単に言うと5年前に
# 00:00:35.110 --> 00:00:35.120 align:start position:0%
# ゆuの日本語ポッドキャストを始めてで、
# 00:00:35.120 --> 00:00:38.910 align:start position:0%
# ゆuの日本語ポッドキャストを始めてで、
# 00:00:38.910 --> 00:00:38.920 align:start position:0%
# もう5年が経ったということで、ま、その
# 00:00:38.920 --> 00:00:42.310 align:start position:0%
# もう5年が経ったということで、ま、その
# 00:00:42.310 --> 00:00:42.320 align:start position:0%
# 始めた頃から新しいメンバーもですね、
# 00:00:42.320 --> 00:00:44.190 align:start position:0%
# 始めた頃から新しいメンバーもですね、
# 00:00:44.190 --> 00:00:44.200 align:start position:0%
# あの、ま、この、この場合のメンバーメン
# 00:00:44.200 --> 00:00:46.110 align:start position:0%
# あの、ま、この、この場合のメンバーメン
# 00:00:46.110 --> 00:00:46.120 align:start position:0%
# バーっていうのは皆さん、フォロワー、皆
# 00:00:46.120 --> 00:00:48.270 align:start position:0%
# バーっていうのは皆さん、フォロワー、皆
# 00:00:48.270 --> 00:00:48.280 align:start position:0%
# さんのことなんですけども、ま、新しい
# 00:00:48.280 --> 00:00:53.150 align:start position:0%
# さんのことなんですけども、ま、新しい
# 00:00:53.150 --> 00:00:53.160 align:start position:0%
# メンバーも迎えて、ま、多分僕についての
# 00:00:53.160 --> 00:00:56.189 align:start position:0%
# メンバーも迎えて、ま、多分僕についての
# 00:00:56.189 --> 00:00:56.199 align:start position:0%
# ね、え、知っていることっていうのは
# 00:00:56.199 --> 00:01:00.110 align:start position:0%
# ね、え、知っていることっていうのは
# 00:01:00.110 --> 00:01:00.120 align:start position:0%
# もちろんですけども、新しい方と、ま、昔
# 00:01:00.120 --> 00:01:03.470 align:start position:0%
# もちろんですけども、新しい方と、ま、昔
# 00:01:03.470 --> 00:01:03.480 align:start position:0%
# から聞いてくださっている方はもう全然
# 00:01:03.480 --> 00:01:06.070 align:start position:0%
# から聞いてくださっている方はもう全然
# 00:01:06.070 --> 00:01:06.080 align:start position:0%
# 違うわけですよね。ていうことで、ま、
# 00:01:06.080 --> 00:01:10.109 align:start position:0%
# 違うわけですよね。ていうことで、ま、
# 00:01:10.109 --> 00:01:10.119 align:start position:0%
# いい機会だなと思いまして、自己紹介をし
# 00:01:10.119 --> 00:01:14.109 align:start position:0%
# いい機会だなと思いまして、自己紹介をし
# 00:01:14.109 --> 00:01:14.119 align:start position:0%
# てみたいと思います。はい。ま、ただね、
# 00:01:14.119 --> 00:01:17.390 align:start position:0%
# てみたいと思います。はい。ま、ただね、
# 00:01:17.390 --> 00:01:17.400 align:start position:0%
# 自己紹介って普通10秒とか20秒ぐらい
# 00:01:17.400 --> 00:01:20.310 align:start position:0%
# 自己紹介って普通10秒とか20秒ぐらい
# 00:01:20.310 --> 00:01:20.320 align:start position:0%
# ですよね。なんですけども、ま、その自己
# 00:01:20.320 --> 00:01:25.350 align:start position:0%
# ですよね。なんですけども、ま、その自己
# 00:01:25.350 --> 00:01:25.360 align:start position:0%
# 紹介で話すテーマをできるだけ深く
# 00:01:25.360 --> 00:01:28.469 align:start position:0%
# 紹介で話すテーマをできるだけ深く
# 00:01:28.469 --> 00:01:28.479 align:start position:0%
# 掘り下げてで、僕について、ま、皆さんに
# 00:01:28.479 --> 00:01:30.870 align:start position:0%
# 掘り下げてで、僕について、ま、皆さんに
# 00:01:30.870 --> 00:01:30.880 align:start position:0%
# 知ってもらおうっていうのが、ま、今回の
# 00:01:30.880 --> 00:01:33.870 align:start position:0%
# 知ってもらおうっていうのが、ま、今回の
# 00:01:33.870 --> 00:01:33.880 align:start position:0%
# 1時間ポッドキャストです。はい。という
# 00:01:33.880 --> 00:01:36.270 align:start position:0%
# 1時間ポッドキャストです。はい。という
# 00:01:36.270 --> 00:01:36.280 align:start position:0%
# ことで、ま、簡単にメモを取ってきました
# 00:01:36.280 --> 00:01:38.789 align:start position:0%
# ことで、ま、簡単にメモを取ってきました
# 00:01:38.789 --> 00:01:38.799 align:start position:0%
# 。ま、こんな感じですね。え、話す内容に
# 00:01:38.799 --> 00:01:42.230 align:start position:0%
# 。ま、こんな感じですね。え、話す内容に
# 00:01:42.230 --> 00:01:42.240 align:start position:0%
# ついては、え、全部で10個です。え、1
# 00:01:42.240 --> 00:01:46.069 align:start position:0%
# ついては、え、全部で10個です。え、1
# 00:01:46.069 --> 00:01:46.079 align:start position:0%
# つ目は名前について、で、2つ目は出身地
# 00:01:46.079 --> 00:01:48.950 align:start position:0%
# つ目は名前について、で、2つ目は出身地
# 00:01:48.950 --> 00:01:48.960 align:start position:0%
# 、住んでいるところについて。そして3つ
# 00:01:48.960 --> 00:01:52.749 align:start position:0%
# 、住んでいるところについて。そして3つ
# 00:01:52.749 --> 00:01:52.759 align:start position:0%
# 目は、え、家族について。そして4つ目、
# 00:01:52.759 --> 00:01:56.469 align:start position:0%
# 目は、え、家族について。そして4つ目、
# 00:01:56.469 --> 00:01:56.479 align:start position:0%
# 好きなこと、趣味、特技。そして5つ目、
# 00:01:56.479 --> 00:02:00.469 align:start position:0%
# 好きなこと、趣味、特技。そして5つ目、
# 00:02:00.469 --> 00:02:00.479 align:start position:0%
# 苦手なこと。そして、え、6つ目、学歴
# 00:02:00.479 --> 00:02:04.749 align:start position:0%
# 苦手なこと。そして、え、6つ目、学歴
# 00:02:04.749 --> 00:02:04.759 align:start position:0%
# ですね。で、7つ目、性格。8つ目、今の
# 00:02:04.759 --> 00:02:07.310 align:start position:0%
# ですね。で、7つ目、性格。8つ目、今の
# 00:02:07.310 --> 00:02:07.320 align:start position:0%
# 仕事。そして、え、ここの爪、
# 00:02:07.320 --> 00:02:10.070 align:start position:0%
# 仕事。そして、え、ここの爪、
# 00:02:10.070 --> 00:02:10.080 align:start position:0%
# プライベート。そして最後はこれからの
# 00:02:10.080 --> 00:02:13.309 align:start position:0%
# プライベート。そして最後はこれからの
# 00:02:13.309 --> 00:02:13.319 align:start position:0%
# 目標ということで、ま、10個のテーマに
# 00:02:13.319 --> 00:02:16.509 align:start position:0%
# 目標ということで、ま、10個のテーマに
# 00:02:16.509 --> 00:02:16.519 align:start position:0%
# ついて1時間かけてのんびりと話していき
# 00:02:16.519 --> 00:02:20.190 align:start position:0%
# ついて1時間かけてのんびりと話していき
# 00:02:20.190 --> 00:02:20.200 align:start position:0%
# たいと思います。はい。で、早速始めて
# 00:02:20.200 --> 00:02:22.750 align:start position:0%
# たいと思います。はい。で、早速始めて
# 00:02:22.750 --> 00:02:22.760 align:start position:0%
# いきたいと思うんですけども、1つ目の
# 00:02:22.760 --> 00:02:25.390 align:start position:0%
# いきたいと思うんですけども、1つ目の
# 00:02:25.390 --> 00:02:25.400 align:start position:0%
# 名前ですね。
# 00:02:25.400 --> 00:02:29.309 align:start position:0%
# 名前ですね。
# 00:02:29.309 --> 00:02:29.319 align:start position:0%
# 僕の名前は裕介と言います。皆さんこれ
# 00:02:29.319 --> 00:02:33.110 align:start position:0%
# 僕の名前は裕介と言います。皆さんこれ
# 00:02:33.110 --> 00:02:33.120 align:start position:0%
# 知ってました?はい。あの、フルネームを
# 00:02:33.120 --> 00:02:35.509 align:start position:0%
# 知ってました?はい。あの、フルネームを
# 00:02:35.509 --> 00:02:35.519 align:start position:0%
# ね、YouTubeでアップロードするの
# 00:02:35.519 --> 00:02:39.190 align:start position:0%
# ね、YouTubeでアップロードするの
# 00:02:39.190 --> 00:02:39.200 align:start position:0%
# はちょっといさかあの抵抗があるところが
# 00:02:39.200 --> 00:02:41.589 align:start position:0%
# はちょっといさかあの抵抗があるところが
# 00:02:41.589 --> 00:02:41.599 align:start position:0%
# あるので名前だけにしたいと思うんですが
# 00:02:41.599 --> 00:02:44.910 align:start position:0%
# あるので名前だけにしたいと思うんですが
# 00:02:44.910 --> 00:02:44.920 align:start position:0%
# 名前はゆ介っています。感じなんですが、
# 00:02:44.920 --> 00:02:50.270 align:start position:0%
# 名前はゆ介っています。感じなんですが、
# 00:02:50.270 --> 00:02:50.280 align:start position:0%
# Uゆ自のUに、え、スケはあのゆ介とか他
# 00:02:50.280 --> 00:02:53.630 align:start position:0%
# Uゆ自のUに、え、スケはあのゆ介とか他
# 00:02:53.630 --> 00:02:53.640 align:start position:0%
# のね、え、皆さんがよく使う簡単な紹介の
# 00:02:53.640 --> 00:02:57.630 align:start position:0%
# のね、え、皆さんがよく使う簡単な紹介の
# 00:02:57.630 --> 00:02:57.640 align:start position:0%
# 回でスって書いて裕介っていう風に読み
# 00:02:57.640 --> 00:03:00.509 align:start position:0%
# 回でスって書いて裕介っていう風に読み
# 00:03:00.509 --> 00:03:00.519 align:start position:0%
# ます。ま、日本人の名前っていうのは
# 00:03:00.519 --> 00:03:02.830 align:start position:0%
# ます。ま、日本人の名前っていうのは
# 00:03:02.830 --> 00:03:02.840 align:start position:0%
# それぞれこう意味が込められてい
# 00:03:02.840 --> 00:03:04.589 align:start position:0%
# それぞれこう意味が込められてい
# 00:03:04.589 --> 00:03:04.599 align:start position:0%
# るっていうのはもう皆さん知っていると
# 00:03:04.599 --> 00:03:08.149 align:start position:0%
# るっていうのはもう皆さん知っていると
# 00:03:08.149 --> 00:03:08.159 align:start position:0%
# 思うんですけども、え、僕の名前は、え、
# 00:03:08.159 --> 00:03:11.509 align:start position:0%
# 思うんですけども、え、僕の名前は、え、
# 00:03:11.509 --> 00:03:11.519 align:start position:0%
# おばあちゃんがつけてくれました。で、
# 00:03:11.519 --> 00:03:14.910 align:start position:0%
# おばあちゃんがつけてくれました。で、
# 00:03:14.910 --> 00:03:14.920 align:start position:0%
# えっと、おばあちゃんがこの名前に込めた
# 00:03:14.920 --> 00:03:18.470 align:start position:0%
# えっと、おばあちゃんがこの名前に込めた
# 00:03:18.470 --> 00:03:18.480 align:start position:0%
# 思いっていうのは、えー、
# 00:03:18.480 --> 00:03:21.670 align:start position:0%
# 思いっていうのは、えー、
# 00:03:21.670 --> 00:03:21.680 align:start position:0%
# 次的に、ま、つまりのんびりと自分の
# 00:03:21.680 --> 00:03:25.509 align:start position:0%
# 次的に、ま、つまりのんびりと自分の
# 00:03:25.509 --> 00:03:25.519 align:start position:0%
# ペースでリラックスしてその過ごして
# 00:03:25.519 --> 00:03:28.110 align:start position:0%
# ペースでリラックスしてその過ごして
# 00:03:28.110 --> 00:03:28.120 align:start position:0%
# 欲しい、優しい男の子に、ま、育って欲し
# 00:03:28.120 --> 00:03:31.270 align:start position:0%
# 欲しい、優しい男の子に、ま、育って欲し
# 00:03:31.270 --> 00:03:31.280 align:start position:0%
# いっていう思いを込めて、え、裕介にした
# 00:03:31.280 --> 00:03:34.589 align:start position:0%
# いっていう思いを込めて、え、裕介にした
# 00:03:34.589 --> 00:03:34.599 align:start position:0%
# そうです。ま、これは僕が生まれた時にお
# 00:03:34.599 --> 00:03:36.949 align:start position:0%
# そうです。ま、これは僕が生まれた時にお
# 00:03:36.949 --> 00:03:36.959 align:start position:0%
# ばあちゃんに直接聞いたわけではなく、ま
# 00:03:36.959 --> 00:03:39.270 align:start position:0%
# ばあちゃんに直接聞いたわけではなく、ま
# 00:03:39.270 --> 00:03:39.280 align:start position:0%
# 、家族から、ま、そういうことがあった
# 00:03:39.280 --> 00:03:41.830 align:start position:0%
# 、家族から、ま、そういうことがあった
# 00:03:41.830 --> 00:03:41.840 align:start position:0%
# らしいよとか、おばあちゃんがそういう風
# 00:03:41.840 --> 00:03:43.589 align:start position:0%
# らしいよとか、おばあちゃんがそういう風
# 00:03:43.589 --> 00:03:43.599 align:start position:0%
# にね、あの、つけたんだよっておばあ
# 00:03:43.599 --> 00:03:46.470 align:start position:0%
# にね、あの、つけたんだよっておばあ
# 00:03:46.470 --> 00:03:46.480 align:start position:0%
# ちゃんに聞いた話なので、ま、あの、本当
# 00:03:46.480 --> 00:03:48.390 align:start position:0%
# ちゃんに聞いた話なので、ま、あの、本当
# 00:03:48.390 --> 00:03:48.400 align:start position:0%
# かどうかはね、分からないですけども、ま
# 00:03:48.400 --> 00:03:51.149 align:start position:0%
# かどうかはね、分からないですけども、ま
# 00:03:51.149 --> 00:03:51.159 align:start position:0%
# 、そういった意味で裕介っていう風に言い
# 00:03:51.159 --> 00:03:54.710 align:start position:0%
# 、そういった意味で裕介っていう風に言い
# 00:03:54.710 --> 00:03:54.720 align:start position:0%
# ます。この裕介っていうのはですね、本当
# 00:03:54.720 --> 00:03:58.069 align:start position:0%
# ます。この裕介っていうのはですね、本当
# 00:03:58.069 --> 00:03:58.079 align:start position:0%
# に日本人色々まあ、なんて言うんですか、
# 00:03:58.079 --> 00:04:01.350 align:start position:0%
# に日本人色々まあ、なんて言うんですか、
# 00:04:01.350 --> 00:04:01.360 align:start position:0%
# よくある名前なんですけども、ま、その中
# 00:04:01.360 --> 00:04:05.589 align:start position:0%
# よくある名前なんですけども、ま、その中
# 00:04:05.589 --> 00:04:05.599 align:start position:0%
# でもこの僕の漢字を使う裕介っていう名前
# 00:04:05.599 --> 00:04:08.550 align:start position:0%
# でもこの僕の漢字を使う裕介っていう名前
# 00:04:08.550 --> 00:04:08.560 align:start position:0%
# はですね、あんまりないんじゃないかなと
# 00:04:08.560 --> 00:04:12.229 align:start position:0%
# はですね、あんまりないんじゃないかなと
# 00:04:12.229 --> 00:04:12.239 align:start position:0%
# 思います。なんか話に聞くとこの僕のU
# 00:04:12.239 --> 00:04:16.349 align:start position:0%
# 思います。なんか話に聞くとこの僕のU
# 00:04:16.349 --> 00:04:16.359 align:start position:0%
# っていう感じは割と若い人にもう使うこと
# 00:04:16.359 --> 00:04:19.469 align:start position:0%
# っていう感じは割と若い人にもう使うこと
# 00:04:19.469 --> 00:04:19.479 align:start position:0%
# が多いらしくて、僕の世代ではあまり使わ
# 00:04:19.479 --> 00:04:22.430 align:start position:0%
# が多いらしくて、僕の世代ではあまり使わ
# 00:04:22.430 --> 00:04:22.440 align:start position:0%
# れない。ま、そういった感じで、ちょっと
# 00:04:22.440 --> 00:04:25.790 align:start position:0%
# れない。ま、そういった感じで、ちょっと
# 00:04:25.790 --> 00:04:25.800 align:start position:0%
# 特別感がね、昔からありました。そして
# 00:04:25.800 --> 00:04:29.469 align:start position:0%
# 特別感がね、昔からありました。そして
# 00:04:29.469 --> 00:04:29.479 align:start position:0%
# この裕介のUなんですけども、形としても
# 00:04:29.479 --> 00:04:33.189 align:start position:0%
# この裕介のUなんですけども、形としても
# 00:04:33.189 --> 00:04:33.199 align:start position:0%
# すごく綺麗だなって思うんですよ。下に心
# 00:04:33.199 --> 00:04:36.110 align:start position:0%
# すごく綺麗だなって思うんですよ。下に心
# 00:04:36.110 --> 00:04:36.120 align:start position:0%
# がある感じですね。あ、心があるという
# 00:04:36.120 --> 00:04:40.950 align:start position:0%
# がある感じですね。あ、心があるという
# 00:04:40.950 --> 00:04:40.960 align:start position:0%
# ことで、ま、すごく人間っぽい優しい感じ
# 00:04:40.960 --> 00:04:44.110 align:start position:0%
# ことで、ま、すごく人間っぽい優しい感じ
# 00:04:44.110 --> 00:04:44.120 align:start position:0%
# がする。うん。ま、勝てなくてもいいと、
# 00:04:44.120 --> 00:04:47.110 align:start position:0%
# がする。うん。ま、勝てなくてもいいと、
# 00:04:47.110 --> 00:04:47.120 align:start position:0%
# 人生が成功しなくてもいいけど、なんか
# 00:04:47.120 --> 00:04:49.110 align:start position:0%
# 人生が成功しなくてもいいけど、なんか
# 00:04:49.110 --> 00:04:49.120 align:start position:0%
# 優しく生きていきたい。そういう風に
# 00:04:49.120 --> 00:04:52.670 align:start position:0%
# 優しく生きていきたい。そういう風に
# 00:04:52.670 --> 00:04:52.680 align:start position:0%
# 思える素敵な名前だなと。あの自分の名前
# 00:04:52.680 --> 00:04:57.189 align:start position:0%
# 思える素敵な名前だなと。あの自分の名前
# 00:04:57.189 --> 00:04:57.199 align:start position:0%
# のことは大好きです。はい。で、え、次に
# 00:04:57.199 --> 00:05:00.110 align:start position:0%
# のことは大好きです。はい。で、え、次に
# 00:05:00.110 --> 00:05:00.120 align:start position:0%
# ですね、ま、皆さんが使っている
# 00:05:00.120 --> 00:05:03.189 align:start position:0%
# ですね、ま、皆さんが使っている
# 00:05:03.189 --> 00:05:03.199 align:start position:0%
# ニックネームゆですね。はい。もうお
# 00:05:03.199 --> 00:05:06.629 align:start position:0%
# ニックネームゆですね。はい。もうお
# 00:05:06.629 --> 00:05:06.639 align:start position:0%
# 気づきの方もいると思うんですが、ゆ介だ
# 00:05:06.639 --> 00:05:10.629 align:start position:0%
# 気づきの方もいると思うんですが、ゆ介だ
# 00:05:10.629 --> 00:05:10.639 align:start position:0%
# からゆゆっていう風にしました。ま、これ
# 00:05:10.639 --> 00:05:13.870 align:start position:0%
# からゆゆっていう風にしました。ま、これ
# 00:05:13.870 --> 00:05:13.880 align:start position:0%
# はあの色々な意味の部分もありまして、え
# 00:05:13.880 --> 00:05:17.510 align:start position:0%
# はあの色々な意味の部分もありまして、え
# 00:05:17.510 --> 00:05:17.520 align:start position:0%
# 、つまり僕のこの裕介のUっていうのは
# 00:05:17.520 --> 00:05:20.029 align:start position:0%
# 、つまり僕のこの裕介のUっていうのは
# 00:05:20.029 --> 00:05:20.039 align:start position:0%
# リラックスして自分のペースでっていう
# 00:05:20.039 --> 00:05:23.749 align:start position:0%
# リラックスして自分のペースでっていう
# 00:05:23.749 --> 00:05:23.759 align:start position:0%
# 意味があります。で、皆さんにもその日本
# 00:05:23.759 --> 00:05:27.990 align:start position:0%
# 意味があります。で、皆さんにもその日本
# 00:05:27.990 --> 00:05:28.000 align:start position:0%
# 語の勉強を自分のペースでリラックスして
# 00:05:28.000 --> 00:05:30.189 align:start position:0%
# 語の勉強を自分のペースでリラックスして
# 00:05:30.189 --> 00:05:30.199 align:start position:0%
# やってもらえたらいいなってずっと思って
# 00:05:30.199 --> 00:05:33.550 align:start position:0%
# やってもらえたらいいなってずっと思って
# 00:05:33.550 --> 00:05:33.560 align:start position:0%
# いて、で、このゆאゆっていうのがいいん
# 00:05:33.560 --> 00:05:35.950 align:start position:0%
# いて、で、このゆאゆっていうのがいいん
# 00:05:35.950 --> 00:05:35.960 align:start position:0%
# じゃないかなっていう風に決めました。で
# 00:05:35.960 --> 00:05:39.150 align:start position:0%
# じゃないかなっていう風に決めました。で
# 00:05:39.150 --> 00:05:39.160 align:start position:0%
# 、ま、この名前をつけたのも、え、今から
# 00:05:39.160 --> 00:05:41.469 align:start position:0%
# 、ま、この名前をつけたのも、え、今から
# 00:05:41.469 --> 00:05:41.479 align:start position:0%
# 5年前、ちょうどこのポッドキャストだっ
# 00:05:41.479 --> 00:05:43.950 align:start position:0%
# 5年前、ちょうどこのポッドキャストだっ
# 00:05:43.950 --> 00:05:43.960 align:start position:0%
# たりとか、あとはゆ日日本語っていう自分
# 00:05:43.960 --> 00:05:46.909 align:start position:0%
# たりとか、あとはゆ日日本語っていう自分
# 00:05:46.909 --> 00:05:46.919 align:start position:0%
# のプロジェクトを立ち上げる時に裕介って
# 00:05:46.919 --> 00:05:50.629 align:start position:0%
# のプロジェクトを立ち上げる時に裕介って
# 00:05:50.629 --> 00:05:50.639 align:start position:0%
# いう名前でそのネットに自分のね、え、
# 00:05:50.639 --> 00:05:54.270 align:start position:0%
# いう名前でそのネットに自分のね、え、
# 00:05:54.270 --> 00:05:54.280 align:start position:0%
# 存在をま、出すっていうのはどうなん
# 00:05:54.280 --> 00:05:56.830 align:start position:0%
# 存在をま、出すっていうのはどうなん
# 00:05:56.830 --> 00:05:56.840 align:start position:0%
# だろうな。せっかくだからみんなが覚え
# 00:05:56.840 --> 00:05:58.749 align:start position:0%
# だろうな。せっかくだからみんなが覚え
# 00:05:58.749 --> 00:05:58.759 align:start position:0%
# やすいニックネームみたいなのがあると
# 00:05:58.759 --> 00:06:01.870 align:start position:0%
# やすいニックネームみたいなのがあると
# 00:06:01.870 --> 00:06:01.880 align:start position:0%
# いいなっていう、ま、そういった話になり
# 00:06:01.880 --> 00:06:06.830 align:start position:0%
# いいなっていう、ま、そういった話になり
# 00:06:06.830 --> 00:06:06.840 align:start position:0%
# まして。で、その時にいろんな候補があっ
# 00:06:06.840 --> 00:06:11.230 align:start position:0%
# まして。で、その時にいろんな候補があっ
# 00:06:11.230 --> 00:06:11.240 align:start position:0%
# たんですけども、UっていうYuYuって
# 00:06:11.240 --> 00:06:13.749 align:start position:0%
# たんですけども、UっていうYuYuって
# 00:06:13.749 --> 00:06:13.759 align:start position:0%
# いう風に書く
# 00:06:13.759 --> 00:06:18.510 align:start position:0%
# いう風に書く
# 00:06:18.510 --> 00:06:18.520 align:start position:0%
# 名前、ま、そういう風な活動名で活動して
# 00:06:18.520 --> 00:06:22.110 align:start position:0%
# 名前、ま、そういう風な活動名で活動して
# 00:06:22.110 --> 00:06:22.120 align:start position:0%
# いる人がその当時5年前には
# 00:06:22.120 --> 00:06:24.430 align:start position:0%
# いる人がその当時5年前には
# 00:06:24.430 --> 00:06:24.440 align:start position:0%
# YouTubeにいなかったんですよね。
# 00:06:24.440 --> 00:06:29.189 align:start position:0%
# YouTubeにいなかったんですよね。
# 00:06:29.189 --> 00:06:29.199 align:start position:0%
# なので、こうちょっと戦略的なあの意味も
# 00:06:29.199 --> 00:06:33.510 align:start position:0%
# なので、こうちょっと戦略的なあの意味も
# 00:06:33.510 --> 00:06:33.520 align:start position:0%
# あって、ま、皆さんが呼びやすい、覚え
# 00:06:33.520 --> 00:06:35.870 align:start position:0%
# あって、ま、皆さんが呼びやすい、覚え
# 00:06:35.870 --> 00:06:35.880 align:start position:0%
# やすい、そして文字として見て分かり
# 00:06:35.880 --> 00:06:40.589 align:start position:0%
# やすい、そして文字として見て分かり
# 00:06:40.589 --> 00:06:40.599 align:start position:0%
# やすいで調べる時にゆゆって調べたら僕が
# 00:06:40.599 --> 00:06:44.309 align:start position:0%
# やすいで調べる時にゆゆって調べたら僕が
# 00:06:44.309 --> 00:06:44.319 align:start position:0%
# 出てくる可能性が高いっていうのでこの
# 00:06:44.319 --> 00:06:47.029 align:start position:0%
# 出てくる可能性が高いっていうのでこの
# 00:06:47.029 --> 00:06:47.039 align:start position:0%
# ゆuユっていう名前をつけました。はい。
# 00:06:47.039 --> 00:06:50.110 align:start position:0%
# ゆuユっていう名前をつけました。はい。
# 00:06:50.110 --> 00:06:50.120 align:start position:0%
# ま、アルファベットで書くとyuyuって
# 00:06:50.120 --> 00:06:54.430 align:start position:0%
# ま、アルファベットで書くとyuyuって
# 00:06:54.430 --> 00:06:54.440 align:start position:0%
# 書くんですが、え、元々の名前が裕介から
# 00:06:54.440 --> 00:06:58.029 align:start position:0%
# 書くんですが、え、元々の名前が裕介から
# 00:06:58.029 --> 00:06:58.039 align:start position:0%
# 来ているので、あの、ひらがで書くとゆう
# 00:06:58.039 --> 00:07:03.029 align:start position:0%
# 来ているので、あの、ひらがで書くとゆう
# 00:07:03.029 --> 00:07:03.039 align:start position:0%
# ゆうっていう風に、あの、書くっていう僕
# 00:07:03.039 --> 00:07:06.110 align:start position:0%
# ゆうっていう風に、あの、書くっていう僕
# 00:07:06.110 --> 00:07:06.120 align:start position:0%
# の中ではそういう理解があって、ま、あの
# 00:07:06.120 --> 00:07:09.070 align:start position:0%
# の中ではそういう理解があって、ま、あの
# 00:07:09.070 --> 00:07:09.080 align:start position:0%
# 、もちろんですけども、YU、Yuだとゆ
# 00:07:09.080 --> 00:07:11.430 align:start position:0%
# 、もちろんですけども、YU、Yuだとゆ
# 00:07:11.430 --> 00:07:11.440 align:start position:0%
# になるので、え、いろんなYouTube
# 00:07:11.440 --> 00:07:14.070 align:start position:0%
# になるので、え、いろんなYouTube
# 00:07:14.070 --> 00:07:14.080 align:start position:0%
# のコメントでね、ゆ先生っていう風に、
# 00:07:14.080 --> 00:07:17.550 align:start position:0%
# のコメントでね、ゆ先生っていう風に、
# 00:07:17.550 --> 00:07:17.560 align:start position:0%
# あの、ま、書かれる方が多いんですけども
# 00:07:17.560 --> 00:07:22.390 align:start position:0%
# あの、ま、書かれる方が多いんですけども
# 00:07:22.390 --> 00:07:22.400 align:start position:0%
# 、ま、正確に言うとU先生になるかなと
# 00:07:22.400 --> 00:07:25.830 align:start position:0%
# 、ま、正確に言うとU先生になるかなと
# 00:07:25.830 --> 00:07:25.840 align:start position:0%
# 思います。ま、あの、ま、正直ね、
# 00:07:25.840 --> 00:07:28.710 align:start position:0%
# 思います。ま、あの、ま、正直ね、
# 00:07:28.710 --> 00:07:28.720 align:start position:0%
# ニックネームですので、あの、どうでも
# 00:07:28.720 --> 00:07:30.990 align:start position:0%
# ニックネームですので、あの、どうでも
# 00:07:30.990 --> 00:07:31.000 align:start position:0%
# いいんですけどもね、あの、もし、え、僕
# 00:07:31.000 --> 00:07:33.510 align:start position:0%
# いいんですけどもね、あの、もし、え、僕
# 00:07:33.510 --> 00:07:33.520 align:start position:0%
# の名前をひらがで書きたいっていう方は、
# 00:07:33.520 --> 00:07:37.270 align:start position:0%
# の名前をひらがで書きたいっていう方は、
# 00:07:37.270 --> 00:07:37.280 align:start position:0%
# え、音を伸ばして4文字ゆうゆうって書い
# 00:07:37.280 --> 00:07:41.110 align:start position:0%
# え、音を伸ばして4文字ゆうゆうって書い
# 00:07:41.110 --> 00:07:41.120 align:start position:0%
# てくれると嬉しいなと思います。はい。で
# 00:07:41.120 --> 00:07:43.189 align:start position:0%
# てくれると嬉しいなと思います。はい。で
# 00:07:43.189 --> 00:07:43.199 align:start position:0%
# 、ま、ちょっと名前つがりでですね。えっ
# 00:07:43.199 --> 00:07:48.309 align:start position:0%
# 、ま、ちょっと名前つがりでですね。えっ
# 00:07:48.309 --> 00:07:48.319 align:start position:0%
# と、僕のその活動名、え、ゆをひらがで
# 00:07:48.319 --> 00:07:51.230 align:start position:0%
# と、僕のその活動名、え、ゆをひらがで
# 00:07:51.230 --> 00:07:51.240 align:start position:0%
# ゆゆって書いてもゆって書いてもそれは
# 00:07:51.240 --> 00:07:54.270 align:start position:0%
# ゆゆって書いてもゆって書いてもそれは
# 00:07:54.270 --> 00:07:54.280 align:start position:0%
# いいんですけども、あのゆ介っていう名前
# 00:07:54.280 --> 00:07:57.790 align:start position:0%
# いいんですけども、あのゆ介っていう名前
# 00:07:57.790 --> 00:07:57.800 align:start position:0%
# をあのコメントで、え、書いてくれる場合
# 00:07:57.800 --> 00:08:01.309 align:start position:0%
# をあのコメントで、え、書いてくれる場合
# 00:08:01.309 --> 00:08:01.319 align:start position:0%
# は、あの、是非僕の感じ、このね、有々児
# 00:08:01.319 --> 00:08:04.830 align:start position:0%
# は、あの、是非僕の感じ、このね、有々児
# 00:08:04.830 --> 00:08:04.840 align:start position:0%
# 的のUを使って書いてくれると嬉しいです
# 00:08:04.840 --> 00:08:09.029 align:start position:0%
# 的のUを使って書いてくれると嬉しいです
# 00:08:09.029 --> 00:08:09.039 align:start position:0%
# 。うん。あの、他の感じで書かれてしまう
# 00:08:09.039 --> 00:08:12.149 align:start position:0%
# 。うん。あの、他の感じで書かれてしまう
# 00:08:12.149 --> 00:08:12.159 align:start position:0%
# となんか他の人みたいな自分に書かれてな
# 00:08:12.159 --> 00:08:14.629 align:start position:0%
# となんか他の人みたいな自分に書かれてな
# 00:08:14.629 --> 00:08:14.639 align:start position:0%
# いっていう気持ちがするんですよね。で、
# 00:08:14.639 --> 00:08:16.749 align:start position:0%
# いっていう気持ちがするんですよね。で、
# 00:08:16.749 --> 00:08:16.759 align:start position:0%
# ま、これちょっと日本語のアドバイスなん
# 00:08:16.759 --> 00:08:19.430 align:start position:0%
# ま、これちょっと日本語のアドバイスなん
# 00:08:19.430 --> 00:08:19.440 align:start position:0%
# ですけども、え、日本人のお友達がいると
# 00:08:19.440 --> 00:08:22.670 align:start position:0%
# ですけども、え、日本人のお友達がいると
# 00:08:22.670 --> 00:08:22.680 align:start position:0%
# 。で、その人の名前の発音は分かるんだ
# 00:08:22.680 --> 00:08:25.670 align:start position:0%
# 。で、その人の名前の発音は分かるんだ
# 00:08:25.670 --> 00:08:25.680 align:start position:0%
# けども、漢字が分からない場合、この場合
# 00:08:25.680 --> 00:08:28.230 align:start position:0%
# けども、漢字が分からない場合、この場合
# 00:08:28.230 --> 00:08:28.240 align:start position:0%
# は基本的にはひらがで書いてしまって
# 00:08:28.240 --> 00:08:31.350 align:start position:0%
# は基本的にはひらがで書いてしまって
# 00:08:31.350 --> 00:08:31.360 align:start position:0%
# 大丈夫です。で、ビジネスの場面では
# 00:08:31.360 --> 00:08:34.469 align:start position:0%
# 大丈夫です。で、ビジネスの場面では
# 00:08:34.469 --> 00:08:34.479 align:start position:0%
# カタカナで書く場合もあります。まあ、
# 00:08:34.479 --> 00:08:37.870 align:start position:0%
# カタカナで書く場合もあります。まあ、
# 00:08:37.870 --> 00:08:37.880 align:start position:0%
# どっちにしても、あの、そのお友達だっ
# 00:08:37.880 --> 00:08:40.949 align:start position:0%
# どっちにしても、あの、そのお友達だっ
# 00:08:40.949 --> 00:08:40.959 align:start position:0%
# たりとか、取引先だったり先輩ね、その
# 00:08:40.959 --> 00:08:44.230 align:start position:0%
# たりとか、取引先だったり先輩ね、その
# 00:08:44.230 --> 00:08:44.240 align:start position:0%
# 日本人の名前の感じをしっかり覚えてお
# 00:08:44.240 --> 00:08:46.590 align:start position:0%
# 日本人の名前の感じをしっかり覚えてお
# 00:08:46.590 --> 00:08:46.600 align:start position:0%
# くっていうのはすごく大切なことになり
# 00:08:46.600 --> 00:08:49.670 align:start position:0%
# くっていうのはすごく大切なことになり
# 00:08:49.670 --> 00:08:49.680 align:start position:0%
# ますし、覚えて損はないと思いますので、
# 00:08:49.680 --> 00:08:52.389 align:start position:0%
# ますし、覚えて損はないと思いますので、
# 00:08:52.389 --> 00:08:52.399 align:start position:0%
# ま、是非ぜひぜ非ぜ非ぜひぜひ
# 00:08:52.399 --> 00:08:55.670 align:start position:0%
# ま、是非ぜひぜ非ぜ非ぜひぜひ
# 00:08:55.670 --> 00:08:55.680 align:start position:0%
# 覚えといてください。はい。これが名前
# 00:08:55.680 --> 00:08:59.790 align:start position:0%
# 覚えといてください。はい。これが名前
# 00:08:59.790 --> 00:08:59.800 align:start position:0%
# ですね。で、次なんですが出身地です。
# 00:08:59.800 --> 00:09:03.230 align:start position:0%
# ですね。で、次なんですが出身地です。
# 00:09:03.230 --> 00:09:03.240 align:start position:0%
# 出身地は埼玉県。ま、僕は埼玉県で生まれ
# 00:09:03.240 --> 00:09:06.389 align:start position:0%
# 出身地は埼玉県。ま、僕は埼玉県で生まれ
# 00:09:06.389 --> 00:09:06.399 align:start position:0%
# ました。そして、えっと、埼玉県で育った
# 00:09:06.399 --> 00:09:09.550 align:start position:0%
# ました。そして、えっと、埼玉県で育った
# 00:09:09.550 --> 00:09:09.560 align:start position:0%
# んですけども、あの、そう、そう、そう、
# 00:09:09.560 --> 00:09:11.150 align:start position:0%
# んですけども、あの、そう、そう、そう、
# 00:09:11.150 --> 00:09:11.160 align:start position:0%
# そう。ま、これはね、ちょ皆さんに
# 00:09:11.160 --> 00:09:13.509 align:start position:0%
# そう。ま、これはね、ちょ皆さんに
# 00:09:13.509 --> 00:09:13.519 align:start position:0%
# しっかり言っておきたいんですが、日本人
# 00:09:13.519 --> 00:09:18.110 align:start position:0%
# しっかり言っておきたいんですが、日本人
# 00:09:18.110 --> 00:09:18.120 align:start position:0%
# です。はい。日本で生まれました。あの、
# 00:09:18.120 --> 00:09:20.550 align:start position:0%
# です。はい。日本で生まれました。あの、
# 00:09:20.550 --> 00:09:20.560 align:start position:0%
# 中にはコメントでね、裕介って日本人
# 00:09:20.560 --> 00:09:23.069 align:start position:0%
# 中にはコメントでね、裕介って日本人
# 00:09:23.069 --> 00:09:23.079 align:start position:0%
# なのっていう風には書く方いるんですけど
# 00:09:23.079 --> 00:09:26.710 align:start position:0%
# なのっていう風には書く方いるんですけど
# 00:09:26.710 --> 00:09:26.720 align:start position:0%
# も、あのコメントが1番傷つくかな。うん
# 00:09:26.720 --> 00:09:29.269 align:start position:0%
# も、あのコメントが1番傷つくかな。うん
# 00:09:29.269 --> 00:09:29.279 align:start position:0%
# 。え、なんか自分が日本人じゃないって
# 00:09:29.279 --> 00:09:31.069 align:start position:0%
# 。え、なんか自分が日本人じゃないって
# 00:09:31.069 --> 00:09:31.079 align:start position:0%
# いうのはなんかアイデンティティがないと
# 00:09:31.079 --> 00:09:34.190 align:start position:0%
# いうのはなんかアイデンティティがないと
# 00:09:34.190 --> 00:09:34.200 align:start position:0%
# か自分の家族が日本にいるのに自分だけ
# 00:09:34.200 --> 00:09:36.430 align:start position:0%
# か自分の家族が日本にいるのに自分だけ
# 00:09:36.430 --> 00:09:36.440 align:start position:0%
# 外国人になっちゃったのみたいな気持ちに
# 00:09:36.440 --> 00:09:39.509 align:start position:0%
# 外国人になっちゃったのみたいな気持ちに
# 00:09:39.509 --> 00:09:39.519 align:start position:0%
# なるので、あの柚介は日本人だよと。うん
# 00:09:39.519 --> 00:09:43.350 align:start position:0%
# なるので、あの柚介は日本人だよと。うん
# 00:09:43.350 --> 00:09:43.360 align:start position:0%
# 。是非ぜひあの皆さんね、あのゆの日本語
# 00:09:43.360 --> 00:09:45.870 align:start position:0%
# 。是非ぜひあの皆さんね、あのゆの日本語
# 00:09:45.870 --> 00:09:45.880 align:start position:0%
# ポッドキャストファンのお友達がいたら
# 00:09:45.880 --> 00:09:47.630 align:start position:0%
# ポッドキャストファンのお友達がいたら
# 00:09:47.630 --> 00:09:47.640 align:start position:0%
# ゆって日本人だよってこな間だ
# 00:09:47.640 --> 00:09:49.389 align:start position:0%
# ゆって日本人だよってこな間だ
# 00:09:49.389 --> 00:09:49.399 align:start position:0%
# ポッドキャストで言ってたよねっていう風
# 00:09:49.399 --> 00:09:53.110 align:start position:0%
# ポッドキャストで言ってたよねっていう風
# 00:09:53.110 --> 00:09:53.120 align:start position:0%
# にあの少しでも皆さんに裕介は日本人だ
# 00:09:53.120 --> 00:09:55.630 align:start position:0%
# にあの少しでも皆さんに裕介は日本人だ
# 00:09:55.630 --> 00:09:55.640 align:start position:0%
# よっていうのを広めてくれると嬉しいなと
# 00:09:55.640 --> 00:09:58.190 align:start position:0%
# よっていうのを広めてくれると嬉しいなと
# 00:09:58.190 --> 00:09:58.200 align:start position:0%
# 思います。はい。ま、話は戻りまして、
# 00:09:58.200 --> 00:10:01.870 align:start position:0%
# 思います。はい。ま、話は戻りまして、
# 00:10:01.870 --> 00:10:01.880 align:start position:0%
# 出身地は埼玉県です。え、東京の北にある
# 00:10:01.880 --> 00:10:05.550 align:start position:0%
# 出身地は埼玉県です。え、東京の北にある
# 00:10:05.550 --> 00:10:05.560 align:start position:0%
# ところですね。あの、ま、日本では東京の
# 00:10:05.560 --> 00:10:07.829 align:start position:0%
# ところですね。あの、ま、日本では東京の
# 00:10:07.829 --> 00:10:07.839 align:start position:0%
# ベッドタウン、ま、つまり東京で働いて
# 00:10:07.839 --> 00:10:11.430 align:start position:0%
# ベッドタウン、ま、つまり東京で働いて
# 00:10:11.430 --> 00:10:11.440 align:start position:0%
# いる人の住む家がある町、ま、として有名
# 00:10:11.440 --> 00:10:13.310 align:start position:0%
# いる人の住む家がある町、ま、として有名
# 00:10:13.310 --> 00:10:13.320 align:start position:0%
# なところなんですけども、ま、そこで
# 00:10:13.320 --> 00:10:16.230 align:start position:0%
# なところなんですけども、ま、そこで
# 00:10:16.230 --> 00:10:16.240 align:start position:0%
# 生まれ育ちました。ただですね、あの、
# 00:10:16.240 --> 00:10:20.750 align:start position:0%
# 生まれ育ちました。ただですね、あの、
# 00:10:20.750 --> 00:10:20.760 align:start position:0%
# お父さんの会社の、え、都合上ね、え、
# 00:10:20.760 --> 00:10:24.790 align:start position:0%
# お父さんの会社の、え、都合上ね、え、
# 00:10:24.790 --> 00:10:24.800 align:start position:0%
# 色々なところを引っ越してとしてきた、ま
# 00:10:24.800 --> 00:10:27.750 align:start position:0%
# 色々なところを引っ越してとしてきた、ま
# 00:10:27.750 --> 00:10:27.760 align:start position:0%
# 、そういった経緯もあります。え、生まれ
# 00:10:27.760 --> 00:10:32.269 align:start position:0%
# 、そういった経緯もあります。え、生まれ
# 00:10:32.269 --> 00:10:32.279 align:start position:0%
# てからすぐですね、どうも栃木県の小山市
# 00:10:32.279 --> 00:10:34.790 align:start position:0%
# てからすぐですね、どうも栃木県の小山市
# 00:10:34.790 --> 00:10:34.800 align:start position:0%
# っていうところに住んでいたそうです。で
# 00:10:34.800 --> 00:10:37.670 align:start position:0%
# っていうところに住んでいたそうです。で
# 00:10:37.670 --> 00:10:37.680 align:start position:0%
# 、なんかそこでね、色々ななんか問題が
# 00:10:37.680 --> 00:10:40.670 align:start position:0%
# 、なんかそこでね、色々ななんか問題が
# 00:10:40.670 --> 00:10:40.680 align:start position:0%
# あったらしくて、で、埼玉県に戻ってきて
# 00:10:40.680 --> 00:10:46.829 align:start position:0%
# あったらしくて、で、埼玉県に戻ってきて
# 00:10:46.829 --> 00:10:46.839 align:start position:0%
# 、で、そこから幼稚園、小学校までは埼玉
# 00:10:46.839 --> 00:10:51.110 align:start position:0%
# 、で、そこから幼稚園、小学校までは埼玉
# 00:10:51.110 --> 00:10:51.120 align:start position:0%
# 県にいました。で、小学校6年生、自分が
# 00:10:51.120 --> 00:10:56.069 align:start position:0%
# 県にいました。で、小学校6年生、自分が
# 00:10:56.069 --> 00:10:56.079 align:start position:0%
# 12歳の時だったかなに静岡県に引っ越す
# 00:10:56.079 --> 00:10:58.990 align:start position:0%
# 12歳の時だったかなに静岡県に引っ越す
# 00:10:58.990 --> 00:10:59.000 align:start position:0%
# ことになります。これもお父さんの仕事の
# 00:10:59.000 --> 00:11:02.790 align:start position:0%
# ことになります。これもお父さんの仕事の
# 00:11:02.790 --> 00:11:02.800 align:start position:0%
# 都合だったんですね。で、えっと、中学校
# 00:11:02.800 --> 00:11:06.470 align:start position:0%
# 都合だったんですね。で、えっと、中学校
# 00:11:06.470 --> 00:11:06.480 align:start position:0%
# 高校の時は6年間静岡県に住んでいました
# 00:11:06.480 --> 00:11:10.590 align:start position:0%
# 高校の時は6年間静岡県に住んでいました
# 00:11:10.590 --> 00:11:10.600 align:start position:0%
# 。で、高校を卒業して今度大学に行く。
# 00:11:10.600 --> 00:11:13.829 align:start position:0%
# 。で、高校を卒業して今度大学に行く。
# 00:11:13.829 --> 00:11:13.839 align:start position:0%
# 大学は東京にあったので、え、埼玉県のお
# 00:11:13.839 --> 00:11:15.710 align:start position:0%
# 大学は東京にあったので、え、埼玉県のお
# 00:11:15.710 --> 00:11:15.720 align:start position:0%
# じいちゃんおばあちゃんの家に住んでいて
# 00:11:15.720 --> 00:11:19.590 align:start position:0%
# じいちゃんおばあちゃんの家に住んでいて
# 00:11:19.590 --> 00:11:19.600 align:start position:0%
# 、で、その後にメキシコに移住しました。
# 00:11:19.600 --> 00:11:22.590 align:start position:0%
# 、で、その後にメキシコに移住しました。
# 00:11:22.590 --> 00:11:22.600 align:start position:0%
# なので、えっと、メキシコに来たのが僕が
# 00:11:22.600 --> 00:11:27.230 align:start position:0%
# なので、えっと、メキシコに来たのが僕が
# 00:11:27.230 --> 00:11:27.240 align:start position:0%
# 22歳の時で、今僕が35歳、36歳かな
# 00:11:27.240 --> 00:11:30.470 align:start position:0%
# 22歳の時で、今僕が35歳、36歳かな
# 00:11:30.470 --> 00:11:30.480 align:start position:0%
# ので、ま、約13年間メキシコに住んでい
# 00:11:30.480 --> 00:11:34.509 align:start position:0%
# ので、ま、約13年間メキシコに住んでい
# 00:11:34.509 --> 00:11:34.519 align:start position:0%
# ます。僕の今住んでいるメキシコの町なん
# 00:11:34.519 --> 00:11:37.389 align:start position:0%
# ます。僕の今住んでいるメキシコの町なん
# 00:11:37.389 --> 00:11:37.399 align:start position:0%
# ですけど、具アダラハ原。すごい難しい
# 00:11:37.399 --> 00:11:40.310 align:start position:0%
# ですけど、具アダラハ原。すごい難しい
# 00:11:40.310 --> 00:11:40.320 align:start position:0%
# 名前ですよね。僕も覚えるの苦労したん
# 00:11:40.320 --> 00:11:43.389 align:start position:0%
# 名前ですよね。僕も覚えるの苦労したん
# 00:11:43.389 --> 00:11:43.399 align:start position:0%
# ですが、グアダラハ原っていうところで、
# 00:11:43.399 --> 00:11:46.190 align:start position:0%
# ですが、グアダラハ原っていうところで、
# 00:11:46.190 --> 00:11:46.200 align:start position:0%
# え、メキシコの第2の都市として、ま、
# 00:11:46.200 --> 00:11:49.629 align:start position:0%
# え、メキシコの第2の都市として、ま、
# 00:11:49.629 --> 00:11:49.639 align:start position:0%
# 知られています。そうですね。すごく
# 00:11:49.639 --> 00:11:53.430 align:start position:0%
# 知られています。そうですね。すごく
# 00:11:53.430 --> 00:11:53.440 align:start position:0%
# 大きい街ではあるんですけども、その
# 00:11:53.440 --> 00:11:57.030 align:start position:0%
# 大きい街ではあるんですけども、その
# 00:11:57.030 --> 00:11:57.040 align:start position:0%
# ビジネスの町ではないので、雰囲気的には
# 00:11:57.040 --> 00:12:00.310 align:start position:0%
# ビジネスの町ではないので、雰囲気的には
# 00:12:00.310 --> 00:12:00.320 align:start position:0%
# ちょっと村というか、田舎みたいな雰囲気
# 00:12:00.320 --> 00:12:03.750 align:start position:0%
# ちょっと村というか、田舎みたいな雰囲気
# 00:12:03.750 --> 00:12:03.760 align:start position:0%
# がある。そういうなんか働いている人が
# 00:12:03.760 --> 00:12:06.829 align:start position:0%
# がある。そういうなんか働いている人が
# 00:12:06.829 --> 00:12:06.839 align:start position:0%
# 毎日こう東京みたいにたくさん歩いていて
# 00:12:06.839 --> 00:12:09.750 align:start position:0%
# 毎日こう東京みたいにたくさん歩いていて
# 00:12:09.750 --> 00:12:09.760 align:start position:0%
# 、街のスピードがすごく早い、生活の
# 00:12:09.760 --> 00:12:13.069 align:start position:0%
# 、街のスピードがすごく早い、生活の
# 00:12:13.069 --> 00:12:13.079 align:start position:0%
# リズムがすごく早い、大変な街ではないっ
# 00:12:13.079 --> 00:12:15.790 align:start position:0%
# リズムがすごく早い、大変な街ではないっ
# 00:12:15.790 --> 00:12:15.800 align:start position:0%
# ていううん。そういったなんか不思議な
# 00:12:15.800 --> 00:12:18.949 align:start position:0%
# ていううん。そういったなんか不思議な
# 00:12:18.949 --> 00:12:18.959 align:start position:0%
# 大きな町なのにちょっと田舎の雰囲気が
# 00:12:18.959 --> 00:12:21.910 align:start position:0%
# 大きな町なのにちょっと田舎の雰囲気が
# 00:12:21.910 --> 00:12:21.920 align:start position:0%
# ある不思議なところです。で、あの
# 00:12:21.920 --> 00:12:25.310 align:start position:0%
# ある不思議なところです。で、あの
# 00:12:25.310 --> 00:12:25.320 align:start position:0%
# グアダラハ原はとても古い町でその
# 00:12:25.320 --> 00:12:27.870 align:start position:0%
# グアダラハ原はとても古い町でその
# 00:12:27.870 --> 00:12:27.880 align:start position:0%
# メキシコっていう国は、え、スペインの
# 00:12:27.880 --> 00:12:30.670 align:start position:0%
# メキシコっていう国は、え、スペインの
# 00:12:30.670 --> 00:12:30.680 align:start position:0%
# 植民地だった時代があるんですね。ていう
# 00:12:30.680 --> 00:12:33.910 align:start position:0%
# 植民地だった時代があるんですね。ていう
# 00:12:33.910 --> 00:12:33.920 align:start position:0%
# ことで、そういう大きな町の中心街は
# 00:12:33.920 --> 00:12:37.870 align:start position:0%
# ことで、そういう大きな町の中心街は
# 00:12:37.870 --> 00:12:37.880 align:start position:0%
# ヨーロッパ風の建物がたくさんあります。
# 00:12:37.880 --> 00:12:41.790 align:start position:0%
# ヨーロッパ風の建物がたくさんあります。
# 00:12:41.790 --> 00:12:41.800 align:start position:0%
# うん。なのでね、メキシコの中心街を歩い
# 00:12:41.800 --> 00:12:44.550 align:start position:0%
# うん。なのでね、メキシコの中心街を歩い
# 00:12:44.550 --> 00:12:44.560 align:start position:0%
# ていると、あれ、僕は今ヨーロッパにいる
# 00:12:44.560 --> 00:12:47.910 align:start position:0%
# ていると、あれ、僕は今ヨーロッパにいる
# 00:12:47.910 --> 00:12:47.920 align:start position:0%
# のかな?ていった錯覚に陥る。なんかそう
# 00:12:47.920 --> 00:12:50.710 align:start position:0%
# のかな?ていった錯覚に陥る。なんかそう
# 00:12:50.710 --> 00:12:50.720 align:start position:0%
# いう風にこうなんか間違えて理解して
# 00:12:50.720 --> 00:12:53.670 align:start position:0%
# いう風にこうなんか間違えて理解して
# 00:12:53.670 --> 00:12:53.680 align:start position:0%
# しまう、錯覚に陥ってしまう、そういった
# 00:12:53.680 --> 00:12:57.670 align:start position:0%
# しまう、錯覚に陥ってしまう、そういった
# 00:12:57.670 --> 00:12:57.680 align:start position:0%
# 綺麗な街並もあるところです。はい。ね、
# 00:12:57.680 --> 00:12:59.750 align:start position:0%
# 綺麗な街並もあるところです。はい。ね、
# 00:12:59.750 --> 00:12:59.760 align:start position:0%
# あのメキシコのね、グアダラ原に住んで
# 00:12:59.760 --> 00:13:02.870 align:start position:0%
# あのメキシコのね、グアダラ原に住んで
# 00:13:02.870 --> 00:13:02.880 align:start position:0%
# いるんですけども、そののんびりした
# 00:13:02.880 --> 00:13:06.509 align:start position:0%
# いるんですけども、そののんびりした
# 00:13:06.509 --> 00:13:06.519 align:start position:0%
# 雰囲気でも大きい町、そして中心街は
# 00:13:06.519 --> 00:13:09.470 align:start position:0%
# 雰囲気でも大きい町、そして中心街は
# 00:13:09.470 --> 00:13:09.480 align:start position:0%
# ヨーロッパの街並があってすごく綺麗な
# 00:13:09.480 --> 00:13:11.910 align:start position:0%
# ヨーロッパの街並があってすごく綺麗な
# 00:13:11.910 --> 00:13:11.920 align:start position:0%
# ところ。うん。ま、そういったいいところ
# 00:13:11.920 --> 00:13:15.910 align:start position:0%
# ところ。うん。ま、そういったいいところ
# 00:13:15.910 --> 00:13:15.920 align:start position:0%
# もあるんですが、僕がこの13年間ずっと
# 00:13:15.920 --> 00:13:19.590 align:start position:0%
# もあるんですが、僕がこの13年間ずっと
# 00:13:19.590 --> 00:13:19.600 align:start position:0%
# メキシコにいる、ま、生活し続けている
# 00:13:19.600 --> 00:13:22.829 align:start position:0%
# メキシコにいる、ま、生活し続けている
# 00:13:22.829 --> 00:13:22.839 align:start position:0%
# 理由の1つがですね、ま、大きな理由の1
# 00:13:22.839 --> 00:13:27.509 align:start position:0%
# 理由の1つがですね、ま、大きな理由の1
# 00:13:27.509 --> 00:13:27.519 align:start position:0%
# つが天候です。天気なんですね。えっと、
# 00:13:27.519 --> 00:13:31.949 align:start position:0%
# つが天候です。天気なんですね。えっと、
# 00:13:31.949 --> 00:13:31.959 align:start position:0%
# この街っていうのはすごく天気がいい。
# 00:13:31.959 --> 00:13:34.910 align:start position:0%
# この街っていうのはすごく天気がいい。
# 00:13:34.910 --> 00:13:34.920 align:start position:0%
# まあ、1年のうちほとんど晴れていて、
# 00:13:34.920 --> 00:13:39.470 align:start position:0%
# まあ、1年のうちほとんど晴れていて、
# 00:13:39.470 --> 00:13:39.480 align:start position:0%
# そして寒くなく暑くもなくっていうところ
# 00:13:39.480 --> 00:13:42.710 align:start position:0%
# そして寒くなく暑くもなくっていうところ
# 00:13:42.710 --> 00:13:42.720 align:start position:0%
# なんですね。え、大体1年の平均気温が
# 00:13:42.720 --> 00:13:46.269 align:start position:0%
# なんですね。え、大体1年の平均気温が
# 00:13:46.269 --> 00:13:46.279 align:start position:0%
# 30°前後で、そして最低気温も大体
# 00:13:46.279 --> 00:13:50.590 align:start position:0%
# 30°前後で、そして最低気温も大体
# 00:13:50.590 --> 00:13:50.600 align:start position:0%
# 10°前後になります。すごくね、この
# 00:13:50.600 --> 00:13:53.710 align:start position:0%
# 10°前後になります。すごくね、この
# 00:13:53.710 --> 00:13:53.720 align:start position:0%
# 地理的に不思議なところにありまして、え
# 00:13:53.720 --> 00:13:57.870 align:start position:0%
# 地理的に不思議なところにありまして、え
# 00:13:57.870 --> 00:13:57.880 align:start position:0%
# 、地球の井戸ですね。がこう丸であったら
# 00:13:57.880 --> 00:14:00.629 align:start position:0%
# 、地球の井戸ですね。がこう丸であったら
# 00:14:00.629 --> 00:14:00.639 align:start position:0%
# どれくらいこう北なのか、どれくらい南な
# 00:14:00.639 --> 00:14:03.790 align:start position:0%
# どれくらいこう北なのか、どれくらい南な
# 00:14:03.790 --> 00:14:03.800 align:start position:0%
# のかっていうのを、え、何度で表すの?
# 00:14:03.800 --> 00:14:06.230 align:start position:0%
# のかっていうのを、え、何度で表すの?
# 00:14:06.230 --> 00:14:06.240 align:start position:0%
# これ井戸って言うんですけども、その井戸
# 00:14:06.240 --> 00:14:10.350 align:start position:0%
# これ井戸って言うんですけども、その井戸
# 00:14:10.350 --> 00:14:10.360 align:start position:0%
# が大体ハワイと同じなんですよ。ハワイっ
# 00:14:10.360 --> 00:14:13.350 align:start position:0%
# が大体ハワイと同じなんですよ。ハワイっ
# 00:14:13.350 --> 00:14:13.360 align:start position:0%
# て言ったらね、とこ、1年中っていう
# 00:14:13.360 --> 00:14:15.350 align:start position:0%
# て言ったらね、とこ、1年中っていう
# 00:14:15.350 --> 00:14:15.360 align:start position:0%
# イメージがあるところだと思うんですけど
# 00:14:15.360 --> 00:14:20.749 align:start position:0%
# イメージがあるところだと思うんですけど
# 00:14:20.749 --> 00:14:20.759 align:start position:0%
# も、ハワイと同じ井戸なんですが、標高が
# 00:14:20.759 --> 00:14:23.910 align:start position:0%
# も、ハワイと同じ井戸なんですが、標高が
# 00:14:23.910 --> 00:14:23.920 align:start position:0%
# 高いところなんですね。大体標高が
# 00:14:23.920 --> 00:14:27.629 align:start position:0%
# 高いところなんですね。大体標高が
# 00:14:27.629 --> 00:14:27.639 align:start position:0%
# 1800mぐらいあります。ああ、日本で
# 00:14:27.639 --> 00:14:30.150 align:start position:0%
# 1800mぐらいあります。ああ、日本で
# 00:14:30.150 --> 00:14:30.160 align:start position:0%
# ね、1番高いところで行っても大体
# 00:14:30.160 --> 00:14:32.389 align:start position:0%
# ね、1番高いところで行っても大体
# 00:14:32.389 --> 00:14:32.399 align:start position:0%
# 1000mぐらいですから、もうさらに上
# 00:14:32.399 --> 00:14:35.670 align:start position:0%
# 1000mぐらいですから、もうさらに上
# 00:14:35.670 --> 00:14:35.680 align:start position:0%
# ですね。え、皆さんの知っている富士山
# 00:14:35.680 --> 00:14:38.189 align:start position:0%
# ですね。え、皆さんの知っている富士山
# 00:14:38.189 --> 00:14:38.199 align:start position:0%
# ありますね。富士山のちょうど真ん中。
# 00:14:38.199 --> 00:14:40.710 align:start position:0%
# ありますね。富士山のちょうど真ん中。
# 00:14:40.710 --> 00:14:40.720 align:start position:0%
# これを5号目って言います。えっと、
# 00:14:40.720 --> 00:14:44.110 align:start position:0%
# これを5号目って言います。えっと、
# 00:14:44.110 --> 00:14:44.120 align:start position:0%
# 富士山は1番上が10号で、1番下が1号
# 00:14:44.120 --> 00:14:46.870 align:start position:0%
# 富士山は1番上が10号で、1番下が1号
# 00:14:46.870 --> 00:14:46.880 align:start position:0%
# なんですが、その真ん中5号目と同じ
# 00:14:46.880 --> 00:14:51.350 align:start position:0%
# なんですが、その真ん中5号目と同じ
# 00:14:51.350 --> 00:14:51.360 align:start position:0%
# くらいの標です。なので、朝とか夜は
# 00:14:51.360 --> 00:14:54.350 align:start position:0%
# くらいの標です。なので、朝とか夜は
# 00:14:54.350 --> 00:14:54.360 align:start position:0%
# すごく涼しいなんだけども、太陽が出て
# 00:14:54.360 --> 00:14:57.470 align:start position:0%
# すごく涼しいなんだけども、太陽が出て
# 00:14:57.470 --> 00:14:57.480 align:start position:0%
# くると暑くなる。うん。ていうね、すごく
# 00:14:57.480 --> 00:15:00.470 align:start position:0%
# くると暑くなる。うん。ていうね、すごく
# 00:15:00.470 --> 00:15:00.480 align:start position:0%
# 不思議なところです。本当に1年中天気が
# 00:15:00.480 --> 00:15:03.629 align:start position:0%
# 不思議なところです。本当に1年中天気が
# 00:15:03.629 --> 00:15:03.639 align:start position:0%
# 良くて、あの、エアコンがいらないんです
# 00:15:03.639 --> 00:15:08.069 align:start position:0%
# 良くて、あの、エアコンがいらないんです
# 00:15:08.069 --> 00:15:08.079 align:start position:0%
# よ。そう。ま、最近ね、気候変動ね、残念
# 00:15:08.079 --> 00:15:10.470 align:start position:0%
# よ。そう。ま、最近ね、気候変動ね、残念
# 00:15:10.470 --> 00:15:10.480 align:start position:0%
# なことに天気がすごく変わってきてしまっ
# 00:15:10.480 --> 00:15:13.670 align:start position:0%
# なことに天気がすごく変わってきてしまっ
# 00:15:13.670 --> 00:15:13.680 align:start position:0%
# ていて、あの、昔みたいなその気候では
# 00:15:13.680 --> 00:15:16.550 align:start position:0%
# ていて、あの、昔みたいなその気候では
# 00:15:16.550 --> 00:15:16.560 align:start position:0%
# なくなってきてはいるんですが、それでも
# 00:15:16.560 --> 00:15:19.790 align:start position:0%
# なくなってきてはいるんですが、それでも
# 00:15:19.790 --> 00:15:19.800 align:start position:0%
# 1年に1ヶ月だけ5月がすごく暑いんです
# 00:15:19.800 --> 00:15:23.749 align:start position:0%
# 1年に1ヶ月だけ5月がすごく暑いんです
# 00:15:23.749 --> 00:15:23.759 align:start position:0%
# が、それ以外は冷房もいらない。え、今ね
# 00:15:23.759 --> 00:15:25.670 align:start position:0%
# が、それ以外は冷房もいらない。え、今ね
# 00:15:25.670 --> 00:15:25.680 align:start position:0%
# 、え、このポッドキャストを撮っているの
# 00:15:25.680 --> 00:15:30.629 align:start position:0%
# 、え、このポッドキャストを撮っているの
# 00:15:30.629 --> 00:15:30.639 align:start position:0%
# は1月の、え、21日ですけども、ま、
# 00:15:30.639 --> 00:15:32.550 align:start position:0%
# は1月の、え、21日ですけども、ま、
# 00:15:32.550 --> 00:15:32.560 align:start position:0%
# この通り
# 00:15:32.560 --> 00:15:34.629 align:start position:0%
# この通り
# 00:15:34.629 --> 00:15:34.639 align:start position:0%
# 普通のこうトレーナーというかロングT
# 00:15:34.639 --> 00:15:36.670 align:start position:0%
# 普通のこうトレーナーというかロングT
# 00:15:36.670 --> 00:15:36.680 align:start position:0%
# シャツを着ています。で、今この
# 00:15:36.680 --> 00:15:38.990 align:start position:0%
# シャツを着ています。で、今この
# 00:15:38.990 --> 00:15:39.000 align:start position:0%
# ポッドキャストを撮っているのが、え、朝
# 00:15:39.000 --> 00:15:43.350 align:start position:0%
# ポッドキャストを撮っているのが、え、朝
# 00:15:43.350 --> 00:15:43.360 align:start position:0%
# の4時50分ということで、まあ1日で
# 00:15:43.360 --> 00:15:47.710 align:start position:0%
# の4時50分ということで、まあ1日で
# 00:15:47.710 --> 00:15:47.720 align:start position:0%
# 1番寒くなる時間帯、しかも1月なのに
# 00:15:47.720 --> 00:15:51.350 align:start position:0%
# 1番寒くなる時間帯、しかも1月なのに
# 00:15:51.350 --> 00:15:51.360 align:start position:0%
# こんな服装で全然寒くない。ちょうど
# 00:15:51.360 --> 00:15:54.550 align:start position:0%
# こんな服装で全然寒くない。ちょうど
# 00:15:54.550 --> 00:15:54.560 align:start position:0%
# いいっていう本当に気候がいい。ま、そう
# 00:15:54.560 --> 00:15:56.990 align:start position:0%
# いいっていう本当に気候がいい。ま、そう
# 00:15:56.990 --> 00:15:57.000 align:start position:0%
# いったこともあって、ま、未だにメキシコ
# 00:15:57.000 --> 00:15:59.829 align:start position:0%
# いったこともあって、ま、未だにメキシコ
# 00:15:59.829 --> 00:15:59.839 align:start position:0%
# のグアダラハ原に住み続けています。ま、
# 00:15:59.839 --> 00:16:02.550 align:start position:0%
# のグアダラハ原に住み続けています。ま、
# 00:16:02.550 --> 00:16:02.560 align:start position:0%
# ここで、えー、ポドキャストを撮ったりと
# 00:16:02.560 --> 00:16:04.870 align:start position:0%
# ここで、えー、ポドキャストを撮ったりと
# 00:16:04.870 --> 00:16:04.880 align:start position:0%
# かオンラインレッスンをやったりして生活
# 00:16:04.880 --> 00:16:08.230 align:start position:0%
# かオンラインレッスンをやったりして生活
# 00:16:08.230 --> 00:16:08.240 align:start position:0%
# しているっていうのが、え、出身地の
# 00:16:08.240 --> 00:16:12.430 align:start position:0%
# しているっていうのが、え、出身地の
# 00:16:12.430 --> 00:16:12.440 align:start position:0%
# テーマです。そして次なんですが家族です
# 00:16:12.440 --> 00:16:17.189 align:start position:0%
# テーマです。そして次なんですが家族です
# 00:16:17.189 --> 00:16:17.199 align:start position:0%
# ね。はい。え、僕の家族は4人家族です。
# 00:16:17.199 --> 00:16:21.150 align:start position:0%
# ね。はい。え、僕の家族は4人家族です。
# 00:16:21.150 --> 00:16:21.160 align:start position:0%
# お父さん、お母さん、僕、そして弟が1人
# 00:16:21.160 --> 00:16:23.829 align:start position:0%
# お父さん、お母さん、僕、そして弟が1人
# 00:16:23.829 --> 00:16:23.839 align:start position:0%
# います。はい。え、もうお父さんと
# 00:16:23.839 --> 00:16:26.749 align:start position:0%
# います。はい。え、もうお父さんと
# 00:16:26.749 --> 00:16:26.759 align:start position:0%
# お母さんはもうお仕事が終わりまして丁年
# 00:16:26.759 --> 00:16:30.829 align:start position:0%
# お母さんはもうお仕事が終わりまして丁年
# 00:16:30.829 --> 00:16:30.839 align:start position:0%
# 退職を迎えて、今その埼玉県の、え、昔お
# 00:16:30.839 --> 00:16:32.670 align:start position:0%
# 退職を迎えて、今その埼玉県の、え、昔お
# 00:16:32.670 --> 00:16:32.680 align:start position:0%
# じいちゃんが住んでいた実家に住んでい
# 00:16:32.680 --> 00:16:36.670 align:start position:0%
# じいちゃんが住んでいた実家に住んでい
# 00:16:36.670 --> 00:16:36.680 align:start position:0%
# ます。はい。で、えっと、ま、お父さん、
# 00:16:36.680 --> 00:16:39.269 align:start position:0%
# ます。はい。で、えっと、ま、お父さん、
# 00:16:39.269 --> 00:16:39.279 align:start position:0%
# お母さん、ま、弟がいるんですけども、ま
# 00:16:39.279 --> 00:16:42.710 align:start position:0%
# お母さん、ま、弟がいるんですけども、ま
# 00:16:42.710 --> 00:16:42.720 align:start position:0%
# 、この家族のテーマについて何を話そうか
# 00:16:42.720 --> 00:16:45.670 align:start position:0%
# 、この家族のテーマについて何を話そうか
# 00:16:45.670 --> 00:16:45.680 align:start position:0%
# なと考えていました。ま、あんまりね、
# 00:16:45.680 --> 00:16:48.509 align:start position:0%
# なと考えていました。ま、あんまりね、
# 00:16:48.509 --> 00:16:48.519 align:start position:0%
# 自分のこの家族、特にそのYouTube
# 00:16:48.519 --> 00:16:51.710 align:start position:0%
# 自分のこの家族、特にそのYouTube
# 00:16:51.710 --> 00:16:51.720 align:start position:0%
# とかSNSの活動をしていない家族につい
# 00:16:51.720 --> 00:16:55.110 align:start position:0%
# とかSNSの活動をしていない家族につい
# 00:16:55.110 --> 00:16:55.120 align:start position:0%
# ていろんな情報を話すのはやっぱり心が
# 00:16:55.120 --> 00:16:57.829 align:start position:0%
# ていろんな情報を話すのはやっぱり心が
# 00:16:57.829 --> 00:16:57.839 align:start position:0%
# 引けるうん、なんかいいのかなっていう風
# 00:16:57.839 --> 00:17:01.389 align:start position:0%
# 引けるうん、なんかいいのかなっていう風
# 00:17:01.389 --> 00:17:01.399 align:start position:0%
# に思う部分もあるので、えっと、僕の家族
# 00:17:01.399 --> 00:17:04.710 align:start position:0%
# に思う部分もあるので、えっと、僕の家族
# 00:17:04.710 --> 00:17:04.720 align:start position:0%
# のすごいところを皆さんに自慢していき
# 00:17:04.720 --> 00:17:07.949 align:start position:0%
# のすごいところを皆さんに自慢していき
# 00:17:07.949 --> 00:17:07.959 align:start position:0%
# たいと思います。はい。え、まずお父さん
# 00:17:07.959 --> 00:17:11.230 align:start position:0%
# たいと思います。はい。え、まずお父さん
# 00:17:11.230 --> 00:17:11.240 align:start position:0%
# なんですけども、え、今67歳です。なん
# 00:17:11.240 --> 00:17:14.069 align:start position:0%
# なんですけども、え、今67歳です。なん
# 00:17:14.069 --> 00:17:14.079 align:start position:0%
# ですが、未だにサーフィンをやっています
# 00:17:14.079 --> 00:17:17.710 align:start position:0%
# ですが、未だにサーフィンをやっています
# 00:17:17.710 --> 00:17:17.720 align:start position:0%
# 。すごいんですよ。はい。アスリートです
# 00:17:17.720 --> 00:17:21.549 align:start position:0%
# 。すごいんですよ。はい。アスリートです
# 00:17:21.549 --> 00:17:21.559 align:start position:0%
# 。ま、67歳っていう年なんですけども、
# 00:17:21.559 --> 00:17:25.270 align:start position:0%
# 。ま、67歳っていう年なんですけども、
# 00:17:25.270 --> 00:17:25.280 align:start position:0%
# すごいね、いい体というかはい。もう本当
# 00:17:25.280 --> 00:17:28.870 align:start position:0%
# すごいね、いい体というかはい。もう本当
# 00:17:28.870 --> 00:17:28.880 align:start position:0%
# にアスリートみたいな体で、あの、普通に
# 00:17:28.880 --> 00:17:32.110 align:start position:0%
# にアスリートみたいな体で、あの、普通に
# 00:17:32.110 --> 00:17:32.120 align:start position:0%
# 、え、冬になっても寒い海にウエット
# 00:17:32.120 --> 00:17:35.150 align:start position:0%
# 、え、冬になっても寒い海にウエット
# 00:17:35.150 --> 00:17:35.160 align:start position:0%
# スーツを着て飛び込みサーフィンをやって
# 00:17:35.160 --> 00:17:38.510 align:start position:0%
# スーツを着て飛び込みサーフィンをやって
# 00:17:38.510 --> 00:17:38.520 align:start position:0%
# います。うん。ま、父さんと言ったらもう
# 00:17:38.520 --> 00:17:41.110 align:start position:0%
# います。うん。ま、父さんと言ったらもう
# ...
# の日本語の小説を今の日本語に書き換えて
# 01:04:51.960 --> 01:04:54.990 align:start position:0%
# の日本語の小説を今の日本語に書き換えて
# 01:04:54.990 --> 01:04:55.000 align:start position:0%
# 、で、それをJLB、JLPのレベル別に
# 01:04:55.000 --> 01:04:57.510 align:start position:0%
# 、で、それをJLB、JLPのレベル別に
# 01:04:57.510 --> 01:04:57.520 align:start position:0%
# 書き換えて、ま、あの、皆さんに読んで
# 01:04:57.520 --> 01:04:59.630 align:start position:0%
# 書き換えて、ま、あの、皆さんに読んで
# 01:04:59.630 --> 01:04:59.640 align:start position:0%
# もらおう。ま、そういった活動もやって
# 01:04:59.640 --> 01:05:02.470 align:start position:0%
# もらおう。ま、そういった活動もやって
# 01:05:02.470 --> 01:05:02.480 align:start position:0%
# ます。はい。ま、それ以外には自分で
# 01:05:02.480 --> 01:05:05.150 align:start position:0%
# ます。はい。ま、それ以外には自分で
# 01:05:05.150 --> 01:05:05.160 align:start position:0%
# オリジナルの小説を書いて、え、悟り
# 01:05:05.160 --> 01:05:07.630 align:start position:0%
# オリジナルの小説を書いて、え、悟り
# 01:05:07.630 --> 01:05:07.640 align:start position:0%
# リーダーさんっていう、ま、あの、ホーム
# 01:05:07.640 --> 01:05:09.029 align:start position:0%
# リーダーさんっていう、ま、あの、ホーム
# 01:05:09.029 --> 01:05:09.039 align:start position:0%
# ページがあるんですけども、悟りリーダー
# 01:05:09.039 --> 01:05:12.029 align:start position:0%
# ページがあるんですけども、悟りリーダー
# 01:05:12.029 --> 01:05:12.039 align:start position:0%
# さんのホームページでその僕の書いた小説
# 01:05:12.039 --> 01:05:14.390 align:start position:0%
# さんのホームページでその僕の書いた小説
# 01:05:14.390 --> 01:05:14.400 align:start position:0%
# をアップロードしてもらっています。ま、
# 01:05:14.400 --> 01:05:16.190 align:start position:0%
# をアップロードしてもらっています。ま、
# 01:05:16.190 --> 01:05:16.200 align:start position:0%
# してもらっていますって言うとずっとやっ
# 01:05:16.200 --> 01:05:17.589 align:start position:0%
# してもらっていますって言うとずっとやっ
# 01:05:17.589 --> 01:05:17.599 align:start position:0%
# てますみたいに聞こえるんですが、
# 01:05:17.599 --> 01:05:19.630 align:start position:0%
# てますみたいに聞こえるんですが、
# 01:05:19.630 --> 01:05:19.640 align:start position:0%
# こな間だ初めてそれをやっていただけまし
# 01:05:19.640 --> 01:05:22.190 align:start position:0%
# こな間だ初めてそれをやっていただけまし
# 01:05:22.190 --> 01:05:22.200 align:start position:0%
# た。はい。ま、これからもね、続けていき
# 01:05:22.200 --> 01:05:24.549 align:start position:0%
# た。はい。ま、これからもね、続けていき
# 01:05:24.549 --> 01:05:24.559 align:start position:0%
# たいなと思っている活動です。ということ
# 01:05:24.559 --> 01:05:27.150 align:start position:0%
# たいなと思っている活動です。ということ
# 01:05:27.150 --> 01:05:27.160 align:start position:0%
# でSNSでポッドキャストを、え、オン
# 01:05:27.160 --> 01:05:29.269 align:start position:0%
# でSNSでポッドキャストを、え、オン
# 01:05:29.269 --> 01:05:29.279 align:start position:0%
# ラインレッスンを、そして本を作ってい
# 01:05:29.279 --> 01:05:31.950 align:start position:0%
# ラインレッスンを、そして本を作ってい
# 01:05:31.950 --> 01:05:31.960 align:start position:0%
# るっていうのが今の仕事かなと思います。
# 01:05:31.960 --> 01:05:35.750 align:start position:0%
# るっていうのが今の仕事かなと思います。
# 01:05:35.750 --> 01:05:35.760 align:start position:0%
# はい。そして、えっと、プライベート。
# 01:05:35.760 --> 01:05:39.470 align:start position:0%
# はい。そして、えっと、プライベート。
# 01:05:39.470 --> 01:05:39.480 align:start position:0%
# プライベートはですね、え、もゲームです
# 01:05:39.480 --> 01:05:43.230 align:start position:0%
# プライベートはですね、え、もゲームです
# 01:05:43.230 --> 01:05:43.240 align:start position:0%
# 。ゲーム、ゲームばっかり。うん。で、
# 01:05:43.240 --> 01:05:45.069 align:start position:0%
# 。ゲーム、ゲームばっかり。うん。で、
# 01:05:45.069 --> 01:05:45.079 align:start position:0%
# それにプライベートの時間そんなないです
# 01:05:45.079 --> 01:05:46.990 align:start position:0%
# それにプライベートの時間そんなないです
# 01:05:46.990 --> 01:05:47.000 align:start position:0%
# 。もう常にあのオンラインレッスンしてる
# 01:05:47.000 --> 01:05:49.750 align:start position:0%
# 。もう常にあのオンラインレッスンしてる
# 01:05:49.750 --> 01:05:49.760 align:start position:0%
# かポッドキャストのアイデア考えてるか
# 01:05:49.760 --> 01:05:53.470 align:start position:0%
# かポッドキャストのアイデア考えてるか
# 01:05:53.470 --> 01:05:53.480 align:start position:0%
# って感じですけども、ま、その中でもあの
# 01:05:53.480 --> 01:05:56.470 align:start position:0%
# って感じですけども、ま、その中でもあの
# 01:05:56.470 --> 01:05:56.480 align:start position:0%
# さっき言った書っていうのをよくやって
# 01:05:56.480 --> 01:05:58.069 align:start position:0%
# さっき言った書っていうのをよくやって
# 01:05:58.069 --> 01:05:58.079 align:start position:0%
# ます。こういったね、ポッドキャストの
# 01:05:58.079 --> 01:06:00.230 align:start position:0%
# ます。こういったね、ポッドキャストの
# 01:06:00.230 --> 01:06:00.240 align:start position:0%
# アイデアも全部ノートに書いてますし、
# 01:06:00.240 --> 01:06:04.109 align:start position:0%
# アイデアも全部ノートに書いてますし、
# 01:06:04.109 --> 01:06:04.119 align:start position:0%
# 01:06:04.119 --> 01:06:07.150 align:start position:0%
# 01:06:07.150 --> 01:06:07.160 align:start position:0%
# 、ま、こういったね、あの、2026年の
# 01:06:07.160 --> 01:06:09.829 align:start position:0%
# 、ま、こういったね、あの、2026年の
# 01:06:09.829 --> 01:06:09.839 align:start position:0%
# 記録、マイブっていうものを書きまし、
# 01:06:09.839 --> 01:06:12.309 align:start position:0%
# 記録、マイブっていうものを書きまし、
# 01:06:12.309 --> 01:06:12.319 align:start position:0%
# あの、買いまして、え、それぞれね、1日
# 01:06:12.319 --> 01:06:15.390 align:start position:0%
# あの、買いまして、え、それぞれね、1日
# 01:06:15.390 --> 01:06:15.400 align:start position:0%
# に何を考えたかっていうのを、ま、小説風
# 01:06:15.400 --> 01:06:18.710 align:start position:0%
# に何を考えたかっていうのを、ま、小説風
# 01:06:18.710 --> 01:06:18.720 align:start position:0%
# に書いている。ま、そういうのは、あの、
# 01:06:18.720 --> 01:06:21.150 align:start position:0%
# に書いている。ま、そういうのは、あの、
# 01:06:21.150 --> 01:06:21.160 align:start position:0%
# プライベートでやってます。まあ、なので
# 01:06:21.160 --> 01:06:26.589 align:start position:0%
# プライベートでやってます。まあ、なので
# 01:06:26.589 --> 01:06:26.599 align:start position:0%
# 本当1日大体17時間、18時間くらい
# 01:06:26.599 --> 01:06:28.870 align:start position:0%
# 本当1日大体17時間、18時間くらい
# 01:06:28.870 --> 01:06:28.880 align:start position:0%
# あのこの部屋にいて、ま、いろんな仕事を
# 01:06:28.880 --> 01:06:30.710 align:start position:0%
# あのこの部屋にいて、ま、いろんな仕事を
# 01:06:30.710 --> 01:06:30.720 align:start position:0%
# したりとかゲームをしたりしているんです
# 01:06:30.720 --> 01:06:33.470 align:start position:0%
# したりとかゲームをしたりしているんです
# 01:06:33.470 --> 01:06:33.480 align:start position:0%
# が、あの、空いている時間はゲームか書く
# 01:06:33.480 --> 01:06:37.630 align:start position:0%
# が、あの、空いている時間はゲームか書く
# 01:06:37.630 --> 01:06:37.640 align:start position:0%
# かをやっているって感じかな。はい。です
# 01:06:37.640 --> 01:06:40.549 align:start position:0%
# かをやっているって感じかな。はい。です
# 01:06:40.549 --> 01:06:40.559 align:start position:0%
# 。で、最後
# 01:06:40.559 --> 01:06:45.309 align:start position:0%
# 。で、最後
# 01:06:45.309 --> 01:06:45.319 align:start position:0%
# はい。これからの目標ということで
# 01:06:45.319 --> 01:06:49.990 align:start position:0%
# はい。これからの目標ということで
# 01:06:49.990 --> 01:06:50.000 align:start position:0%
# シンプルです。これからの僕の目標は
# 01:06:50.000 --> 01:06:53.470 align:start position:0%
# シンプルです。これからの僕の目標は
# 01:06:53.470 --> 01:06:53.480 align:start position:0%
# 日本語教師として仕事を続けていくこと
# 01:06:53.480 --> 01:06:59.109 align:start position:0%
# 日本語教師として仕事を続けていくこと
# 01:06:59.109 --> 01:06:59.119 align:start position:0%
# です。これは13年前も今もずっと変わっ
# 01:06:59.119 --> 01:07:03.150 align:start position:0%
# です。これは13年前も今もずっと変わっ
# 01:07:03.150 --> 01:07:03.160 align:start position:0%
# てないです。そう、日本語の先生として
# 01:07:03.160 --> 01:07:07.630 align:start position:0%
# てないです。そう、日本語の先生として
# 01:07:07.630 --> 01:07:07.640 align:start position:0%
# 仕事を続けていきたいだから何をするかは
# 01:07:07.640 --> 01:07:10.069 align:start position:0%
# 仕事を続けていきたいだから何をするかは
# 01:07:10.069 --> 01:07:10.079 align:start position:0%
# 変わっているんですが目標はずっと変わっ
# 01:07:10.079 --> 01:07:12.309 align:start position:0%
# 変わっているんですが目標はずっと変わっ
# 01:07:12.309 --> 01:07:12.319 align:start position:0%
# てないですね。ま、皆さんも知っていると
# 01:07:12.319 --> 01:07:15.069 align:start position:0%
# てないですね。ま、皆さんも知っていると
# 01:07:15.069 --> 01:07:15.079 align:start position:0%
# 思うんですが、日本語の先生っていうのは
# 01:07:15.079 --> 01:07:17.670 align:start position:0%
# 思うんですが、日本語の先生っていうのは
# 01:07:17.670 --> 01:07:17.680 align:start position:0%
# 、あの、お金がたくさんもらえる仕事では
# 01:07:17.680 --> 01:07:21.230 align:start position:0%
# 、あの、お金がたくさんもらえる仕事では
# 01:07:21.230 --> 01:07:21.240 align:start position:0%
# ないですね。うん。それプラスやっぱり
# 01:07:21.240 --> 01:07:24.829 align:start position:0%
# ないですね。うん。それプラスやっぱり
# 01:07:24.829 --> 01:07:24.839 align:start position:0%
# 時代の流れに大きく左右される、影響さ
# 01:07:24.839 --> 01:07:27.710 align:start position:0%
# 時代の流れに大きく左右される、影響さ
# 01:07:27.710 --> 01:07:27.720 align:start position:0%
# れる仕事でもあると思うんです。ま、
# 01:07:27.720 --> 01:07:30.309 align:start position:0%
# れる仕事でもあると思うんです。ま、
# 01:07:30.309 --> 01:07:30.319 align:start position:0%
# 例えばAIが出てしま、え、AIが出た時
# 01:07:30.319 --> 01:07:32.990 align:start position:0%
# 例えばAIが出てしま、え、AIが出た時
# 01:07:32.990 --> 01:07:33.000 align:start position:0%
# にとか、え、コロナになってオンラインの
# 01:07:33.000 --> 01:07:36.109 align:start position:0%
# にとか、え、コロナになってオンラインの
# 01:07:36.109 --> 01:07:36.119 align:start position:0%
# 仕事が当たり前になった時にその日本語
# 01:07:36.119 --> 01:07:38.230 align:start position:0%
# 仕事が当たり前になった時にその日本語
# 01:07:38.230 --> 01:07:38.240 align:start position:0%
# 教師、日本語を教える仕事っていうのは
# 01:07:38.240 --> 01:07:40.990 align:start position:0%
# 教師、日本語を教える仕事っていうのは
# 01:07:40.990 --> 01:07:41.000 align:start position:0%
# どんどんどんどん形を変えていったわけな
# 01:07:41.000 --> 01:07:43.910 align:start position:0%
# どんどんどんどん形を変えていったわけな
# 01:07:43.910 --> 01:07:43.920 align:start position:0%
# んですけども、その変わっ
# 01:07:43.920 --> 01:07:47.390 align:start position:0%
# んですけども、その変わっ
# 01:07:47.390 --> 01:07:47.400 align:start position:0%
# たとしても日本語教師の仕事を続けていく
# 01:07:47.400 --> 01:07:49.990 align:start position:0%
# たとしても日本語教師の仕事を続けていく
# 01:07:49.990 --> 01:07:50.000 align:start position:0%
# ためには自分がやることを変えていか
# 01:07:50.000 --> 01:07:52.990 align:start position:0%
# ためには自分がやることを変えていか
# 01:07:52.990 --> 01:07:53.000 align:start position:0%
# なきゃいけない。ま、そういった意味で
# 01:07:53.000 --> 01:07:54.710 align:start position:0%
# なきゃいけない。ま、そういった意味で
# 01:07:54.710 --> 01:07:54.720 align:start position:0%
# ポッドキャストをやったりオンライン
# 01:07:54.720 --> 01:07:58.670 align:start position:0%
# ポッドキャストをやったりオンライン
# 01:07:58.670 --> 01:07:58.680 align:start position:0%
# レッスンにしたり、あの本を今作ったりと
# 01:07:58.680 --> 01:08:02.829 align:start position:0%
# レッスンにしたり、あの本を今作ったりと
# 01:08:02.829 --> 01:08:02.839 align:start position:0%
# かはしています。うん。なんで日本語教師
# 01:08:02.839 --> 01:08:07.390 align:start position:0%
# かはしています。うん。なんで日本語教師
# 01:08:07.390 --> 01:08:07.400 align:start position:0%
# をここまで続けていきたいのかって、あの
# 01:08:07.400 --> 01:08:10.390 align:start position:0%
# をここまで続けていきたいのかって、あの
# 01:08:10.390 --> 01:08:10.400 align:start position:0%
# 、ま、考えるとですね、ま、いろんな理由
# 01:08:10.400 --> 01:08:12.589 align:start position:0%
# 、ま、考えるとですね、ま、いろんな理由
# 01:08:12.589 --> 01:08:12.599 align:start position:0%
# があるんですが、ま、1つはこの仕事が
# 01:08:12.599 --> 01:08:15.309 align:start position:0%
# があるんですが、ま、1つはこの仕事が
# 01:08:15.309 --> 01:08:15.319 align:start position:0%
# 好きだからですね。何が好きかって言うと
# 01:08:15.319 --> 01:08:18.590 align:start position:0%
# 好きだからですね。何が好きかって言うと
# 01:08:18.590 --> 01:08:18.600 align:start position:0%
# 、本当に世界の皆さんに出会えるからだと
# 01:08:18.600 --> 01:08:23.030 align:start position:0%
# 、本当に世界の皆さんに出会えるからだと
# 01:08:23.030 --> 01:08:23.040 align:start position:0%
# 思うんです。やっぱ人生を辛くするもの
# 01:08:23.040 --> 01:08:26.390 align:start position:0%
# 思うんです。やっぱ人生を辛くするもの
# 01:08:26.390 --> 01:08:26.400 align:start position:0%
# って人間であるっていう風にも思います
# 01:08:26.400 --> 01:08:29.669 align:start position:0%
# って人間であるっていう風にも思います
# 01:08:29.669 --> 01:08:29.679 align:start position:0%
# けども、やっぱりに人生を幸せにするのも
# 01:08:29.679 --> 01:08:33.430 align:start position:0%
# けども、やっぱりに人生を幸せにするのも
# 01:08:33.430 --> 01:08:33.440 align:start position:0%
# 人間だと思うんですよ。うん。なのでその
# 01:08:33.440 --> 01:08:36.110 align:start position:0%
# 人間だと思うんですよ。うん。なのでその
# 01:08:36.110 --> 01:08:36.120 align:start position:0%
# 素敵な人とたくさん出会いたい。そういっ
# 01:08:36.120 --> 01:08:39.269 align:start position:0%
# 素敵な人とたくさん出会いたい。そういっ
# 01:08:39.269 --> 01:08:39.279 align:start position:0%
# たお仕事っていうのを考えた時にこの日本
# 01:08:39.279 --> 01:08:41.510 align:start position:0%
# たお仕事っていうのを考えた時にこの日本
# 01:08:41.510 --> 01:08:41.520 align:start position:0%
# 語の先生っていうのは最高の仕事だなって
# 01:08:41.520 --> 01:08:43.910 align:start position:0%
# 語の先生っていうのは最高の仕事だなって
# 01:08:43.910 --> 01:08:43.920 align:start position:0%
# 思いますので、ま、これからも続けていき
# 01:08:43.920 --> 01:08:47.630 align:start position:0%
# 思いますので、ま、これからも続けていき
# 01:08:47.630 --> 01:08:47.640 align:start position:0%
# たいと思います。あとはもう多分怖さも
# 01:08:47.640 --> 01:08:50.349 align:start position:0%
# たいと思います。あとはもう多分怖さも
# 01:08:50.349 --> 01:08:50.359 align:start position:0%
# あるんでしょうね。つまりその13年前
# 01:08:50.359 --> 01:08:53.110 align:start position:0%
# あるんでしょうね。つまりその13年前
# 01:08:53.110 --> 01:08:53.120 align:start position:0%
# から大学卒業してこの日本語教師っていう
# 01:08:53.120 --> 01:08:57.189 align:start position:0%
# から大学卒業してこの日本語教師っていう
# 01:08:57.189 --> 01:08:57.199 align:start position:0%
# 仕事を始めてもう35歳になった。今更他
# 01:08:57.199 --> 01:09:00.749 align:start position:0%
# 仕事を始めてもう35歳になった。今更他
# 01:09:00.749 --> 01:09:00.759 align:start position:0%
# の仕事ってできないよなね。仕事を変える
# 01:09:00.759 --> 01:09:03.189 align:start position:0%
# の仕事ってできないよなね。仕事を変える
# 01:09:03.189 --> 01:09:03.199 align:start position:0%
# ぐらいだったら今日本語教師としてやって
# 01:09:03.199 --> 01:09:05.870 align:start position:0%
# ぐらいだったら今日本語教師としてやって
# 01:09:05.870 --> 01:09:05.880 align:start position:0%
# いることを変える方がいろんな知識とかも
# 01:09:05.880 --> 01:09:09.149 align:start position:0%
# いることを変える方がいろんな知識とかも
# 01:09:09.149 --> 01:09:09.159 align:start position:0%
# ねあの活用できるのでいいんじゃない
# 01:09:09.159 --> 01:09:11.430 align:start position:0%
# ねあの活用できるのでいいんじゃない
# 01:09:11.430 --> 01:09:11.440 align:start position:0%
# かっていう風に考えてる部分はあるんじゃ
# 01:09:11.440 --> 01:09:13.990 align:start position:0%
# かっていう風に考えてる部分はあるんじゃ
# 01:09:13.990 --> 01:09:14.000 align:start position:0%
# ないかなと思います。はい。ま、そういっ
# 01:09:14.000 --> 01:09:15.669 align:start position:0%
# ないかなと思います。はい。ま、そういっ
# た
# 01:09:15.669 --> 01:09:15.679 align:start position:0%
# た
# 01:09:15.679 --> 01:09:17.990 align:start position:0%
# た
# 01:09:17.990 --> 01:09:18.000 align:start position:0%
# 、ま、ことで
# 01:09:18.000 --> 01:09:20.630 align:start position:0%
# 、ま、ことで
# 01:09:20.630 --> 01:09:20.640 align:start position:0%
# これからもずっと日本語教師としての仕事
# 01:09:20.640 --> 01:09:22.990 align:start position:0%
# これからもずっと日本語教師としての仕事
# 01:09:22.990 --> 01:09:23.000 align:start position:0%
# を続けていきたい。それを目標に頑張って
# 01:09:23.000 --> 01:09:25.709 align:start position:0%
# を続けていきたい。それを目標に頑張って
# 01:09:25.709 --> 01:09:25.719 align:start position:0%
# いきたいと思います。はい。ま、そんな僕
# 01:09:25.719 --> 01:09:27.590 align:start position:0%
# いきたいと思います。はい。ま、そんな僕
# 01:09:27.590 --> 01:09:27.600 align:start position:0%
# でございますけども、どうだったでしょう
# 01:09:27.600 --> 01:09:29.950 align:start position:0%
# でございますけども、どうだったでしょう
# 01:09:29.950 --> 01:09:29.960 align:start position:0%
# かね。もうそんなこと知ってたよっていう
# 01:09:29.960 --> 01:09:32.229 align:start position:0%
# かね。もうそんなこと知ってたよっていう
# 01:09:32.229 --> 01:09:32.239 align:start position:0%
# こともあったでしょうし、え、そんなこと
# 01:09:32.239 --> 01:09:34.070 align:start position:0%
# こともあったでしょうし、え、そんなこと
# 01:09:34.070 --> 01:09:34.080 align:start position:0%
# あったんだ、知らなかったんだっていう
# 01:09:34.080 --> 01:09:36.430 align:start position:0%
# あったんだ、知らなかったんだっていう
# 01:09:36.430 --> 01:09:36.440 align:start position:0%
# こともあったかなと思います。で、この
# 01:09:36.440 --> 01:09:38.630 align:start position:0%
# こともあったかなと思います。で、この
# 01:09:38.630 --> 01:09:38.640 align:start position:0%
# ポッドキャストを聞いて、あ、裕介って
# 01:09:38.640 --> 01:09:41.349 align:start position:0%
# ポッドキャストを聞いて、あ、裕介って
# 01:09:41.349 --> 01:09:41.359 align:start position:0%
# こんな人間なんだな。あ、こんな人間が
# 01:09:41.359 --> 01:09:43.669 align:start position:0%
# こんな人間なんだな。あ、こんな人間が
# 01:09:43.669 --> 01:09:43.679 align:start position:0%
# 作っているポッドキャスト、ラジオ番組な
# 01:09:43.679 --> 01:09:45.990 align:start position:0%
# 作っているポッドキャスト、ラジオ番組な
# 01:09:45.990 --> 01:09:46.000 align:start position:0%
# んだなっていう風に思って聞いてくれると
# 01:09:46.000 --> 01:09:48.269 align:start position:0%
# んだなっていう風に思って聞いてくれると
# 01:09:48.269 --> 01:09:48.279 align:start position:0%
# 多分聞こえ方が変わってくるんじゃないか
# 01:09:48.279 --> 01:09:50.229 align:start position:0%
# 多分聞こえ方が変わってくるんじゃないか
# 01:09:50.229 --> 01:09:50.239 align:start position:0%
# なと思いますので、是非この
# 01:09:50.239 --> 01:09:52.430 align:start position:0%
# なと思いますので、是非この
# 01:09:52.430 --> 01:09:52.440 align:start position:0%
# ポッドキャストを聞き終わった後、え、別
# 01:09:52.440 --> 01:09:54.149 align:start position:0%
# ポッドキャストを聞き終わった後、え、別
# 01:09:54.149 --> 01:09:54.159 align:start position:0%
# のお気に入りのポッドキャストだったりと
# 01:09:54.159 --> 01:09:56.189 align:start position:0%
# のお気に入りのポッドキャストだったりと
# 01:09:56.189 --> 01:09:56.199 align:start position:0%
# か最近のエピソードを聞いてくれると
# 01:09:56.199 --> 01:09:59.030 align:start position:0%
# か最近のエピソードを聞いてくれると
# 01:09:59.030 --> 01:09:59.040 align:start position:0%
# すごく嬉しいです。はい、ということで皆
# 01:09:59.040 --> 01:10:01.189 align:start position:0%
# すごく嬉しいです。はい、ということで皆
# 01:10:01.189 --> 01:10:01.199 align:start position:0%
# さん引き続き日本語の勉強を頑張って
# 01:10:01.199 --> 01:10:06.159 align:start position:0%
# さん引き続き日本語の勉強を頑張って
